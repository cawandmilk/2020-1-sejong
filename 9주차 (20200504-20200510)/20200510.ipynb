# %% [markdown]
# # **주요 내용**
#
# *   SeparableConv2D, SeparableConv1D 구조 확인 (param # 등)

# %%
notebookName = "20200510"
notebookName
# Out:
# '20200510'

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers

height = 64
weight = 64
channels = 3
num_classes = 10

model = Sequential()
model.add(layers.SeparableConv2D(32, 3, activation = 'relu', input_shape = (height, weight, channels,)))
model.add(layers.SeparableConv2D(64, 3, activation = 'relu'))
model.add(layers.MaxPooling2D(2))

model.add(layers.SeparableConv2D(64, 3, activation = 'relu'))
model.add(layers.SeparableConv2D(128, 3, activation = 'relu'))
model.add(layers.MaxPooling2D(2))

model.add(layers.SeparableConv2D(64, 3, activation = 'relu'))
model.add(layers.SeparableConv2D(128, 3, activation = 'relu'))
model.add(layers.GlobalAveragePooling2D())

model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.Dense(num_classes, activation = 'softmax'))

model.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy')

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# separable_conv2d_2 (Separabl (None, 62, 62, 32)        155
# _________________________________________________________________
# separable_conv2d_3 (Separabl (None, 60, 60, 64)        2400
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 30, 30, 64)        0
# _________________________________________________________________
# separable_conv2d_4 (Separabl (None, 28, 28, 64)        4736
# _________________________________________________________________
# separable_conv2d_5 (Separabl (None, 26, 26, 128)       8896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# separable_conv2d_6 (Separabl (None, 11, 11, 64)        9408
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True, to_file = 'model.png')

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers

height = 64
weight = 64
channels = 3
num_classes = 10

model2 = Sequential()
model2.add(layers.Conv2D(32, 3, activation = 'relu', input_shape = (height, weight, channels,)))
model2.add(layers.Conv2D(64, 3, activation = 'relu'))
model2.add(layers.MaxPooling2D(2))

model2.add(layers.Conv2D(64, 3, activation = 'relu'))
model2.add(layers.Conv2D(128, 3, activation = 'relu'))
model2.add(layers.MaxPooling2D(2))

model2.add(layers.Conv2D(64, 3, activation = 'relu'))
model2.add(layers.Conv2D(128, 3, activation = 'relu'))
model2.add(layers.GlobalAveragePooling2D())

model2.add(layers.Dense(32, activation = 'relu'))
model2.add(layers.Dense(num_classes, activation = 'softmax'))

model2.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy')

# %%
model2.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d (Conv2D)              (None, 62, 62, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 60, 60, 64)        18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 30, 30, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        36928
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 26, 26, 128)       73856
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 11, 64)        73792
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(model2, show_shapes = True, to_file = 'model2.png')

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers

length = 3**9
num_classes = 10

model3 = Sequential()
model3.add(layers.Conv1D(32, 3, activation = 'relu', input_shape = (length, 1)))
model3.add(layers.MaxPooling1D(3))

model3.add(layers.Conv1D(64, 3, activation = 'relu'))
model3.add(layers.MaxPooling1D(3))

model3.add(layers.Conv1D(128, 3, activation = 'relu'))
model3.add(layers.MaxPooling1D(3))

model3.add(layers.Conv1D(256, 3, activation = 'relu'))
model3.add(layers.GlobalAveragePooling1D())

model3.add(layers.Dense(num_classes, activation = 'softmax'))

model3.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy')

# %%
model3.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv1d_17 (Conv1D)           (None, 19681, 32)         128
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 6560, 32)          0
# _________________________________________________________________
# conv1d_18 (Conv1D)           (None, 6558, 64)          6208
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 2186, 64)          0
# _________________________________________________________________
# conv1d_19 (Conv1D)           (None, 2184, 128)         24704
# _________________________________________________________________
# max_pooling1d_9 (MaxPooling1 (None, 728, 128)          0
# _________________________________________________________________
# conv1d_20 (Conv1D)           (None, 726, 256)          98560
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(model3, show_shapes = True, to_file = 'model3.png')

# %%
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras import layers

length = 3**9
num_classes = 10

model4 = Sequential()
model4.add(layers.SeparableConv1D(32, 3, activation = 'relu', input_shape = (length, 1)))
model4.add(layers.MaxPooling1D(3))

model4.add(layers.SeparableConv1D(64, 3, activation = 'relu'))
model4.add(layers.MaxPooling1D(3))

model4.add(layers.SeparableConv1D(128, 3, activation = 'relu'))
model4.add(layers.MaxPooling1D(3))

model4.add(layers.SeparableConv1D(256, 3, activation = 'relu'))
model4.add(layers.GlobalAveragePooling1D())

model4.add(layers.Dense(num_classes, activation = 'softmax'))

model4.compile(optimizer = 'rmsprop', loss = 'categorical_crossentropy')

# %%
model4.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# separable_conv1d (SeparableC (None, 19681, 32)         67
# _________________________________________________________________
# max_pooling1d_10 (MaxPooling (None, 6560, 32)          0
# _________________________________________________________________
# separable_conv1d_1 (Separabl (None, 6558, 64)          2208
# _________________________________________________________________
# max_pooling1d_11 (MaxPooling (None, 2186, 64)          0
# _________________________________________________________________
# separable_conv1d_2 (Separabl (None, 2184, 128)         8512
# _________________________________________________________________
# max_pooling1d_12 (MaxPooling (None, 728, 128)          0
# _________________________________________________________________
# separable_conv1d_3 (Separabl (None, 726, 256)          33408
# ...

# %%
from tensorflow.keras.utils import plot_model

plot_model(model4, show_shapes = True, to_file = 'model4.png')

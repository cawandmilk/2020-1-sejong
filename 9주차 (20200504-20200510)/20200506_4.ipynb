# %% [markdown]
# # **주요 내용**
#
# *   optimizer 변경 (rmsprop → adam)
# *   기존 실험결과와 비교 (20200506.ipynb)

# %%
notebookName = "20200506_4"
notebookName
# Out:
# '20200506_4'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0-rc4'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 18392459774731900953, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 1682744110446139572
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17196052606721242956
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 7304675328
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 15613401747347657604
#  physical_device_desc: "device: 0, name: Tesla P4, pci bus id: 0000:00:04.0, compute capability: 6.1"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Wed May  6 14:20:22 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   49C    P0    24W /  75W |    203MiB /  7611MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM04233KMS0', 'GSF08333KJH0', 'I4F02933JSI0', 'GSM05953CJH0', 'GSF08142LDH0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 9   # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %% [markdown]
# **train data, validation data 분할 및 전처리 (normalization)**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

random_state = 1234
test_size = 0.2

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels,
                                                  test_size = test_size,
                                                  random_state = random_state) # fixed

x_train = X_train.reshape(len(X_train), data_length, 1)
x_val = X_val.reshape(len(X_val), data_length, 1) 

y_train = to_categorical(Y_train)
y_val = to_categorical(Y_val)

# %%
print("test_size: {}, random_state: {}\n".format(test_size, random_state))
print('x_train.shape: {}, y_train.shape: {}'.format(x_train.shape, y_train.shape))
print('x_val.shape: {}, y_val.shape: {}'.format(x_val.shape, y_val.shape))
# Out:
# test_size: 0.2, random_state: 1234
#
# x_train.shape: (3200, 19683, 1), y_train.shape: (3200, 50)
# x_val.shape: (800, 19683, 1), y_val.shape: (800, 50)

# %% [markdown]
# **Build Model**

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model

num_blocks = 4
base = 3        # base of data_length

model = Sequential(name = notebookName)

# convolutional layer (4 blocks)
for i in range(num_blocks):
    model.add(layers.Conv1D(name = "block{}_conv".format(i+1), filters = 2 ** (4+i), kernel_size = base, strides = 1, 
                            padding = "same", activation = 'relu', input_shape = (data_length, 1)))
    model.add(layers.MaxPooling1D(name = "block{}_pool".format(i+1), pool_size = base))
    model.add(layers.BatchNormalization(name = "block{}_norm".format(i+1)))

# mapping from (3**5, 128) to (128) by GlobalAveragePooling1D()
model.add(layers.GlobalAveragePooling1D(name = "global_average_pooling"))
model.add(layers.Dense(num_labels, activation = 'softmax', name = "dense"))

model.compile(optimizer = 'adam',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# plot_model(model, show_shapes = True, to_file = 'model.png')
# Out:
# Model: "20200506_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# block1_conv (Conv1D)         (None, 19683, 16)         64
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 6561, 16)          0
# _________________________________________________________________
# block1_norm (BatchNormalizat (None, 6561, 16)          64
# _________________________________________________________________
# block2_conv (Conv1D)         (None, 6561, 32)          1568
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 2187, 32)          0
# _________________________________________________________________
# block2_norm (BatchNormalizat (None, 2187, 32)          128
# _________________________________________________________________
# block3_conv (Conv1D)         (None, 2187, 64)          6208
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 729, 64)           0
# _________________________________________________________________
# block3_norm (BatchNormalizat (None, 729, 64)           256
# _________________________________________________________________
# block4_conv (Conv1D)         (None, 729, 128)          24704
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 243, 128)          0
# _________________________________________________________________
# block4_norm (BatchNormalizat (None, 243, 128)          512
# _________________________________________________________________
# global_average_pooling (Glob (None, 128)               0
# _________________________________________________________________
# dense (Dense)                (None, 50)                6450
# =================================================================
# Total params: 39,954
# Trainable params: 39,474
# Non-trainable params: 480
# _________________________________________________________________

# %% [markdown]
# **모델 훈련 및 저장**

# %%
save_model_path = "/content/drive/My Drive/models/{}".format(notebookName)
if not os.path.exists(save_model_path):
    os.mkdir(save_model_path)

batch_size = 80
epochs = 500

print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))
history = model.fit(x_train, y_train,
                    validation_data = (x_val, y_val),
                    epochs = epochs,
                    batch_size = batch_size,
                    verbose = 0)
# Out:
# Train on 3200 samples, validate on 800 samples...

# %% [markdown]
# **모델 및 결과 저장**

# %%
save_results_path = "/content/drive/My Drive/results"
if not os.path.exists(save_results_path):
    os.mkdir(save_results_path)

np.savez_compressed(os.path.join(save_results_path, notebookName),
                    accuracy = history.history['accuracy'],
                    val_accuracy = history.history['val_accuracy'],
                    loss = history.history['loss'],
                    val_loss = history.history['val_loss'])

# name
print("save_file_name: {}".format(notebookName))
# Out:
# save_file_name: 20200506_4

# %% [markdown]
# **히스토리 출력**

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

_history = np.load(os.path.join(save_results_path, "20200506.npz"))

_acc = _history['accuracy']
_val_acc = _history['val_accuracy']
_loss = _history['loss']
_val_loss = _history['val_loss']

fig = plt.figure(figsize = (10, 8), facecolor = 'white', dpi = 300)

# accuracy
plt.subplot(2, 1, 1)

plt.plot(np.arange(1, len(acc) + 1, 1), acc, 'bo', label = 'Training accuracy (adam)', ms = 4, alpha = .7)
plt.plot(np.arange(1, len(val_acc) + 1, 1), val_acc, 'b', label = 'Validation accuracy (adam)', alpha = .7)
plt.plot(np.arange(1, len(_acc) + 1, 1), _acc, 'ro', label = 'Training accuracy (rmsprop)', ms = 4, alpha = .7)
plt.plot(np.arange(1, len(_val_acc) + 1, 1), _val_acc, 'r', label = 'Validation accuracy (rmsprop)', alpha = .7)
plt.title('train and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()

# loss
plt.subplot(2, 1, 2)

plt.plot(np.arange(1, len(loss) + 1, 1), loss, 'bo', label = 'Training loss (adam)', ms = 4, alpha = .7)
plt.plot(np.arange(1, len(val_loss) + 1, 1), val_loss, 'b', label = 'Validation loss (adam)', alpha = .7)
plt.plot(np.arange(1, len(_loss) + 1, 1), loss, 'ro', label = 'Training loss (rmsprop)', ms = 4, alpha = .7)
plt.plot(np.arange(1, len(_val_loss) + 1, 1), val_loss, 'r', label = 'Validation loss (rmsprop)', alpha = .7)
plt.title('train and validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **test data를 통해 모델 최종 평가 (field test)**

# %%
# reshaping
del test_data, test_labels

test_data = np.load(save_test_data_name + ".npy")
test_labels = np.load(save_test_labels_name + ".npy")

test_data = test_data.reshape(len(test_data), data_length, 1)
test_labels = to_categorical(test_labels)

print('test_data.shape: {}, test_labels.shape: {}'.format(test_data.shape, test_labels.shape))
# Out:
# test_data.shape: (1000, 19683, 1), test_labels.shape: (1000, 50)

# %%
results = model.evaluate(test_data, test_labels, batch_size = batch_size)

print('test loss, test acc:', results)
# Out:
# 13/13 [==============================] - 0s 32ms/step - loss: 0.0801 - accuracy: 0.9710
# test loss, test acc: [0.08005569130182266, 0.9710000157356262]

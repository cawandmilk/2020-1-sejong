# %% [markdown]
# # **주요 내용**
#
# *   모델 마지막에 fully connected layer 추가
# *   data length 2^13 -> 3^9 변경 (충분히 긴 데이터 필요)
# *   정규화 과정 생략
#
# 1.
# 2.
# 3.

# %%
notebookName = "20200521"
notebookName
# Out:
# '20200521'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2580276356912525592, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 16599559053742287111
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4525262342809591643
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13468640784454069770
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Thu May 21 03:32:21 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P0    33W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM06235BJH0', 'GSM03634SJY0', 'GSM03224CHD0', 'GSF05733HBH0', 'I4F02224SDY0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3**9  # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def my_split(train_data, train_labels):
    test_size = 0.2

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    return x_train, y_train, x_val, y_val

# %% [markdown]
# **Build Model**

# %%
def build_model_1(model_input, i):
    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = 'same')(model_input)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)
    x = layers.ReLU(name = "block1_conv1_act")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)


    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    x = layers.ReLU(name = "block2_conv1_act")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)


    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    x = layers.ReLU(name = "block3_conv1_act")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)


    # block 4
    x = layers.Conv1D(name = "block4_conv1", filters = 256, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block4_conv1_bn")(x)
    x = layers.ReLU(name = "block4_conv1_act")(x)
    
    x = layers.Conv1D(name = "block4_conv2", filters = 256, kernel_size = 3, strides = 1, padding = 'same')(x)
    x = layers.BatchNormalization(name = "block4_conv2_bn")(x)    
    x = layers.ReLU(name = "block4_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block4_pool", pool_size = 3)(x)


    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out, name = "original_ks3_{}".format(i))
    print("model name: {}".format(model.name))
    return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

# %%
model_1 = build_model_1(model_input, 0)
# Out:
# model name: original_ks3_0

# %%
model_1.summary()
# Out:
# Model: "original_ks3_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 19683, 1)]        0
# _________________________________________________________________
# block1_conv1 (Conv1D)        (None, 19683, 32)         128
# _________________________________________________________________
# block1_conv1_bn (BatchNormal (None, 19683, 32)         128
# _________________________________________________________________
# block1_conv1_act (ReLU)      (None, 19683, 32)         0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 19683, 32)         3104
# _________________________________________________________________
# block1_conv2_bn (BatchNormal (None, 19683, 32)         128
# _________________________________________________________________
# block1_conv2_act (ReLU)      (None, 19683, 32)         0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 6561, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 6561, 64)          6208
# _________________________________________________________________
# block2_conv1_bn (BatchNormal (None, 6561, 64)          256
# _________________________________________________________________
# block2_conv1_act (ReLU)      (None, 6561, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 6561, 64)          12352
# _________________________________________________________________
# block2_conv2_bn (BatchNormal (None, 6561, 64)          256
# _________________________________________________________________
# block2_conv2_act (ReLU)      (None, 6561, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 2187, 64)          0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 2187, 128)         24704
# _________________________________________________________________
# block3_conv1_bn (BatchNormal (None, 2187, 128)         512
# _________________________________________________________________
# block3_conv1_act (ReLU)      (None, 2187, 128)         0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 2187, 128)         49280
# _________________________________________________________________
# block3_conv2_bn (BatchNormal (None, 2187, 128)         512
# _________________________________________________________________
# block3_conv2_act (ReLU)      (None, 2187, 128)         0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 729, 128)          0
# _________________________________________________________________
# block4_conv1 (Conv1D)        (None, 729, 256)          98560
# _________________________________________________________________
# block4_conv1_bn (BatchNormal (None, 729, 256)          1024
# _________________________________________________________________
# block4_conv1_act (ReLU)      (None, 729, 256)          0
# _________________________________________________________________
# block4_conv2 (Conv1D)        (None, 729, 256)          196864
# _________________________________________________________________
# block4_conv2_bn (BatchNormal (None, 729, 256)          1024
# _________________________________________________________________
# block4_conv2_act (ReLU)      (None, 729, 256)          0
# _________________________________________________________________
# block4_pool (MaxPooling1D)   (None, 243, 256)          0
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 256)               0
# _________________________________________________________________
# predictions (Dense)          (None, 50)                12850
# =================================================================
# Total params: 407,890
# Trainable params: 405,970
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes = True, to_file = 'model_1.png')

# %% [markdown]
# **Train model**

# %%
from tensorflow.keras import optimizers
from tensorflow.keras import callbacks
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    opt = optimizers.RMSprop(lr = 0.001)
    model.compile(optimizer = opt,
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # save model & results
    save_model_path = os.path.join("/content/drive/My Drive/models", notebookName)
    save_results_path = os.path.join("/content/drive/My Drive/results", notebookName)

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    save_model_path = os.path.join(save_model_path, model.name)
    save_results_path = os.path.join(save_results_path, model.name)

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    # callback
    # reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.1, patience = 100)
    checkpoint = callbacks.ModelCheckpoint(filepath = os.path.join(save_model_path, "cp-{epoch:03d}-{val_accuracy:.4f}.ckpt"),
                                           monitor = 'val_accuracy', verbose = 1, save_best_only = True, save_weights_only = True)
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 1,
                        callbacks = [checkpoint])
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save
    # model.save(os.path.join(save_model_path, model.name) + ".h5")
    np.savez_compressed(os.path.join(save_results_path, model.name),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'],
                        working_time = np.array([end - start]))

# %%
def my_evaluate(model, test_data, test_labels, batch_size):
    loss, acc = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print("model name: {}, test loss: {}, test_acc: {}".format(model.name, loss, acc))

    save_eval_path = os.path.join("/content/drive/My Drive/evals", notebookName)
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    save_eval_path = os.path.join(save_eval_path, model.name)
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    pred = model.predict(test_data) # (1000, 50)
    np.save(os.path.join(save_eval_path,  model.name), pred)

# %% [markdown]
# **test**

# %%
epochs = 200
batch_size = 128
num_models = 1

# train test split
x_train, y_train, x_val, y_val = my_split(train_data, train_labels)

# build & compile & train model
model_input = Input(shape = (data_length, 1))
models = [
    build_model_1(model_input, i),
]

for model in models:
    compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs)

model_names = [model.name for model in models]
# Out:
# model name: original_ks3_49
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 21 03:53:53 2020
# Epoch 1/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7455 - accuracy: 0.3028
# Epoch 00001: val_accuracy improved from -inf to 0.05500, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-001-0.0550.ckpt
# 25/25 [==============================] - 7s 299ms/step - loss: 2.7455 - accuracy: 0.3028 - val_loss: 3.7365 - val_accuracy: 0.0550
# Epoch 2/200
# 25/25 [==============================] - ETA: 0s - loss: 1.5405 - accuracy: 0.6338
# Epoch 00002: val_accuracy improved from 0.05500 to 0.10500, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-002-0.1050.ckpt
# 25/25 [==============================] - 7s 277ms/step - loss: 1.5405 - accuracy: 0.6338 - val_loss: 3.6197 - val_accuracy: 0.1050
# Epoch 3/200
# 25/25 [==============================] - ETA: 0s - loss: 1.1010 - accuracy: 0.7609
# Epoch 00003: val_accuracy improved from 0.10500 to 0.12750, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-003-0.1275.ckpt
# 25/25 [==============================] - 7s 275ms/step - loss: 1.1010 - accuracy: 0.7609 - val_loss: 3.3259 - val_accuracy: 0.1275
# Epoch 4/200
# 25/25 [==============================] - ETA: 0s - loss: 0.8478 - accuracy: 0.8222
# Epoch 00004: val_accuracy improved from 0.12750 to 0.28375, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-004-0.2837.ckpt
# 25/25 [==============================] - 7s 282ms/step - loss: 0.8478 - accuracy: 0.8222 - val_loss: 2.8746 - val_accuracy: 0.2837
# Epoch 5/200
# 25/25 [==============================] - ETA: 0s - loss: 0.6724 - accuracy: 0.8641
# Epoch 00005: val_accuracy improved from 0.28375 to 0.34125, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-005-0.3413.ckpt
# 25/25 [==============================] - 7s 274ms/step - loss: 0.6724 - accuracy: 0.8641 - val_loss: 2.4821 - val_accuracy: 0.3413
# Epoch 6/200
# 25/25 [==============================] - ETA: 0s - loss: 0.5559 - accuracy: 0.8913
# Epoch 00006: val_accuracy improved from 0.34125 to 0.48625, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-006-0.4863.ckpt
# 25/25 [==============================] - 7s 280ms/step - loss: 0.5559 - accuracy: 0.8913 - val_loss: 2.0122 - val_accuracy: 0.4863
# Epoch 7/200
# 25/25 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.9109
# Epoch 00007: val_accuracy improved from 0.48625 to 0.55500, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp-007-0.5550.ckpt
# 25/25 [==============================] - 7s 276ms/step - loss: 0.4791 - accuracy: 0.9109 - val_loss: 1.7152 - val_accuracy: 0.5550
# Epoch 8/200
# 25/25 [==============================] - ETA: 0s - loss: 0.3955 - accuracy: 0.9175
# Epoch 00008: val_accuracy improved from 0.55500 to 0.64375, saving model to /content/drive/My Drive/models/20200521/original_ks3_49/cp
val_accuracy did not improve from 0.99750
# 25/25 [==============================] - 7s 269ms/step - loss: 0.0177 - accuracy: 0.9984 - val_loss: 0.0969 - val_accuracy: 0.9675
# Epoch 197/200
# 25/25 [==============================] - ETA: 0s - loss: 4.0664e-04 - accuracy: 1.0000
# Epoch 00197: val_accuracy did not improve from 0.99750
# 25/25 [==============================] - 7s 271ms/step - loss: 4.0664e-04 - accuracy: 1.0000 - val_loss: 0.0305 - val_accuracy: 0.9900
# Epoch 198/200
# 25/25 [==============================] - ETA: 0s - loss: 5.1274e-05 - accuracy: 1.0000
# Epoch 00198: val_accuracy did not improve from 0.99750
# 25/25 [==============================] - 7s 268ms/step - loss: 5.1274e-05 - accuracy: 1.0000 - val_loss: 0.0556 - val_accuracy: 0.9837
# Epoch 199/200
# 25/25 [==============================] - ETA: 0s - loss: 3.3081e-05 - accuracy: 1.0000
# Epoch 00199: val_accuracy did not improve from 0.99750
# 25/25 [==============================] - 7s 268ms/step - loss: 3.3081e-05 - accuracy: 1.0000 - val_loss: 0.0194 - val_accuracy: 0.9925
# Epoch 200/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0149 - accuracy: 0.9972
# Epoch 00200: val_accuracy did not improve from 0.99750
# 25/25 [==============================] - 7s 269ms/step - loss: 0.0149 - accuracy: 0.9972 - val_loss: 0.1557 - val_accuracy: 0.9550
# [    end time] Thu May 21 04:17:25 2020
# [working time] 1412.60 (sec)

# %%
model_input = Input(shape = (data_length, 1))

new_models = [
        build_model_1(model_input, 0),
]

for i, model_name in enumerate(model_names):
    checkpoint_dir = "/content/drive/My Drive/models/{}/{}".format(notebookName, model_name)
    latest = tf.train.latest_checkpoint(checkpoint_dir)

    model = new_models[i]
    model.load_weights(latest)

    opt = optimizers.RMSprop(lr = 0.001)
    model.compile(optimizer = opt,
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # test_data
    test_data = np.load(save_test_data_name + ".npy")
    test_labels = np.load(save_test_labels_name + ".npy")

    test_data = test_data.reshape(len(test_data), data_length, 1)
    test_labels = to_categorical(test_labels)

    # standarization
    # test_data -= mean
    # test_data /= std 
    
    my_evaluate(model, test_data, test_labels, batch_size)
# Out:
# model name: original_ks3_0
# 8/8 [==============================] - 1s 80ms/step - loss: 0.0269 - accuracy: 0.9950
# model name: original_ks3_0, test loss: 0.02691342867910862, test_acc: 0.9950000047683716

# %%
import numpy as np
import os

previous = notebookName
num_models = 1

working_time = np.zeros((num_models))
histories = np.zeros((num_models, 4, epochs))

for i, model_name in enumerate(model_names):
    history = np.load(os.path.join("/content/drive/My Drive/results", previous, model_name, "{}.npz".format(model_name)))

    histories[i, 0] = history['accuracy']
    histories[i, 1] = history['val_accuracy']
    histories[i, 2] = history['loss']
    histories[i, 3] = history['val_loss']

    working_time[i] = history['working_time']

# %%
print(working_time.shape, histories.shape)
# Out:
# (1,) (1, 4, 200)

# %%
mn = ["original_ks3"]

for i in range(num_models):
    print("[{}] avg working time: {:.2f} sec".format(mn[i], working_time[i]))
# Out:
# [original_ks3] avg working time: 1412.60 sec

# %%
import pandas as pd

def smooth_curve(points):
    # df = pd.DataFrame(points, columns = list('A'))
    # # df['A'] = df['A'].rolling(5).mean()
    # df['B'] = df['A'].ewm(10).mean()
    # return df['B'].to_numpy()
    return points

# %%
import matplotlib.pyplot as plt

def plot_histories(histories):
    fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)
    c = ['r', 'g', 'b', 'm', 'k', 'c']
    # l = ["--", "-", ":", "-."]
    l = ["-"] * num_models

    plt.subplot(1, 2, 1)
    for i, history in enumerate(histories):
        acc = history[0]
        val_acc = history[1]
        plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - smooth_curve(val_acc), color = c[i], label = mn[i], linewidth = 1.5, linestyle = l[i])
        # plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - val_acc, alpha = .3, color = c[i], linewidth = .5, linestyle = l[i])
    plt.title('Validation Error')
    plt.xlabel('Epochs')
    plt.ylabel('Error Rate')
    plt.ylim([-0.03, 1.03])
    # plt.yscale('log')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.subplot(1, 2, 2)
    for i, history in enumerate(histories):
        loss = history[2]
        val_loss = history[3]
        plt.plot(np.arange(1, len(val_loss) + 1, 1), smooth_curve(val_loss), color = c[i], label = mn[i], linewidth = 1.5, linestyle = l[i])
        # plt.plot(np.arange(1, len(val_loss) + 1, 1), val_loss, alpha = .3, color = c[i], linewidth = .5, linestyle = l[i])
    plt.title('Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.tight_layout()
    plt.show()

# %%
plot_histories(histories)

# %%
test_labels = np.zeros((1000, 50))
num_labels = 50

# %%
preds = np.zeros((num_models, test_labels.shape[0], test_labels.shape[1])) # (3, 10, 1000, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    preds[i] = pred
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-48-67ac596cc0b1> in <module>()
#       2
#       3 for i, model_name in enumerate(model_names):
# ----> 4     pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
#       5     preds[i] = pred
#
# /usr/local/lib/python3.6/dist-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     426         own_fid = False
#     427     else:
# --> 428         fid = open(os_fspath(file), "rb")
#     429         own_fid = True
#     430
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/evals/20200521/original_ks3_49/original_ks3_49.npy'

# %%
test_errors = np.zeros((num_models))

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)
    
    test_errors[i] = np.sum(np.not_equal(np.argmax(pred, axis = 1), y)) / test_labels.shape[0]

# %%
test_errors

# %%
for i in range(num_models):
    print("[{}] avg test error: {:.4f}".format(mn[i], test_errors[i].mean()))

# %%
cmcs = np.zeros((num_models, 50)) # (3, 10, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)

    a = np.array([sorted(pred[j], reverse = True).index(pred[j, y[j]]) for j in range(len(y))]) # 정답의 순위    
    cmcs[i] = np.array([len(a[a<=j]) / 1000 for j in range(50)])

# %%
print(cmcs)

# %%
fig = plt.figure(figsize = (5, 4), facecolor = 'white', dpi = 300)

for i, model_cmc in enumerate(cmcs):
    c = ['r', 'g', 'b', 'm', 'k', 'c']
    # l = ["--", "-", ":", "-."]
    l = ["-"] * num_models

    plt.plot(np.arange(1, 21, 1), model_cmc[:20],
             color = c[i], label = mn[i], alpha = .7, linewidth = 1.5, linestyle = l[i])

plt.title('Cumulative Match Curve')
plt.xlabel('Rank (k)')
plt.ylabel('Rank-k Classification Rate')
plt.xticks([1, 5, 10, 20])
plt.legend()
plt.grid(True, linewidth = 0.4)

plt.tight_layout()
plt.show()

# %%
for i, cmc in enumerate(cmcs):
    print("[{}] top 1 error: {:.4f}, top 5 error: {:.4f}".format(mn[i], 1 - cmc[0], 1 - cmc[4]))

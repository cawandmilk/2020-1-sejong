# %% [markdown]
# # **주요 내용**
#
# *   20200512_9.ipynb 사용
# *   checkpoint의 관찰항목 val_accuracy -> val_loss

# %%
notebookName = "20200521_2"
notebookName
# Out:
# '20200521_2'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2460324216890572766, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 4241512640363158006
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 11087309905877566125
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 18030979229969439216
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Thu May 21 04:30:19 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    30W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM06235BJH0', 'GSM03634SJY0', 'GSM03224CHD0', 'GSF05733HBH0', 'I4F02224SDY0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3**9  # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def my_split(train_data, train_labels):
    test_size = 0.2

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    return x_train, y_train, x_val, y_val

# %% [markdown]
# **Build Model**

# %%
def build_model_1(model_input, i):

    # block 1
    a = layers.Conv1D(name = "block1a_conv", filters = 32, kernel_size = 3, strides = 1, padding = 'same')(model_input)
    a = layers.ReLU(name = "block1a_conv_act")(a)

    b = layers.Conv1D(name = "block1b_conv", filters = 32, kernel_size = 5, strides = 1, padding = 'same')(model_input)
    b = layers.ReLU(name = "block1b_conv_act")(b)
    
    x = layers.Add(name = "block1_add")([a, b])
    x = layers.BatchNormalization(name = "block1_bn")(x)
    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    a = layers.Conv1D(name = "block2a_conv", filters = 64, kernel_size = 3, strides = 1, padding = 'same')(x)
    a = layers.ReLU(name = "block2a_conv_act")(a)

    b = layers.Conv1D(name = "block2b_conv", filters = 64, kernel_size = 5, strides = 1, padding = 'same')(x)
    b = layers.ReLU(name = "block2b_conv_act")(b)
    
    x = layers.Add(name = "block2_add")([a, b])
    x = layers.BatchNormalization(name = "block2_bn")(x)
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    a = layers.Conv1D(name = "block3a_conv", filters = 128, kernel_size = 3, strides = 1, padding = 'same')(x)
    a = layers.ReLU(name = "block3a_conv_act")(a)

    b = layers.Conv1D(name = "block3b_conv", filters = 128, kernel_size = 5, strides = 1, padding = 'same')(x)
    b = layers.ReLU(name = "block3b_conv_act")(b)
    
    x = layers.Add(name = "block3_add")([a, b])
    x = layers.BatchNormalization(name = "block3_bn")(x)
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # block 4
    a = layers.Conv1D(name = "block4a_conv", filters = 256, kernel_size = 3, strides = 1, padding = 'same')(x)
    a = layers.ReLU(name = "block4a_conv_act")(a)

    b = layers.Conv1D(name = "block4b_conv", filters = 256, kernel_size = 5, strides = 1, padding = 'same')(x)
    b = layers.ReLU(name = "block4b_conv_act")(b)
    
    x = layers.Add(name = "block4_add")([a, b])
    x = layers.BatchNormalization(name = "block4_bn")(x)
    x = layers.MaxPooling1D(name = "block4_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out, name = "xcep_conv_ks3_{}".format(i))
    print("model name: {}".format(model.name))
    return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

# %%
model_1 = build_model_1(model_input, 0)
# Out:
# model name: xcep_conv_ks3_0

# %%
model_1.summary()
# Out:
# Model: "xcep_conv_ks3_0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_5 (InputLayer)            [(None, 19683, 1)]   0
# __________________________________________________________________________________________________
# block1a_conv (Conv1D)           (None, 19683, 32)    128         input_5[0][0]
# __________________________________________________________________________________________________
# block1b_conv (Conv1D)           (None, 19683, 32)    192         input_5[0][0]
# __________________________________________________________________________________________________
# block1a_conv_act (ReLU)         (None, 19683, 32)    0           block1a_conv[0][0]
# __________________________________________________________________________________________________
# block1b_conv_act (ReLU)         (None, 19683, 32)    0           block1b_conv[0][0]
# __________________________________________________________________________________________________
# block1_add (Add)                (None, 19683, 32)    0           block1a_conv_act[0][0]
#                                                                  block1b_conv_act[0][0]
# __________________________________________________________________________________________________
# block1_bn (BatchNormalization)  (None, 19683, 32)    128         block1_add[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 6561, 32)     0           block1_bn[0][0]
# __________________________________________________________________________________________________
# block2a_conv (Conv1D)           (None, 6561, 64)     6208        block1_pool[0][0]
# __________________________________________________________________________________________________
# block2b_conv (Conv1D)           (None, 6561, 64)     10304       block1_pool[0][0]
# __________________________________________________________________________________________________
# block2a_conv_act (ReLU)         (None, 6561, 64)     0           block2a_conv[0][0]
# __________________________________________________________________________________________________
# block2b_conv_act (ReLU)         (None, 6561, 64)     0           block2b_conv[0][0]
# __________________________________________________________________________________________________
# block2_add (Add)                (None, 6561, 64)     0           block2a_conv_act[0][0]
#                                                                  block2b_conv_act[0][0]
# __________________________________________________________________________________________________
# block2_bn (BatchNormalization)  (None, 6561, 64)     256         block2_add[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 2187, 64)     0           block2_bn[0][0]
# __________________________________________________________________________________________________
# block3a_conv (Conv1D)           (None, 2187, 128)    24704       block2_pool[0][0]
# __________________________________________________________________________________________________
# block3b_conv (Conv1D)           (None, 2187, 128)    41088       block2_pool[0][0]
# __________________________________________________________________________________________________
# block3a_conv_act (ReLU)         (None, 2187, 128)    0           block3a_conv[0][0]
# __________________________________________________________________________________________________
# block3b_conv_act (ReLU)         (None, 2187, 128)    0           block3b_conv[0][0]
# __________________________________________________________________________________________________
# block3_add (Add)                (None, 2187, 128)    0           block3a_conv_act[0][0]
#                                                                  block3b_conv_act[0][0]
# __________________________________________________________________________________________________
# block3_bn (BatchNormalization)  (None, 2187, 128)    512         block3_add[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 729, 128)     0           block3_bn[0][0]
# __________________________________________________________________________________________________
# block4a_conv (Conv1D)           (None, 729, 256)     98560       block3_pool[0][0]
# __________________________________________________________________________________________________
# block4b_conv (Conv1D)           (None, 729, 256)     164096      block3_pool[0][0]
# __________________________________________________________________________________________________
# block4a_conv_act (ReLU)         (None, 729, 256)     0           block4a_conv[0][0]
# __________________________________________________________________________________________________
# block4b_conv_act (ReLU)         (None, 729, 256)     0           block4b_conv[0][0]
# __________________________________________________________________________________________________
# block4_add (Add)                (None, 729, 256)     0           block4a_conv_act[0][0]
#                                                                  block4b_conv_act[0][0]
# __________________________________________________________________________________________________
# block4_bn (BatchNormalization)  (None, 729, 256)     1024        block4_add[0][0]
# __________________________________________________________________________________________________
# block4_pool (MaxPooling1D)      (None, 243, 256)     0           block4_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 256)          0           block4_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           12850       avg_pool[0][0]
# ==================================================================================================
# Total params: 360,050
# Trainable params: 359,090
# Non-trainable params: 960
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes = True, to_file = 'model_1.png')

# %% [markdown]
# **Train model**

# %%
from tensorflow.keras import optimizers
from tensorflow.keras import callbacks
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    opt = optimizers.RMSprop(lr = 0.001)
    model.compile(optimizer = opt,
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # save model & results
    save_model_path = os.path.join("/content/drive/My Drive/models", notebookName)
    save_results_path = os.path.join("/content/drive/My Drive/results", notebookName)

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    save_model_path = os.path.join(save_model_path, model.name)
    save_results_path = os.path.join(save_results_path, model.name)

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    # callback
    # reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.1, patience = 100)
    checkpoint = callbacks.ModelCheckpoint(filepath = os.path.join(save_model_path, "cp-{epoch:03d}-{val_loss:.4f}.ckpt"),
                                           monitor = 'val_loss', verbose = 1, save_best_only = True, save_weights_only = True)
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 1,
                        callbacks = [checkpoint])
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save
    # model.save(os.path.join(save_model_path, model.name) + ".h5")
    np.savez_compressed(os.path.join(save_results_path, model.name),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'],
                        working_time = np.array([end - start]))

# %%
def my_evaluate(model, test_data, test_labels, batch_size):
    loss, acc = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print("model name: {}, test loss: {}, test_acc: {}".format(model.name, loss, acc))

    save_eval_path = os.path.join("/content/drive/My Drive/evals", notebookName)
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    save_eval_path = os.path.join(save_eval_path, model.name)
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    pred = model.predict(test_data) # (1000, 50)
    np.save(os.path.join(save_eval_path,  model.name), pred)

# %% [markdown]
# **test**

# %%
epochs = 200
batch_size = 128
num_models = 1

# train test split
x_train, y_train, x_val, y_val = my_split(train_data, train_labels)

# build & compile & train model
model_input = Input(shape = (data_length, 1))
models = [
    build_model_1(model_input, i),
]

for model in models:
    compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs)

model_names = [model.name for model in models]
# Out:
# model name: xcep_conv_ks3_49
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 21 04:40:44 2020
# Epoch 1/200
# 25/25 [==============================] - ETA: 0s - loss: 2.4438 - accuracy: 0.3953
# Epoch 00001: val_loss improved from inf to 7.52330, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-001-7.5233.ckpt
# 25/25 [==============================] - 5s 217ms/step - loss: 2.4438 - accuracy: 0.3953 - val_loss: 7.5233 - val_accuracy: 0.0237
# Epoch 2/200
# 25/25 [==============================] - ETA: 0s - loss: 1.1336 - accuracy: 0.7675
# Epoch 00002: val_loss improved from 7.52330 to 3.35652, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-002-3.3565.ckpt
# 25/25 [==============================] - 5s 204ms/step - loss: 1.1336 - accuracy: 0.7675 - val_loss: 3.3565 - val_accuracy: 0.1013
# Epoch 3/200
# 25/25 [==============================] - ETA: 0s - loss: 0.6718 - accuracy: 0.8747
# Epoch 00003: val_loss improved from 3.35652 to 2.71173, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-003-2.7117.ckpt
# 25/25 [==============================] - 5s 201ms/step - loss: 0.6718 - accuracy: 0.8747 - val_loss: 2.7117 - val_accuracy: 0.2600
# Epoch 4/200
# 25/25 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.9162
# Epoch 00004: val_loss improved from 2.71173 to 2.35535, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-004-2.3554.ckpt
# 25/25 [==============================] - 5s 206ms/step - loss: 0.4939 - accuracy: 0.9162 - val_loss: 2.3554 - val_accuracy: 0.3075
# Epoch 5/200
# 25/25 [==============================] - ETA: 0s - loss: 0.3519 - accuracy: 0.9397
# Epoch 00005: val_loss improved from 2.35535 to 1.73889, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-005-1.7389.ckpt
# 25/25 [==============================] - 5s 201ms/step - loss: 0.3519 - accuracy: 0.9397 - val_loss: 1.7389 - val_accuracy: 0.5550
# Epoch 6/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2598 - accuracy: 0.9634
# Epoch 00006: val_loss improved from 1.73889 to 1.24916, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-006-1.2492.ckpt
# 25/25 [==============================] - 5s 208ms/step - loss: 0.2598 - accuracy: 0.9634 - val_loss: 1.2492 - val_accuracy: 0.7663
# Epoch 7/200
# 25/25 [==============================] - ETA: 0s - loss: 0.2167 - accuracy: 0.9644
# Epoch 00007: val_loss improved from 1.24916 to 0.93530, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-007-0.9353.ckpt
# 25/25 [==============================] - 5s 201ms/step - loss: 0.2167 - accuracy: 0.9644 - val_loss: 0.9353 - val_accuracy: 0.8375
# Epoch 8/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1606 - accuracy: 0.9753
# Epoch 00008: val_loss improved from 0.93530 to 0.75708, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-008-0.7571.ckpt
# 25/25 [==============================] - 5s 208ms/step - loss: 0.1606 - accuracy: 0.9753 - val_loss: 0.7571 - val_accuracy: 0.8188
# Epoch 9/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1287 - accuracy: 0.9831
# Epoch 00009: val_loss improved from 0.75708 to 0.41516, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-009-0.4152.ckpt
# 25/25 [==============================] - 5s 203ms/step - loss: 0.1287 - accuracy: 0.9831 - val_loss: 0.4152 - val_accuracy: 0.9413
# Epoch 10/200
# 25/25 [==============================] - ETA: 0s - loss: 0.1173 - accuracy: 0.9850
# Epoch 00010: val_loss did not improve from 0.41516
# 25/25 [==============================] - 5s 199ms/step - loss: 0.1173 - accuracy: 0.9850 - val_loss: 0.4160 - val_accuracy: 0.9038
# Epoch 11/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0957 - accuracy: 0.9847
# Epoch 00011: val_loss improved from 0.41516 to 0.26019, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-011-0.2602.ckpt
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0957 - accuracy: 0.9847 - val_loss: 0.2602 - val_accuracy: 0.9488
# Epoch 12/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0828 - accuracy: 0.9887
# Epoch 00012: val_loss improved from 0.26019 to 0.18754, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-012-0.1875.ckpt
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0828 - accuracy: 0.9887 - val_loss: 0.1875 - val_accuracy: 0.9750
# Epoch 13/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0619 - accuracy: 0.9925
# Epoch 00013: val_loss did not improve from 0.18754
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0619 - accuracy: 0.9925 - val_loss: 0.2211 - val_accuracy: 0.9438
# Epoch 14/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9919
# Epoch 00014: val_loss improved from 0.18754 to 0.16100, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-014-0.1610.ckpt
# 25/25 [==============================] - 5s 208ms/step - loss: 0.0551 - accuracy: 0.9919 - val_loss: 0.1610 - val_accuracy: 0.9613
# Epoch 15/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0507 - accuracy: 0.9928
# Epoch 00015: val_loss improved from 0.16100 to 0.10617, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-015-0.1062.ckpt
# 25/25 [==============================] - 5s 202ms/step - loss: 0.0507 - accuracy: 0.9928 - val_loss: 0.1062 - val_accuracy: 0.9812
# Epoch 16/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9937
# Epoch 00016: val_loss did not improve from 0.10617
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0428 - accuracy: 0.9937 - val_loss: 0.1454 - val_accuracy: 0.9700
# Epoch 17/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9947
# Epoch 00017: val_loss did not improve from 0.10617
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0428 - accuracy: 0.9947 - val_loss: 0.1078 - val_accuracy: 0.9750
# Epoch 18/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9975
# Epoch 00018: val_loss did not improve from 0.10617
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0235 - accuracy: 0.9975 - val_loss: 0.3213 - val_accuracy: 0.9275
# Epoch 19/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0356 - accuracy: 0.9925
# Epoch 00019: val_loss improved from 0.10617 to 0.09322, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-019-0.0932.ckpt
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0356 - accuracy: 0.9925 - val_loss: 0.0932 - val_accuracy: 0.9775
# Epoch 20/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0348 - accuracy: 0.9925
# Epoch 00020: val_loss did not improve from 0.09322
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0348 - accuracy: 0.9925 - val_loss: 0.1185 - val_accuracy: 0.9675
# Epoch 21/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9994
# Epoch 00021: val_loss did not improve from 0.09322
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0151 - accuracy: 0.9994 - val_loss: 0.1029 - val_accuracy: 0.9725
# Epoch 22/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.9950
# Epoch 00022: val_loss did not improve from 0.09322
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0255 - accuracy: 0.9950 - val_loss: 0.1055 - val_accuracy: 0.9725
# Epoch 23/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9981
# Epoch 00023: val_loss improved from 0.09322 to 0.08181, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-023-0.0818.ckpt
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0160 - accuracy: 0.9981 - val_loss: 0.0818 - val_accuracy: 0.9812
# Epoch 24/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0293 - accuracy: 0.9944
# Epoch 00024: val_loss did not improve from 0.08181
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0293 - accuracy: 0.9944 - val_loss: 0.0980 - val_accuracy: 0.9725
# Epoch 25/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00025: val_loss improved from 0.08181 to 0.07039, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-025-0.0704.ckpt
# 25/25 [==============================] - 5s 205ms/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.0704 - val_accuracy: 0.9825
# Epoch 26/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9972
# Epoch 00026: val_loss did not improve from 0.07039
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0181 - accuracy: 0.9972 - val_loss: 0.3498 - val_accuracy: 0.9200
# Epoch 27/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 1.0000
# Epoch 00027: val_loss did not improve from 0.07039
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0735 - val_accuracy: 0.9812
# Epoch 28/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0138 - accuracy: 0.9987
# Epoch 00028: val_loss did not improve from 0.07039
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0138 - accuracy: 0.9987 - val_loss: 0.1038 - val_accuracy: 0.9712
# Epoch 29/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9969
# Epoch 00029: val_loss improved from 0.07039 to 0.05479, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-029-0.0548.ckpt
# 25/25 [==============================] - 5s 201ms/step - loss: 0.0204 - accuracy: 0.9969 - val_loss: 0.0548 - val_accuracy: 0.9875
# Epoch 30/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0139 - accuracy: 0.9972
# Epoch 00030: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0139 - accuracy: 0.9972 - val_loss: 0.0692 - val_accuracy: 0.9837
# Epoch 31/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0030 - accuracy: 1.0000
# Epoch 00031: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0575 - val_accuracy: 0.9862
# Epoch 32/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9978
# Epoch 00032: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0111 - accuracy: 0.9978 - val_loss: 0.0699 - val_accuracy: 0.9825
# Epoch 33/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9969
# Epoch 00033: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0137 - accuracy: 0.9969 - val_loss: 0.1285 - val_accuracy: 0.9625
# Epoch 34/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9981
# Epoch 00034: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0112 - accuracy: 0.9981 - val_loss: 0.0603 - val_accuracy: 0.9837
# Epoch 35/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 1.0000
# Epoch 00035: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0988 - val_accuracy: 0.9775
# Epoch 36/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0129 - accuracy: 0.9969
# Epoch 00036: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0129 - accuracy: 0.9969 - val_loss: 0.1281 - val_accuracy: 0.9688
# Epoch 37/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.9991
# Epoch 00037: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0065 - accuracy: 0.9991 - val_loss: 0.0923 - val_accuracy: 0.9725
# Epoch 38/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0203 - accuracy: 0.9959
# Epoch 00038: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0203 - accuracy: 0.9959 - val_loss: 0.0712 - val_accuracy: 0.9812
# Epoch 39/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00039: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.1105 - val_accuracy: 0.9737
# Epoch 40/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9984
# Epoch 00040: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.0580 - val_accuracy: 0.9862
# Epoch 41/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000
# Epoch 00041: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 200ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0932 - val_accuracy: 0.9737
# Epoch 42/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9978
# Epoch 00042: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0097 - accuracy: 0.9978 - val_loss: 0.0732 - val_accuracy: 0.9812
# Epoch 43/200
# 25/25 [==============================] - ETA: 0s - loss: 9.5516e-04 - accuracy: 1.0000
# Epoch 00043: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 9.5516e-04 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9887
# Epoch 44/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9987
# Epoch 00044: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.7567 - val_accuracy: 0.8825
# Epoch 45/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9987
# Epoch 00045: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0071 - accuracy: 0.9987 - val_loss: 0.0621 - val_accuracy: 0.9850
# Epoch 46/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9991
# Epoch 00046: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0064 - accuracy: 0.9991 - val_loss: 0.1348 - val_accuracy: 0.9663
# Epoch 47/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 1.0000
# Epoch 00047: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9887
# Epoch 48/200
# 25/25 [==============================] - ETA: 0s - loss: 4.0915e-04 - accuracy: 1.0000
# Epoch 00048: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 4.0915e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9887
# Epoch 49/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.9953
# Epoch 00049: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0278 - accuracy: 0.9953 - val_loss: 0.0670 - val_accuracy: 0.9825
# Epoch 50/200
# 25/25 [==============================] - ETA: 0s - loss: 4.8228e-04 - accuracy: 1.0000
# Epoch 00050: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 4.8228e-04 - accuracy: 1.0000 - val_loss: 0.0613 - val_accuracy: 0.9825
# Epoch 51/200
# 25/25 [==============================] - ETA: 0s - loss: 2.9907e-04 - accuracy: 1.0000
# Epoch 00051: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 2.9907e-04 - accuracy: 1.0000 - val_loss: 0.0658 - val_accuracy: 0.9825
# Epoch 52/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9984
# Epoch 00052: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0061 - accuracy: 0.9984 - val_loss: 0.0712 - val_accuracy: 0.9837
# Epoch 53/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9997
# Epoch 00053: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1174 - val_accuracy: 0.9675
# Epoch 54/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0082 - accuracy: 0.9972
# Epoch 00054: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0082 - accuracy: 0.9972 - val_loss: 0.0592 - val_accuracy: 0.9875
# Epoch 55/200
# 25/25 [==============================] - ETA: 0s - loss: 4.1547e-04 - accuracy: 1.0000
# Epoch 00055: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 4.1547e-04 - accuracy: 1.0000 - val_loss: 0.0563 - val_accuracy: 0.9875
# Epoch 56/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9966
# Epoch 00056: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0156 - accuracy: 0.9966 - val_loss: 0.0898 - val_accuracy: 0.9762
# Epoch 57/200
# 25/25 [==============================] - ETA: 0s - loss: 5.9411e-04 - accuracy: 1.0000
# Epoch 00057: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 5.9411e-04 - accuracy: 1.0000 - val_loss: 0.0603 - val_accuracy: 0.9862
# Epoch 58/200
# 25/25 [==============================] - ETA: 0s - loss: 2.1144e-04 - accuracy: 1.0000
# Epoch 00058: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 2.1144e-04 - accuracy: 1.0000 - val_loss: 0.0560 - val_accuracy: 0.9887
# Epoch 59/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.9962
# Epoch 00059: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0150 - accuracy: 0.9962 - val_loss: 0.1581 - val_accuracy: 0.9625
# Epoch 60/200
# 25/25 [==============================] - ETA: 0s - loss: 9.5056e-04 - accuracy: 1.0000
# Epoch 00060: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 9.5056e-04 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9825
# Epoch 61/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7126e-04 - accuracy: 1.0000
# Epoch 00061: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 200ms/step - loss: 2.7126e-04 - accuracy: 1.0000 - val_loss: 0.0672 - val_accuracy: 0.9850
# Epoch 62/200
# 25/25 [==============================] - ETA: 0s - loss: 1.4795e-04 - accuracy: 1.0000
# Epoch 00062: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 1.4795e-04 - accuracy: 1.0000 - val_loss: 0.0697 - val_accuracy: 0.9837
# Epoch 63/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9969
# Epoch 00063: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0109 - accuracy: 0.9969 - val_loss: 0.1369 - val_accuracy: 0.9625
# Epoch 64/200
# 25/25 [==============================] - ETA: 0s - loss: 5.7887e-04 - accuracy: 1.0000
# Epoch 00064: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 5.7887e-04 - accuracy: 1.0000 - val_loss: 0.1152 - val_accuracy: 0.9700
# Epoch 65/200
# 25/25 [==============================] - ETA: 0s - loss: 2.4140e-04 - accuracy: 1.0000
# Epoch 00065: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 2.4140e-04 - accuracy: 1.0000 - val_loss: 0.0585 - val_accuracy: 0.9825
# Epoch 66/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7291e-04 - accuracy: 1.0000
# Epoch 00066: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 2.7291e-04 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9388
# Epoch 67/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0207 - accuracy: 0.9966
# Epoch 00067: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0207 - accuracy: 0.9966 - val_loss: 0.0609 - val_accuracy: 0.9812
# Epoch 68/200
# 25/25 [==============================] - ETA: 0s - loss: 2.2125e-04 - accuracy: 1.0000
# Epoch 00068: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 2.2125e-04 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 0.9850
# Epoch 69/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0084 - accuracy: 0.9978
# Epoch 00069: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0084 - accuracy: 0.9978 - val_loss: 0.1904 - val_accuracy: 0.9563
# Epoch 70/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9994
# Epoch 00070: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.0678 - val_accuracy: 0.9850
# Epoch 71/200
# 25/25 [==============================] - ETA: 0s - loss: 1.8786e-04 - accuracy: 1.0000
# Epoch 00071: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 200ms/step - loss: 1.8786e-04 - accuracy: 1.0000 - val_loss: 0.0564 - val_accuracy: 0.9850
# Epoch 72/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9997
# Epoch 00072: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 203ms/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 0.1247 - val_accuracy: 0.9675
# Epoch 73/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9984
# Epoch 00073: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0080 - accuracy: 0.9984 - val_loss: 0.2005 - val_accuracy: 0.9513
# Epoch 74/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0147 - accuracy: 0.9966
# Epoch 00074: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0147 - accuracy: 0.9966 - val_loss: 0.0672 - val_accuracy: 0.9737
# Epoch 75/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 00075: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.0779 - val_accuracy: 0.9787
# Epoch 76/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0100 - accuracy: 0.9981
# Epoch 00076: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0100 - accuracy: 0.9981 - val_loss: 0.1097 - val_accuracy: 0.9688
# Epoch 77/200
# 25/25 [==============================] - ETA: 0s - loss: 2.3167e-04 - accuracy: 1.0000
# Epoch 00077: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 2.3167e-04 - accuracy: 1.0000 - val_loss: 0.0686 - val_accuracy: 0.9850
# Epoch 78/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0089 - accuracy: 0.9975
# Epoch 00078: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 0.1141 - val_accuracy: 0.9712
# Epoch 79/200
# 25/25 [==============================] - ETA: 0s - loss: 3.9783e-04 - accuracy: 1.0000
# Epoch 00079: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 199ms/step - loss: 3.9783e-04 - accuracy: 1.0000 - val_loss: 0.0693 - val_accuracy: 0.9812
# Epoch 80/200
# 25/25 [==============================] - ETA: 0s - loss: 1.3466e-04 - accuracy: 1.0000
# Epoch 00080: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 1.3466e-04 - accuracy: 1.0000 - val_loss: 0.0593 - val_accuracy: 0.9850
# Epoch 81/200
# 25/25 [==============================] - ETA: 0s - loss: 6.4886e-05 - accuracy: 1.0000
# Epoch 00081: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 6.4886e-05 - accuracy: 1.0000 - val_loss: 0.0562 - val_accuracy: 0.9862
# Epoch 82/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9975
# Epoch 00082: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.0998 - val_accuracy: 0.9750
# Epoch 83/200
# 25/25 [==============================] - ETA: 0s - loss: 2.2700e-04 - accuracy: 1.0000
# Epoch 00083: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 2.2700e-04 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9837
# Epoch 84/200
# 25/25 [==============================] - ETA: 0s - loss: 4.8979e-04 - accuracy: 1.0000
# Epoch 00084: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 4.8979e-04 - accuracy: 1.0000 - val_loss: 0.0863 - val_accuracy: 0.9800
# Epoch 85/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9984
# Epoch 00085: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0123 - accuracy: 0.9984 - val_loss: 0.0774 - val_accuracy: 0.9775
# Epoch 86/200
# 25/25 [==============================] - ETA: 0s - loss: 1.2264e-04 - accuracy: 1.0000
# Epoch 00086: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 1.2264e-04 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9825
# Epoch 87/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9994
# Epoch 00087: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0042 - accuracy: 0.9994 - val_loss: 0.7406 - val_accuracy: 0.9275
# Epoch 88/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9994
# Epoch 00088: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.1856 - val_accuracy: 0.9475
# Epoch 89/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9966
# Epoch 00089: val_loss did not improve from 0.05479
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0124 - accuracy: 0.9966 - val_loss: 0.0896 - val_accuracy: 0.9812
# Epoch 90/200
# 25/25 [==============================] - ETA: 0s - loss: 5.2135e-04 - accuracy: 1.0000
# Epoch 00090: val_loss improved from 0.05479 to 0.05018, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-090-0.0502.ckpt
# 25/25 [==============================] - 5s 202ms/step - loss: 5.2135e-04 - accuracy: 1.0000 - val_loss: 0.0502 - val_accuracy: 0.9862
# Epoch 91/200
# 25/25 [==============================] - ETA: 0s - loss: 9.3475e-05 - accuracy: 1.0000
# Epoch 00091: val_loss improved from 0.05018 to 0.04955, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-091-0.0495.ckpt
# 25/25 [==============================] - 5s 201ms/step - loss: 9.3475e-05 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9875
# Epoch 92/200
# 25/25 [==============================] - ETA: 0s - loss: 5.3766e-05 - accuracy: 1.0000
# Epoch 00092: val_loss improved from 0.04955 to 0.04688, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-092-0.0469.ckpt
# 25/25 [==============================] - 5s 203ms/step - loss: 5.3766e-05 - accuracy: 1.0000 - val_loss: 0.0469 - val_accuracy: 0.9875
# Epoch 93/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0042 - accuracy: 0.9991
# Epoch 00093: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0914 - val_accuracy: 0.9737
# Epoch 94/200
# 25/25 [==============================] - ETA: 0s - loss: 2.0622e-04 - accuracy: 1.0000
# Epoch 00094: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.0622e-04 - accuracy: 1.0000 - val_loss: 0.0531 - val_accuracy: 0.9850
# Epoch 95/200
# 25/25 [==============================] - ETA: 0s - loss: 4.9482e-05 - accuracy: 1.0000
# Epoch 00095: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 4.9482e-05 - accuracy: 1.0000 - val_loss: 0.0548 - val_accuracy: 0.9862
# Epoch 96/200
# 25/25 [==============================] - ETA: 0s - loss: 2.2249e-05 - accuracy: 1.0000
# Epoch 00096: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.2249e-05 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9887
# Epoch 97/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00097: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.0629 - val_accuracy: 0.9825
# Epoch 98/200
# 25/25 [==============================] - ETA: 0s - loss: 6.7493e-05 - accuracy: 1.0000
# Epoch 00098: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 6.7493e-05 - accuracy: 1.0000 - val_loss: 0.0538 - val_accuracy: 0.9875
# Epoch 99/200
# 25/25 [==============================] - ETA: 0s - loss: 2.1314e-05 - accuracy: 1.0000
# Epoch 00099: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.1314e-05 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9850
# Epoch 100/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9991
# Epoch 00100: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0027 - accuracy: 0.9991 - val_loss: 0.4949 - val_accuracy: 0.9187
# Epoch 101/200
# 25/25 [==============================] - ETA: 0s - loss: 3.5141e-04 - accuracy: 1.0000
# Epoch 00101: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 3.5141e-04 - accuracy: 1.0000 - val_loss: 0.1074 - val_accuracy: 0.9787
# Epoch 102/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9991
# Epoch 00102: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 0.2195 - val_accuracy: 0.9538
# Epoch 103/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9984
# Epoch 00103: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.1009 - val_accuracy: 0.9663
# Epoch 104/200
# 25/25 [==============================] - ETA: 0s - loss: 7.8193e-04 - accuracy: 0.9997
# Epoch 00104: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 7.8193e-04 - accuracy: 0.9997 - val_loss: 0.0611 - val_accuracy: 0.9825
# Epoch 105/200
# 25/25 [==============================] - ETA: 0s - loss: 6.4675e-05 - accuracy: 1.0000
# Epoch 00105: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 6.4675e-05 - accuracy: 1.0000 - val_loss: 0.0532 - val_accuracy: 0.9875
# Epoch 106/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 0.9975
# Epoch 00106: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0067 - accuracy: 0.9975 - val_loss: 0.0997 - val_accuracy: 0.9725
# Epoch 107/200
# 25/25 [==============================] - ETA: 0s - loss: 1.1343e-04 - accuracy: 1.0000
# Epoch 00107: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.1343e-04 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9862
# Epoch 108/200
# 25/25 [==============================] - ETA: 0s - loss: 5.2894e-05 - accuracy: 1.0000
# Epoch 00108: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 5.2894e-05 - accuracy: 1.0000 - val_loss: 0.0609 - val_accuracy: 0.9862
# Epoch 109/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9981
# Epoch 00109: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0074 - accuracy: 0.9981 - val_loss: 0.1174 - val_accuracy: 0.9750
# Epoch 110/200
# 25/25 [==============================] - ETA: 0s - loss: 1.3516e-04 - accuracy: 1.0000
# Epoch 00110: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.3516e-04 - accuracy: 1.0000 - val_loss: 0.0748 - val_accuracy: 0.9862
# Epoch 111/200
# 25/25 [==============================] - ETA: 0s - loss: 3.8073e-05 - accuracy: 1.0000
# Epoch 00111: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 3.8073e-05 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9837
# Epoch 112/200
# 25/25 [==============================] - ETA: 0s - loss: 2.1329e-05 - accuracy: 1.0000
# Epoch 00112: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 2.1329e-05 - accuracy: 1.0000 - val_loss: 0.0716 - val_accuracy: 0.9825
# Epoch 113/200
# 25/25 [==============================] - ETA: 0s - loss: 1.0675e-05 - accuracy: 1.0000
# Epoch 00113: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 1.0675e-05 - accuracy: 1.0000 - val_loss: 0.0627 - val_accuracy: 0.9862
# Epoch 114/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0104 - accuracy: 0.9984
# Epoch 00114: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0104 - accuracy: 0.9984 - val_loss: 0.0930 - val_accuracy: 0.9800
# Epoch 115/200
# 25/25 [==============================] - ETA: 0s - loss: 4.5870e-05 - accuracy: 1.0000
# Epoch 00115: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 4.5870e-05 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9862
# Epoch 116/200
# 25/25 [==============================] - ETA: 0s - loss: 1.8580e-05 - accuracy: 1.0000
# Epoch 00116: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.8580e-05 - accuracy: 1.0000 - val_loss: 0.0744 - val_accuracy: 0.9850
# Epoch 117/200
# 25/25 [==============================] - ETA: 0s - loss: 1.1984e-05 - accuracy: 1.0000
# Epoch 00117: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.1984e-05 - accuracy: 1.0000 - val_loss: 0.0674 - val_accuracy: 0.9862
# Epoch 118/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 0.9978
# Epoch 00118: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0080 - accuracy: 0.9978 - val_loss: 0.1750 - val_accuracy: 0.9563
# Epoch 119/200
# 25/25 [==============================] - ETA: 0s - loss: 2.3493e-04 - accuracy: 1.0000
# Epoch 00119: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.3493e-04 - accuracy: 1.0000 - val_loss: 0.0738 - val_accuracy: 0.9825
# Epoch 120/200
# 25/25 [==============================] - ETA: 0s - loss: 2.6494e-05 - accuracy: 1.0000
# Epoch 00120: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.6494e-05 - accuracy: 1.0000 - val_loss: 0.0582 - val_accuracy: 0.9875
# Epoch 121/200
# 25/25 [==============================] - ETA: 0s - loss: 1.6932e-05 - accuracy: 1.0000
# Epoch 00121: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.6932e-05 - accuracy: 1.0000 - val_loss: 0.0516 - val_accuracy: 0.9887
# Epoch 122/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9978
# Epoch 00122: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0178 - accuracy: 0.9978 - val_loss: 0.1079 - val_accuracy: 0.9712
# Epoch 123/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0022 - accuracy: 0.9994
# Epoch 00123: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.0648 - val_accuracy: 0.9812
# Epoch 124/200
# 25/25 [==============================] - ETA: 0s - loss: 3.7243e-05 - accuracy: 1.0000
# Epoch 00124: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 3.7243e-05 - accuracy: 1.0000 - val_loss: 0.0492 - val_accuracy: 0.9862
# Epoch 125/200
# 25/25 [==============================] - ETA: 0s - loss: 2.9711e-05 - accuracy: 1.0000
# Epoch 00125: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 2.9711e-05 - accuracy: 1.0000 - val_loss: 0.0495 - val_accuracy: 0.9850
# Epoch 126/200
# 25/25 [==============================] - ETA: 0s - loss: 1.0671e-05 - accuracy: 1.0000
# Epoch 00126: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.0671e-05 - accuracy: 1.0000 - val_loss: 0.0551 - val_accuracy: 0.9862
# Epoch 127/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9984
# Epoch 00127: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 0.0760 - val_accuracy: 0.9812
# Epoch 128/200
# 25/25 [==============================] - ETA: 0s - loss: 8.8529e-05 - accuracy: 1.0000
# Epoch 00128: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 8.8529e-05 - accuracy: 1.0000 - val_loss: 0.0910 - val_accuracy: 0.9787
# Epoch 129/200
# 25/25 [==============================] - ETA: 0s - loss: 8.1150e-05 - accuracy: 1.0000
# Epoch 00129: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 8.1150e-05 - accuracy: 1.0000 - val_loss: 0.0543 - val_accuracy: 0.9862
# Epoch 130/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0107 - accuracy: 0.9994
# Epoch 00130: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0107 - accuracy: 0.9994 - val_loss: 0.1144 - val_accuracy: 0.9663
# Epoch 131/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9994
# Epoch 00131: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0019 - accuracy: 0.9994 - val_loss: 0.0675 - val_accuracy: 0.9800
# Epoch 132/200
# 25/25 [==============================] - ETA: 0s - loss: 2.8439e-05 - accuracy: 1.0000
# Epoch 00132: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.8439e-05 - accuracy: 1.0000 - val_loss: 0.0574 - val_accuracy: 0.9850
# Epoch 133/200
# 25/25 [==============================] - ETA: 0s - loss: 1.5500e-05 - accuracy: 1.0000
# Epoch 00133: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.5500e-05 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 0.9850
# Epoch 134/200
# 25/25 [==============================] - ETA: 0s - loss: 8.9834e-06 - accuracy: 1.0000
# Epoch 00134: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 8.9834e-06 - accuracy: 1.0000 - val_loss: 0.0514 - val_accuracy: 0.9862
# Epoch 135/200
# 25/25 [==============================] - ETA: 0s - loss: 3.9567e-06 - accuracy: 1.0000
# Epoch 00135: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 3.9567e-06 - accuracy: 1.0000 - val_loss: 0.0594 - val_accuracy: 0.9862
# Epoch 136/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0021 - accuracy: 0.9991
# Epoch 00136: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0021 - accuracy: 0.9991 - val_loss: 0.2092 - val_accuracy: 0.9525
# Epoch 137/200
# 25/25 [==============================] - ETA: 0s - loss: 8.2999e-05 - accuracy: 1.0000
# Epoch 00137: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 8.2999e-05 - accuracy: 1.0000 - val_loss: 0.1030 - val_accuracy: 0.9762
# Epoch 138/200
# 25/25 [==============================] - ETA: 0s - loss: 3.4932e-05 - accuracy: 1.0000
# Epoch 00138: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 3.4932e-05 - accuracy: 1.0000 - val_loss: 0.0794 - val_accuracy: 0.9812
# Epoch 139/200
# 25/25 [==============================] - ETA: 0s - loss: 1.1453e-05 - accuracy: 1.0000
# Epoch 00139: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.1453e-05 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9850
# Epoch 140/200
# 25/25 [==============================] - ETA: 0s - loss: 5.1600e-06 - accuracy: 1.0000
# Epoch 00140: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 5.1600e-06 - accuracy: 1.0000 - val_loss: 0.0632 - val_accuracy: 0.9825
# Epoch 141/200
# 25/25 [==============================] - ETA: 0s - loss: 2.9005e-06 - accuracy: 1.0000
# Epoch 00141: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 2.9005e-06 - accuracy: 1.0000 - val_loss: 0.0662 - val_accuracy: 0.9850
# Epoch 142/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.9987
# Epoch 00142: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0027 - accuracy: 0.9987 - val_loss: 0.3192 - val_accuracy: 0.9375
# Epoch 143/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0045 - accuracy: 0.9991
# Epoch 00143: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.1064 - val_accuracy: 0.9762
# Epoch 144/200
# 25/25 [==============================] - ETA: 0s - loss: 4.1021e-05 - accuracy: 1.0000
# Epoch 00144: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 4.1021e-05 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9825
# Epoch 145/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0071 - accuracy: 0.9991
# Epoch 00145: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0071 - accuracy: 0.9991 - val_loss: 0.1077 - val_accuracy: 0.9750
# Epoch 146/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.9994
# Epoch 00146: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.0796 - val_accuracy: 0.9800
# Epoch 147/200
# 25/25 [==============================] - ETA: 0s - loss: 3.7573e-04 - accuracy: 0.9997
# Epoch 00147: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 3.7573e-04 - accuracy: 0.9997 - val_loss: 0.1037 - val_accuracy: 0.9762
# Epoch 148/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9987
# Epoch 00148: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0090 - accuracy: 0.9987 - val_loss: 0.0937 - val_accuracy: 0.9800
# Epoch 149/200
# 25/25 [==============================] - ETA: 0s - loss: 3.0683e-05 - accuracy: 1.0000
# Epoch 00149: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 3.0683e-05 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9837
# Epoch 150/200
# 25/25 [==============================] - ETA: 0s - loss: 1.6104e-05 - accuracy: 1.0000
# Epoch 00150: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 1.6104e-05 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9837
# Epoch 151/200
# 25/25 [==============================] - ETA: 0s - loss: 9.8189e-06 - accuracy: 1.0000
# Epoch 00151: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 200ms/step - loss: 9.8189e-06 - accuracy: 1.0000 - val_loss: 0.0688 - val_accuracy: 0.9862
# Epoch 152/200
# 25/25 [==============================] - ETA: 0s - loss: 1.0564e-05 - accuracy: 1.0000
# Epoch 00152: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 1.0564e-05 - accuracy: 1.0000 - val_loss: 0.8639 - val_accuracy: 0.8963
# Epoch 153/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9975
# Epoch 00153: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0160 - accuracy: 0.9975 - val_loss: 0.2078 - val_accuracy: 0.9563
# Epoch 154/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9997
# Epoch 00154: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0011 - accuracy: 0.9997 - val_loss: 0.1002 - val_accuracy: 0.9700
# Epoch 155/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 0.9987
# Epoch 00155: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0054 - accuracy: 0.9987 - val_loss: 0.0994 - val_accuracy: 0.9750
# Epoch 156/200
# 25/25 [==============================] - ETA: 0s - loss: 9.2863e-05 - accuracy: 1.0000
# Epoch 00156: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 9.2863e-05 - accuracy: 1.0000 - val_loss: 0.0781 - val_accuracy: 0.9825
# Epoch 157/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7851e-05 - accuracy: 1.0000
# Epoch 00157: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.7851e-05 - accuracy: 1.0000 - val_loss: 0.0730 - val_accuracy: 0.9837
# Epoch 158/200
# 25/25 [==============================] - ETA: 0s - loss: 1.1736e-05 - accuracy: 1.0000
# Epoch 00158: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.1736e-05 - accuracy: 1.0000 - val_loss: 0.0667 - val_accuracy: 0.9850
# Epoch 159/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0081 - accuracy: 0.9994
# Epoch 00159: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0081 - accuracy: 0.9994 - val_loss: 0.0720 - val_accuracy: 0.9787
# Epoch 160/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7266e-05 - accuracy: 1.0000
# Epoch 00160: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 2.7266e-05 - accuracy: 1.0000 - val_loss: 0.0657 - val_accuracy: 0.9825
# Epoch 161/200
# 25/25 [==============================] - ETA: 0s - loss: 1.9634e-05 - accuracy: 1.0000
# Epoch 00161: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 196ms/step - loss: 1.9634e-05 - accuracy: 1.0000 - val_loss: 0.0635 - val_accuracy: 0.9837
# Epoch 162/200
# 25/25 [==============================] - ETA: 0s - loss: 5.7809e-06 - accuracy: 1.0000
# Epoch 00162: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 5.7809e-06 - accuracy: 1.0000 - val_loss: 0.0629 - val_accuracy: 0.9862
# Epoch 163/200
# 25/25 [==============================] - ETA: 0s - loss: 3.1887e-06 - accuracy: 1.0000
# Epoch 00163: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 3.1887e-06 - accuracy: 1.0000 - val_loss: 0.0801 - val_accuracy: 0.9850
# Epoch 164/200
# 25/25 [==============================] - ETA: 0s - loss: 5.8258e-06 - accuracy: 1.0000
# Epoch 00164: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 5.8258e-06 - accuracy: 1.0000 - val_loss: 0.1026 - val_accuracy: 0.9812
# Epoch 165/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9987
# Epoch 00165: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.0887 - val_accuracy: 0.9775
# Epoch 166/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 0.9994
# Epoch 00166: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0051 - accuracy: 0.9994 - val_loss: 0.1178 - val_accuracy: 0.9675
# Epoch 167/200
# 25/25 [==============================] - ETA: 0s - loss: 2.8123e-05 - accuracy: 1.0000
# Epoch 00167: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 2.8123e-05 - accuracy: 1.0000 - val_loss: 0.0783 - val_accuracy: 0.9750
# Epoch 168/200
# 25/25 [==============================] - ETA: 0s - loss: 1.0326e-05 - accuracy: 1.0000
# Epoch 00168: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 1.0326e-05 - accuracy: 1.0000 - val_loss: 0.0664 - val_accuracy: 0.9825
# Epoch 169/200
# 25/25 [==============================] - ETA: 0s - loss: 4.6095e-06 - accuracy: 1.0000
# Epoch 00169: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 4.6095e-06 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9850
# Epoch 170/200
# 25/25 [==============================] - ETA: 0s - loss: 2.8912e-06 - accuracy: 1.0000
# Epoch 00170: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 2.8912e-06 - accuracy: 1.0000 - val_loss: 0.0571 - val_accuracy: 0.9875
# Epoch 171/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0017 - accuracy: 0.9997
# Epoch 00171: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0017 - accuracy: 0.9997 - val_loss: 0.0793 - val_accuracy: 0.9837
# Epoch 172/200
# 25/25 [==============================] - ETA: 0s - loss: 1.8879e-05 - accuracy: 1.0000
# Epoch 00172: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.8879e-05 - accuracy: 1.0000 - val_loss: 0.0696 - val_accuracy: 0.9837
# Epoch 173/200
# 25/25 [==============================] - ETA: 0s - loss: 4.5404e-06 - accuracy: 1.0000
# Epoch 00173: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 4.5404e-06 - accuracy: 1.0000 - val_loss: 0.0619 - val_accuracy: 0.9850
# Epoch 174/200
# 25/25 [==============================] - ETA: 0s - loss: 3.3713e-06 - accuracy: 1.0000
# Epoch 00174: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 3.3713e-06 - accuracy: 1.0000 - val_loss: 0.0525 - val_accuracy: 0.9862
# Epoch 175/200
# 25/25 [==============================] - ETA: 0s - loss: 3.4439e-06 - accuracy: 1.0000
# Epoch 00175: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 3.4439e-06 - accuracy: 1.0000 - val_loss: 0.1723 - val_accuracy: 0.9737
# Epoch 176/200
# 25/25 [==============================] - ETA: 0s - loss: 5.2222e-04 - accuracy: 0.9997
# Epoch 00176: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 5.2222e-04 - accuracy: 0.9997 - val_loss: 0.0790 - val_accuracy: 0.9825
# Epoch 177/200
# 25/25 [==============================] - ETA: 0s - loss: 8.1342e-06 - accuracy: 1.0000
# Epoch 00177: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 8.1342e-06 - accuracy: 1.0000 - val_loss: 0.0598 - val_accuracy: 0.9862
# Epoch 178/200
# 25/25 [==============================] - ETA: 0s - loss: 4.8610e-06 - accuracy: 1.0000
# Epoch 00178: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 200ms/step - loss: 4.8610e-06 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9862
# Epoch 179/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.9987
# Epoch 00179: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 199ms/step - loss: 0.0074 - accuracy: 0.9987 - val_loss: 0.1059 - val_accuracy: 0.9775
# Epoch 180/200
# 25/25 [==============================] - ETA: 0s - loss: 2.6168e-04 - accuracy: 1.0000
# Epoch 00180: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 197ms/step - loss: 2.6168e-04 - accuracy: 1.0000 - val_loss: 0.0717 - val_accuracy: 0.9862
# Epoch 181/200
# 25/25 [==============================] - ETA: 0s - loss: 1.7528e-05 - accuracy: 1.0000
# Epoch 00181: val_loss did not improve from 0.04688
# 25/25 [==============================] - 5s 198ms/step - loss: 1.7528e-05 - accuracy: 1.0000 - val_loss: 0.0493 - val_accuracy: 0.9875
# Epoch 182/200
# 25/25 [==============================] - ETA: 0s - loss: 6.3985e-06 - accuracy: 1.0000
# Epoch 00182: val_loss improved from 0.04688 to 0.04477, saving model to /content/drive/My Drive/models/20200521_2/xcep_conv_ks3_49/cp-182-0.0448.ckpt
# 25/25 [==============================] - 5s 200ms/step - loss: 6.3985e-06 - accuracy: 1.0000 - val_loss: 0.0448 - val_accuracy: 0.9900
# Epoch 183/200
# 25/25 [==============================] - ETA: 0s - loss: 3.0663e-06 - accuracy: 1.0000
# Epoch 00183: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 3.0663e-06 - accuracy: 1.0000 - val_loss: 0.0542 - val_accuracy: 0.9900
# Epoch 184/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7320e-06 - accuracy: 1.0000
# Epoch 00184: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 2.7320e-06 - accuracy: 1.0000 - val_loss: 0.0628 - val_accuracy: 0.9900
# Epoch 185/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9984
# Epoch 00185: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0109 - accuracy: 0.9984 - val_loss: 0.3740 - val_accuracy: 0.9362
# Epoch 186/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9994
# Epoch 00186: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 0.0011 - accuracy: 0.9994 - val_loss: 0.2675 - val_accuracy: 0.9463
# Epoch 187/200
# 25/25 [==============================] - ETA: 0s - loss: 2.3495e-04 - accuracy: 1.0000
# Epoch 00187: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 2.3495e-04 - accuracy: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9675
# Epoch 188/200
# 25/25 [==============================] - ETA: 0s - loss: 3.3485e-05 - accuracy: 1.0000
# Epoch 00188: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 199ms/step - loss: 3.3485e-05 - accuracy: 1.0000 - val_loss: 0.0669 - val_accuracy: 0.9850
# Epoch 189/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9978
# Epoch 00189: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0102 - accuracy: 0.9978 - val_loss: 0.0938 - val_accuracy: 0.9787
# Epoch 190/200
# 25/25 [==============================] - ETA: 0s - loss: 4.5933e-04 - accuracy: 1.0000
# Epoch 00190: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 4.5933e-04 - accuracy: 1.0000 - val_loss: 0.4461 - val_accuracy: 0.9550
# Epoch 191/200
# 25/25 [==============================] - ETA: 0s - loss: 0.0064 - accuracy: 0.9981
# Epoch 00191: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.0911 - val_accuracy: 0.9787
# Epoch 192/200
# 25/25 [==============================] - ETA: 0s - loss: 1.7874e-05 - accuracy: 1.0000
# Epoch 00192: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 1.7874e-05 - accuracy: 1.0000 - val_loss: 0.0756 - val_accuracy: 0.9837
# Epoch 193/200
# 25/25 [==============================] - ETA: 0s - loss: 1.3400e-05 - accuracy: 1.0000
# Epoch 00193: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 197ms/step - loss: 1.3400e-05 - accuracy: 1.0000 - val_loss: 0.0701 - val_accuracy: 0.9875
# Epoch 194/200
# 25/25 [==============================] - ETA: 0s - loss: 9.5458e-06 - accuracy: 1.0000
# Epoch 00194: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 9.5458e-06 - accuracy: 1.0000 - val_loss: 0.0654 - val_accuracy: 0.9850
# Epoch 195/200
# 25/25 [==============================] - ETA: 0s - loss: 4.8965e-06 - accuracy: 1.0000
# Epoch 00195: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 4.8965e-06 - accuracy: 1.0000 - val_loss: 0.0645 - val_accuracy: 0.9862
# Epoch 196/200
# 25/25 [==============================] - ETA: 0s - loss: 2.7090e-06 - accuracy: 1.0000
# Epoch 00196: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 2.7090e-06 - accuracy: 1.0000 - val_loss: 0.0875 - val_accuracy: 0.9800
# Epoch 197/200
# 25/25 [==============================] - ETA: 0s - loss: 1.7702e-06 - accuracy: 1.0000
# Epoch 00197: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 199ms/step - loss: 1.7702e-06 - accuracy: 1.0000 - val_loss: 0.0546 - val_accuracy: 0.9862
# Epoch 198/200
# 25/25 [==============================] - ETA: 0s - loss: 3.7614e-07 - accuracy: 1.0000
# Epoch 00198: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 3.7614e-07 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9875
# Epoch 199/200
# 25/25 [==============================] - ETA: 0s - loss: 2.6043e-07 - accuracy: 1.0000
# Epoch 00199: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 2.6043e-07 - accuracy: 1.0000 - val_loss: 0.0537 - val_accuracy: 0.9875
# Epoch 200/200
# 25/25 [==============================] - ETA: 0s - loss: 3.0502e-07 - accuracy: 1.0000
# Epoch 00200: val_loss did not improve from 0.04477
# 25/25 [==============================] - 5s 198ms/step - loss: 3.0502e-07 - accuracy: 1.0000 - val_loss: 0.0557 - val_accuracy: 0.9862
# [    end time] Thu May 21 04:57:56 2020
# [working time] 1032.62 (sec)

# %%
model_input = Input(shape = (data_length, 1))

new_models = [
        build_model_1(model_input, 0),
]

for i, model_name in enumerate(model_names):
    checkpoint_dir = "/content/drive/My Drive/models/{}/{}".format(notebookName, model_name)
    latest = tf.train.latest_checkpoint(checkpoint_dir)

    model = new_models[i]
    model.load_weights(latest)

    opt = optimizers.RMSprop(lr = 0.001)
    model.compile(optimizer = opt,
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # test_data
    test_data = np.load(save_test_data_name + ".npy")
    test_labels = np.load(save_test_labels_name + ".npy")

    test_data = test_data.reshape(len(test_data), data_length, 1)
    test_labels = to_categorical(test_labels)

    # standarization
    # test_data -= mean
    # test_data /= std 
    
    my_evaluate(model, test_data, test_labels, batch_size)
# Out:
# model name: xcep_conv_ks3_0
# 8/8 [==============================] - 1s 68ms/step - loss: 0.0480 - accuracy: 0.9910
# model name: xcep_conv_ks3_0, test loss: 0.047951266169548035, test_acc: 0.9909999966621399

# %%
import numpy as np
import os

previous = notebookName
num_models = 1

working_time = np.zeros((num_models))
histories = np.zeros((num_models, 4, epochs))

for i, model_name in enumerate(model_names):
    history = np.load(os.path.join("/content/drive/My Drive/results", previous, model_name, "{}.npz".format(model_name)))

    histories[i, 0] = history['accuracy']
    histories[i, 1] = history['val_accuracy']
    histories[i, 2] = history['loss']
    histories[i, 3] = history['val_loss']

    working_time[i] = history['working_time']

# %%
print(working_time.shape, histories.shape)
# Out:
# (1,) (1, 4, 200)

# %%
mn = ["original_ks3"]

for i in range(num_models):
    print("[{}] avg working time: {:.2f} sec".format(mn[i], working_time[i]))
# Out:
# [original_ks3] avg working time: 1032.62 sec

# %%
import pandas as pd

def smooth_curve(points):
    # df = pd.DataFrame(points, columns = list('A'))
    # # df['A'] = df['A'].rolling(5).mean()
    # df['B'] = df['A'].ewm(10).mean()
    # return df['B'].to_numpy()
    return points

# %%
import matplotlib.pyplot as plt

def plot_histories(histories):
    fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)
    c = ['r', 'g', 'b', 'm', 'k', 'c']
    # l = ["--", "-", ":", "-."]
    l = ["-"] * num_models

    plt.subplot(1, 2, 1)
    for i, history in enumerate(histories):
        acc = history[0]
        val_acc = history[1]
        plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - smooth_curve(val_acc), color = c[i], label = mn[i], linewidth = 1.5, linestyle = l[i])
        # plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - val_acc, alpha = .3, color = c[i], linewidth = .5, linestyle = l[i])
    plt.title('Validation Error')
    plt.xlabel('Epochs')
    plt.ylabel('Error Rate')
    plt.ylim([-0.03, 1.03])
    # plt.yscale('log')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.subplot(1, 2, 2)
    for i, history in enumerate(histories):
        loss = history[2]
        val_loss = history[3]
        plt.plot(np.arange(1, len(val_loss) + 1, 1), smooth_curve(val_loss), color = c[i], label = mn[i], linewidth = 1.5, linestyle = l[i])
        # plt.plot(np.arange(1, len(val_loss) + 1, 1), val_loss, alpha = .3, color = c[i], linewidth = .5, linestyle = l[i])
    plt.title('Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.tight_layout()
    plt.show()

# %%
plot_histories(histories)

# %%
test_labels = np.zeros((1000, 50))
num_labels = 50

# %%
preds = np.zeros((num_models, test_labels.shape[0], test_labels.shape[1])) # (3, 10, 1000, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    preds[i] = pred

# %%
test_errors = np.zeros((num_models))

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)
    
    test_errors[i] = np.sum(np.not_equal(np.argmax(pred, axis = 1), y)) / test_labels.shape[0]

# %%
test_errors

# %%
for i in range(num_models):
    print("[{}] avg test error: {:.4f}".format(mn[i], test_errors[i].mean()))

# %%
cmcs = np.zeros((num_models, 50)) # (3, 10, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)

    a = np.array([sorted(pred[j], reverse = True).index(pred[j, y[j]]) for j in range(len(y))]) # 정답의 순위    
    cmcs[i] = np.array([len(a[a<=j]) / 1000 for j in range(50)])

# %%
print(cmcs)

# %%
fig = plt.figure(figsize = (5, 4), facecolor = 'white', dpi = 300)

for i, model_cmc in enumerate(cmcs):
    c = ['r', 'g', 'b', 'm', 'k', 'c']
    # l = ["--", "-", ":", "-."]
    l = ["-"] * num_models

    plt.plot(np.arange(1, 21, 1), model_cmc[:20],
             color = c[i], label = mn[i], alpha = .7, linewidth = 1.5, linestyle = l[i])

plt.title('Cumulative Match Curve')
plt.xlabel('Rank (k)')
plt.ylabel('Rank-k Classification Rate')
plt.xticks([1, 5, 10, 20])
plt.legend()
plt.grid(True, linewidth = 0.4)

plt.tight_layout()
plt.show()

# %%
for i, cmc in enumerate(cmcs):
    print("[{}] top 1 error: {:.4f}, top 5 error: {:.4f}".format(mn[i], 1 - cmc[0], 1 - cmc[4]))

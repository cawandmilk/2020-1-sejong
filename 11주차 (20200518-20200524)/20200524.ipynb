# %% [markdown]
# # **주요 내용**
#
# *   seed 고정

# %%
notebookName = "20200524"
notebookName
# Out:
# '20200524'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15129735339105751858, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 6515638405678126687
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17274424426687224498
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3989130599258748275
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Sun May 24 10:45:42 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    32W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **unzip**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path): os.mkdir(pcm_path)
if not os.path.exists(wav_path): os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSF08333KJH0', 'GSM07355MIW0', 'I4F03423KSR0', 'GSM03224CHD0', 'GSF05134JHK0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 8

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 6561), train_labels.shape: (4000,)
# test_data.shape: (1000, 6561), test_labels.shape: (1000,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def my_split(train_data, train_labels):
    test_size = 0.2
    random_state = 1234

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size, random_state = random_state)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    # standarization
    mean = x_train.mean()
    x_train -= mean
    std = x_train.std()
    x_train /= std

    x_val -= mean
    x_val /= std

    return x_train, y_train, x_val, y_val, mean, std

# %% [markdown]
# **Build Model**

# %%
from tensorflow.keras import regularizers

def build_block(model_input, block_loop, filters_, kernel_size_, strides_):
    x = model_input
    for i in range(block_loop):
        x = layers.Conv1D(filters = filters_, kernel_size = kernel_size_, strides = strides_,
                          kernel_regularizer = regularizers.l2(1e-4),
                          padding = 'same')(x)
        x = layers.ReLU()(x)
        
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling1D(pool_size = 3)(x)

    return x

# %%
def build_model_1(model_input):

    x = build_block(model_input, 1, 32, 5, 1)
    x = build_block(x, 1, 64, 5, 1)
    x = build_block(x, 1, 128, 5, 1)
    x = build_block(x, 1, 256, 5, 1)

    # out
    x = layers.GlobalAveragePooling1D()(x)
    out = layers.Dense(num_labels, activation = 'softmax')(x)

    model = Model(model_input, out, name = "original")
    print("model name: {}".format(model.name))
    
    return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

# %%
model_1 = build_model_1(model_input)
model_1.summary()
# Out:
# model name: original
# Model: "original"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_45 (InputLayer)        [(None, 6561, 1)]         0
# _________________________________________________________________
# conv1d_176 (Conv1D)          (None, 6561, 32)          192
# _________________________________________________________________
# re_lu_176 (ReLU)             (None, 6561, 32)          0
# _________________________________________________________________
# batch_normalization_176 (Bat (None, 6561, 32)          128
# _________________________________________________________________
# max_pooling1d_176 (MaxPoolin (None, 2187, 32)          0
# _________________________________________________________________
# conv1d_177 (Conv1D)          (None, 2187, 64)          10304
# _________________________________________________________________
# re_lu_177 (ReLU)             (None, 2187, 64)          0
# _________________________________________________________________
# batch_normalization_177 (Bat (None, 2187, 64)          256
# _________________________________________________________________
# max_pooling1d_177 (MaxPoolin (None, 729, 64)           0
# _________________________________________________________________
# conv1d_178 (Conv1D)          (None, 729, 128)          41088
# _________________________________________________________________
# re_lu_178 (ReLU)             (None, 729, 128)          0
# _________________________________________________________________
# batch_normalization_178 (Bat (None, 729, 128)          512
# _________________________________________________________________
# max_pooling1d_178 (MaxPoolin (None, 243, 128)          0
# _________________________________________________________________
# conv1d_179 (Conv1D)          (None, 243, 256)          164096
# _________________________________________________________________
# re_lu_179 (ReLU)             (None, 243, 256)          0
# _________________________________________________________________
# batch_normalization_179 (Bat (None, 243, 256)          1024
# _________________________________________________________________
# max_pooling1d_179 (MaxPoolin (None, 81, 256)           0
# _________________________________________________________________
# global_average_pooling1d_44  (None, 256)               0
# _________________________________________________________________
# dense_44 (Dense)             (None, 50)                12850
# =================================================================
# Total params: 230,450
# Trainable params: 229,490
# Non-trainable params: 960
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes = True, to_file = 'model_1.png')

# %% [markdown]
# **Train model**

# %%
from tensorflow.keras import optimizers
from tensorflow.keras import callbacks
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    opt = optimizers.RMSprop(lr = 0.001)
    model.compile(optimizer = opt,
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # save model & results
    save_model_path = os.path.join("/content/drive/My Drive/models", notebookName)
    save_results_path = os.path.join("/content/drive/My Drive/results", notebookName)

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    save_model_path = os.path.join(save_model_path, model.name)
    save_results_path = os.path.join(save_results_path, model.name)

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    # callback
    def scheduler(epoch, lr):
        return 0.3 * lr if not (epoch+1) % 50 else lr

    lrs = tf.keras.callbacks.LearningRateScheduler(scheduler)
    # reduce_lr = callbacks.ReduceLROnPlateau(monitor='val_loss', factor = 0.94, patience = 5)
    # checkpoint = callbacks.ModelCheckpoint(filepath = os.path.join(save_model_path, "cp-{epoch:03d}-{val_loss:.4f}.ckpt"),
    #                                        monitor = 'val_loss', verbose = 1, save_best_only = True, save_weights_only = True)
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 1,
                        callbacks = [lrs])
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save
    # model.save(os.path.join(save_model_path, model.name) + ".h5")
    np.savez_compressed(os.path.join(save_results_path, model.name),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'],
                        working_time = np.array([end - start]))

# %%
def my_evaluate(model, test_data, test_labels, batch_size):
    loss, acc = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print("model name: {}, test loss: {}, test_acc: {}".format(model.name, loss, acc))

    save_eval_path = os.path.join("/content/drive/My Drive/evals", notebookName)
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    save_eval_path = os.path.join(save_eval_path, model.name)
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    pred = model.predict(test_data) # (1000, 50)
    np.save(os.path.join(save_eval_path,  model.name), pred)

# %% [markdown]
# **test**

# %%
epochs = 200
batch_size = 128
num_models = 1

# train test split
x_train, y_train, x_val, y_val, mean, std = my_split(train_data, train_labels)

# build & compile & train model
model_input = Input(shape = (data_length, 1))
models = [
          build_model_1(model_input)
          ]

for model in models:
    compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs)

model_names = [model.name for model in models]

# test_data
test_data = np.load(save_test_data_name + ".npy")
test_labels = np.load(save_test_labels_name + ".npy")

test_data = test_data.reshape(len(test_data), data_length, 1)
test_labels = to_categorical(test_labels)

# standarization
test_data -= mean
test_data /= std 

for model in models:
    my_evaluate(model, test_data, test_labels, batch_size)
# Out:
# model name: original
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 24 16:06:27 2020
# Epoch 1/200
# 25/25 [==============================] - 2s 63ms/step - loss: 2.7609 - accuracy: 0.3034 - val_loss: 3.8324 - val_accuracy: 0.0763 - lr: 0.0010
# Epoch 2/200
# 25/25 [==============================] - 1s 54ms/step - loss: 1.5997 - accuracy: 0.5884 - val_loss: 3.8397 - val_accuracy: 0.0512 - lr: 0.0010
# Epoch 3/200
# 25/25 [==============================] - 1s 53ms/step - loss: 1.1945 - accuracy: 0.7134 - val_loss: 3.9655 - val_accuracy: 0.0475 - lr: 0.0010
# Epoch 4/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.9675 - accuracy: 0.7684 - val_loss: 4.1061 - val_accuracy: 0.0725 - lr: 0.0010
# Epoch 5/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.8136 - accuracy: 0.8125 - val_loss: 4.2680 - val_accuracy: 0.0550 - lr: 0.0010
# Epoch 6/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.7036 - accuracy: 0.8425 - val_loss: 4.4730 - val_accuracy: 0.0562 - lr: 0.0010
# Epoch 7/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.6141 - accuracy: 0.8650 - val_loss: 4.7755 - val_accuracy: 0.0463 - lr: 0.0010
# Epoch 8/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.5378 - accuracy: 0.8822 - val_loss: 4.5536 - val_accuracy: 0.0600 - lr: 0.0010
# Epoch 9/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.4748 - accuracy: 0.9047 - val_loss: 4.9660 - val_accuracy: 0.0637 - lr: 0.0010
# Epoch 10/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.4362 - accuracy: 0.9116 - val_loss: 4.7671 - val_accuracy: 0.0725 - lr: 0.0010
# Epoch 11/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.3916 - accuracy: 0.9212 - val_loss: 4.5529 - val_accuracy: 0.0838 - lr: 0.0010
# Epoch 12/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.3544 - accuracy: 0.9306 - val_loss: 3.4100 - val_accuracy: 0.1775 - lr: 0.0010
# Epoch 13/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.3260 - accuracy: 0.9381 - val_loss: 2.7993 - val_accuracy: 0.3038 - lr: 0.0010
# Epoch 14/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.2921 - accuracy: 0.9484 - val_loss: 2.7871 - val_accuracy: 0.2975 - lr: 0.0010
# Epoch 15/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.2907 - accuracy: 0.9481 - val_loss: 2.9354 - val_accuracy: 0.2962 - lr: 0.0010
# Epoch 16/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2713 - accuracy: 0.9531 - val_loss: 2.5016 - val_accuracy: 0.3688 - lr: 0.0010
# Epoch 17/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.2296 - accuracy: 0.9638 - val_loss: 1.9782 - val_accuracy: 0.4525 - lr: 0.0010
# Epoch 18/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2302 - accuracy: 0.9616 - val_loss: 1.6575 - val_accuracy: 0.5700 - lr: 0.0010
# Epoch 19/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2213 - accuracy: 0.9650 - val_loss: 1.2732 - val_accuracy: 0.6488 - lr: 0.0010
# Epoch 20/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.2033 - accuracy: 0.9672 - val_loss: 1.4019 - val_accuracy: 0.6062 - lr: 0.0010
# Epoch 21/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1855 - accuracy: 0.9712 - val_loss: 1.3591 - val_accuracy: 0.6525 - lr: 0.0010
# Epoch 22/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1875 - accuracy: 0.9700 - val_loss: 1.3590 - val_accuracy: 0.6913 - lr: 0.0010
# Epoch 23/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1840 - accuracy: 0.9694 - val_loss: 1.2422 - val_accuracy: 0.6637 - lr: 0.0010
# Epoch 24/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1753 - accuracy: 0.9706 - val_loss: 1.6049 - val_accuracy: 0.6950 - lr: 0.0010
# Epoch 25/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1674 - accuracy: 0.9722 - val_loss: 0.9280 - val_accuracy: 0.7563 - lr: 0.0010
# Epoch 26/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1724 - accuracy: 0.9719 - val_loss: 1.1957 - val_accuracy: 0.7075 - lr: 0.0010
# Epoch 27/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1439 - accuracy: 0.9762 - val_loss: 2.5552 - val_accuracy: 0.6375 - lr: 0.0010
# Epoch 28/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1463 - accuracy: 0.9772 - val_loss: 1.0002 - val_accuracy: 0.7638 - lr: 0.0010
# Epoch 29/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1590 - accuracy: 0.9725 - val_loss: 0.5118 - val_accuracy: 0.8475 - lr: 0.0010
# Epoch 30/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1326 - accuracy: 0.9784 - val_loss: 0.7989 - val_accuracy: 0.8050 - lr: 0.0010
# Epoch 31/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1312 - accuracy: 0.9797 - val_loss: 1.5079 - val_accuracy: 0.7050 - lr: 0.0010
# Epoch 32/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1388 - accuracy: 0.9787 - val_loss: 1.0474 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 33/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1250 - accuracy: 0.9781 - val_loss: 0.5562 - val_accuracy: 0.8425 - lr: 0.0010
# Epoch 34/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1321 - accuracy: 0.9800 - val_loss: 2.0222 - val_accuracy: 0.6363 - lr: 0.0010
# Epoch 35/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1269 - accuracy: 0.9809 - val_loss: 0.7266 - val_accuracy: 0.8037 - lr: 0.0010
# Epoch 36/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1296 - accuracy: 0.9806 - val_loss: 0.7108 - val_accuracy: 0.8125 - lr: 0.0010
# Epoch 37/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1049 - accuracy: 0.9847 - val_loss: 0.8470 - val_accuracy: 0.7812 - lr: 0.0010
# Epoch 38/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1264 - accuracy: 0.9784 - val_loss: 0.8975 - val_accuracy: 0.7750 - lr: 0.0010
# Epoch 39/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1017 - accuracy: 0.9837 - val_loss: 0.7544 - val_accuracy: 0.8225 - lr: 0.0010
# Epoch 40/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1209 - accuracy: 0.9809 - val_loss: 0.6313 - val_accuracy: 0.8400 - lr: 0.0010
# Epoch 41/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1069 - accuracy: 0.9828 - val_loss: 0.8347 - val_accuracy: 0.7825 - lr: 0.0010
# Epoch 42/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1052 - accuracy: 0.9831 - val_loss: 0.5869 - val_accuracy: 0.8587 - lr: 0.0010
# Epoch 43/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1123 - accuracy: 0.9819 - val_loss: 0.5867 - val_accuracy: 0.8438 - lr: 0.0010
# Epoch 44/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0923 - accuracy: 0.9872 - val_loss: 0.6253 - val_accuracy: 0.8325 - lr: 0.0010
# Epoch 45/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.1204 - accuracy: 0.9809 - val_loss: 0.7049 - val_accuracy: 0.8338 - lr: 0.0010
# Epoch 46/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0931 - accuracy: 0.9859 - val_loss: 0.6572 - val_accuracy: 0.8225 - lr: 0.0010
# Epoch 47/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0993 - accuracy: 0.9862 - val_loss: 0.5457 - val_accuracy: 0.8550 - lr: 0.0010
# Epoch 48/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0988 - accuracy: 0.9844 - val_loss: 0.6480 - val_accuracy: 0.8163 - lr: 0.0010
# Epoch 49/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.1169 - accuracy: 0.9812 - val_loss: 0.6958 - val_accuracy: 0.8450 - lr: 0.0010
# Epoch 50/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0747 - accuracy: 0.9906 - val_loss: 0.4639 - val_accuracy: 0.8800 - lr: 3.0000e-04
# Epoch 51/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0730 - accuracy: 0.9897 - val_loss: 0.4181 - val_accuracy: 0.8900 - lr: 3.0000e-04
# Epoch 52/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0709 - accuracy: 0.9894 - val_loss: 0.4122 - val_accuracy: 0.8988 - lr: 3.0000e-04
# Epoch 53/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0709 - accuracy: 0.9903 - val_loss: 0.4115 - val_accuracy: 0.8863 - lr: 3.0000e-04
# Epoch 54/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0676 - accuracy: 0.9903 - val_loss: 0.4118 - val_accuracy: 0.8875 - lr: 3.0000e-04
# Epoch 55/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0668 - accuracy: 0.9903 - val_loss: 0.3979 - val_accuracy: 0.8988 - lr: 3.0000e-04
# Epoch 56/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0639 - accuracy: 0.9922 - val_loss: 0.4567 - val_accuracy: 0.8763 - lr: 3.0000e-04
# Epoch 57/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0656 - accuracy: 0.9934 - val_loss: 0.4193 - val_accuracy: 0.8863 - lr: 3.0000e-04
# Epoch 58/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0622 - accuracy: 0.9922 - val_loss: 0.4283 - val_accuracy: 0.8863 - lr: 3.0000e-04
# Epoch 59/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0623 - accuracy: 0.9922 - val_loss: 0.3710 - val_accuracy: 0.9100 - lr: 3.0000e-04
# Epoch 60/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0577 - accuracy: 0.9944 - val_loss: 0.4822 - val_accuracy: 0.8850 - lr: 3.0000e-04
# Epoch 61/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0604 - accuracy: 0.9925 - val_loss: 0.5275 - val_accuracy: 0.8725 - lr: 3.0000e-04
# Epoch 62/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0580 - accuracy: 0.9934 - val_loss: 0.3632 - val_accuracy: 0.9050 - lr: 3.0000e-04
# Epoch 63/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0599 - accuracy: 0.9916 - val_loss: 0.3910 - val_accuracy: 0.9025 - lr: 3.0000e-04
# Epoch 64/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0555 - accuracy: 0.9931 - val_loss: 0.4022 - val_accuracy: 0.8963 - lr: 3.0000e-04
# Epoch 65/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0553 - accuracy: 0.9931 - val_loss: 0.4177 - val_accuracy: 0.8913 - lr: 3.0000e-04
# Epoch 66/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0524 - accuracy: 0.9941 - val_loss: 0.4516 - val_accuracy: 0.8813 - lr: 3.0000e-04
# Epoch 67/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0530 - accuracy: 0.9937 - val_loss: 0.4124 - val_accuracy: 0.8950 - lr: 3.0000e-04
# Epoch 68/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0534 - accuracy: 0.9937 - val_loss: 0.4902 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 69/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0518 - accuracy: 0.9941 - val_loss: 0.4575 - val_accuracy: 0.8875 - lr: 3.0000e-04
# Epoch 70/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0511 - accuracy: 0.9937 - val_loss: 0.5197 - val_accuracy: 0.8875 - lr: 3.0000e-04
# Epoch 71/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0493 - accuracy: 0.9950 - val_loss: 0.3791 - val_accuracy: 0.9087 - lr: 3.0000e-04
# Epoch 72/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0498 - accuracy: 0.9944 - val_loss: 0.6073 - val_accuracy: 0.8737 - lr: 3.0000e-04
# Epoch 73/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0499 - accuracy: 0.9941 - val_loss: 0.5299 - val_accuracy: 0.8775 - lr: 3.0000e-04
# Epoch 74/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0493 - accuracy: 0.9947 - val_loss: 0.4837 - val_accuracy: 0.8800 - lr: 3.0000e-04
# Epoch 75/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0483 - accuracy: 0.9941 - val_loss: 0.4332 - val_accuracy: 0.8888 - lr: 3.0000e-04
# Epoch 76/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0475 - accuracy: 0.9934 - val_loss: 0.5125 - val_accuracy: 0.8913 - lr: 3.0000e-04
# Epoch 77/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0468 - accuracy: 0.9947 - val_loss: 0.4498 - val_accuracy: 0.8863 - lr: 3.0000e-04
# Epoch 78/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0461 - accuracy: 0.9947 - val_loss: 0.4064 - val_accuracy: 0.8825 - lr: 3.0000e-04
# Epoch 79/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0451 - accuracy: 0.9950 - val_loss: 0.5559 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 80/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0490 - accuracy: 0.9941 - val_loss: 0.4234 - val_accuracy: 0.8913 - lr: 3.0000e-04
# Epoch 81/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0455 - accuracy: 0.9941 - val_loss: 0.5271 - val_accuracy: 0.8687 - lr: 3.0000e-04
# Epoch 82/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0451 - accuracy: 0.9934 - val_loss: 0.5330 - val_accuracy: 0.8725 - lr: 3.0000e-04
# Epoch 83/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0439 - accuracy: 0.9950 - val_loss: 0.3779 - val_accuracy: 0.9038 - lr: 3.0000e-04
# Epoch 84/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0447 - accuracy: 0.9934 - val_loss: 0.4450 - val_accuracy: 0.8750 - lr: 3.0000e-04
# Epoch 85/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0441 - accuracy: 0.9959 - val_loss: 0.5201 - val_accuracy: 0.8600 - lr: 3.0000e-04
# Epoch 86/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0432 - accuracy: 0.9956 - val_loss: 0.7143 - val_accuracy: 0.8275 - lr: 3.0000e-04
# Epoch 87/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0431 - accuracy: 0.9953 - val_loss: 0.5161 - val_accuracy: 0.8712 - lr: 3.0000e-04
# Epoch 88/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0420 - accuracy: 0.9944 - val_loss: 0.4853 - val_accuracy: 0.8800 - lr: 3.0000e-04
# Epoch 89/200
# 25/25 [==============================] - 1s 55ms/step - loss: 0.0402 - accuracy: 0.9956 - val_loss: 0.5919 - val_accuracy: 0.8587 - lr: 3.0000e-04
# Epoch 90/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0394 - accuracy: 0.9956 - val_loss: 0.9931 - val_accuracy: 0.8275 - lr: 3.0000e-04
# Epoch 91/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0401 - accuracy: 0.9944 - val_loss: 0.4338 - val_accuracy: 0.8863 - lr: 3.0000e-04
# Epoch 92/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0392 - accuracy: 0.9956 - val_loss: 0.4654 - val_accuracy: 0.8875 - lr: 3.0000e-04
# Epoch 93/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0402 - accuracy: 0.9959 - val_loss: 0.3758 - val_accuracy: 0.9000 - lr: 3.0000e-04
# Epoch 94/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0420 - accuracy: 0.9947 - val_loss: 0.3792 - val_accuracy: 0.9050 - lr: 3.0000e-04
# Epoch 95/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0378 - accuracy: 0.9956 - val_loss: 0.3986 - val_accuracy: 0.9013 - lr: 3.0000e-04
# Epoch 96/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0372 - accuracy: 0.9953 - val_loss: 0.3567 - val_accuracy: 0.9050 - lr: 3.0000e-04
# Epoch 97/200
# 25/25 [==============================] - 1s 55ms/step - loss: 0.0375 - accuracy: 0.9953 - val_loss: 0.5681 - val_accuracy: 0.8775 - lr: 3.0000e-04
# Epoch 98/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0353 - accuracy: 0.9966 - val_loss: 0.4726 - val_accuracy: 0.8737 - lr: 3.0000e-04
# Epoch 99/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0345 - accuracy: 0.9966 - val_loss: 0.5787 - val_accuracy: 0.8575 - lr: 3.0000e-04
# Epoch 100/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0342 - accuracy: 0.9969 - val_loss: 0.3569 - val_accuracy: 0.9050 - lr: 9.0000e-05
# Epoch 101/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0309 - accuracy: 0.9984 - val_loss: 0.3912 - val_accuracy: 0.9038 - lr: 9.0000e-05
# Epoch 102/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0303 - accuracy: 0.9975 - val_loss: 0.4129 - val_accuracy: 0.9013 - lr: 9.0000e-05
# Epoch 103/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0298 - accuracy: 0.9984 - val_loss: 0.3637 - val_accuracy: 0.9100 - lr: 9.0000e-05
# Epoch 104/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0292 - accuracy: 0.9981 - val_loss: 0.3697 - val_accuracy: 0.9087 - lr: 9.0000e-05
# Epoch 105/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0291 - accuracy: 0.9978 - val_loss: 0.3385 - val_accuracy: 0.9050 - lr: 9.0000e-05
# Epoch 106/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0283 - accuracy: 0.9981 - val_loss: 0.3822 - val_accuracy: 0.9013 - lr: 9.0000e-05
# Epoch 107/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0286 - accuracy: 0.9978 - val_loss: 0.3891 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 108/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0291 - accuracy: 0.9981 - val_loss: 0.3333 - val_accuracy: 0.9150 - lr: 9.0000e-05
# Epoch 109/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0282 - accuracy: 0.9978 - val_loss: 0.3456 - val_accuracy: 0.9025 - lr: 9.0000e-05
# Epoch 110/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0280 - accuracy: 0.9984 - val_loss: 0.3849 - val_accuracy: 0.9050 - lr: 9.0000e-05
# Epoch 111/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0274 - accuracy: 0.9987 - val_loss: 0.3609 - val_accuracy: 0.9112 - lr: 9.0000e-05
# Epoch 112/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0279 - accuracy: 0.9987 - val_loss: 0.3409 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 113/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0281 - accuracy: 0.9981 - val_loss: 0.3440 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 114/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0269 - accuracy: 0.9984 - val_loss: 0.3612 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 115/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0269 - accuracy: 0.9984 - val_loss: 0.3334 - val_accuracy: 0.9187 - lr: 9.0000e-05
# Epoch 116/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0266 - accuracy: 0.9984 - val_loss: 0.4233 - val_accuracy: 0.8938 - lr: 9.0000e-05
# Epoch 117/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0264 - accuracy: 0.9984 - val_loss: 0.3466 - val_accuracy: 0.9038 - lr: 9.0000e-05
# Epoch 118/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0260 - accuracy: 0.9994 - val_loss: 0.3610 - val_accuracy: 0.9100 - lr: 9.0000e-05
# Epoch 119/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0261 - accuracy: 0.9991 - val_loss: 0.3822 - val_accuracy: 0.9000 - lr: 9.0000e-05
# Epoch 120/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0257 - accuracy: 0.9984 - val_loss: 0.3229 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 121/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0249 - accuracy: 0.9994 - val_loss: 0.3289 - val_accuracy: 0.9100 - lr: 9.0000e-05
# Epoch 122/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0257 - accuracy: 0.9984 - val_loss: 0.4363 - val_accuracy: 0.9062 - lr: 9.0000e-05
# Epoch 123/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0260 - accuracy: 0.9984 - val_loss: 0.4725 - val_accuracy: 0.9025 - lr: 9.0000e-05
# Epoch 124/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0258 - accuracy: 0.9981 - val_loss: 0.3804 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 125/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0246 - accuracy: 0.9991 - val_loss: 0.3595 - val_accuracy: 0.9137 - lr: 9.0000e-05
# Epoch 126/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0239 - accuracy: 0.9997 - val_loss: 0.3786 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 127/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0272 - accuracy: 0.9978 - val_loss: 0.3286 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 128/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0252 - accuracy: 0.9987 - val_loss: 0.3428 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 129/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0257 - accuracy: 0.9981 - val_loss: 0.3525 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 130/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0238 - accuracy: 0.9991 - val_loss: 0.3357 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 131/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0242 - accuracy: 0.9987 - val_loss: 0.3156 - val_accuracy: 0.9150 - lr: 9.0000e-05
# Epoch 132/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0234 - accuracy: 0.9994 - val_loss: 0.3709 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 133/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0237 - accuracy: 0.9991 - val_loss: 0.3273 - val_accuracy: 0.9150 - lr: 9.0000e-05
# Epoch 134/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0244 - accuracy: 0.9987 - val_loss: 0.3226 - val_accuracy: 0.9187 - lr: 9.0000e-05
# Epoch 135/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0241 - accuracy: 0.9984 - val_loss: 0.3299 - val_accuracy: 0.9162 - lr: 9.0000e-05
# Epoch 136/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0234 - accuracy: 0.9997 - val_loss: 0.3303 - val_accuracy: 0.9150 - lr: 9.0000e-05
# Epoch 137/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0240 - accuracy: 0.9991 - val_loss: 0.3622 - val_accuracy: 0.9062 - lr: 9.0000e-05
# Epoch 138/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0235 - accuracy: 0.9994 - val_loss: 0.3733 - val_accuracy: 0.9000 - lr: 9.0000e-05
# Epoch 139/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0242 - accuracy: 0.9984 - val_loss: 0.3327 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 140/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0236 - accuracy: 0.9991 - val_loss: 0.3428 - val_accuracy: 0.9062 - lr: 9.0000e-05
# Epoch 141/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0232 - accuracy: 0.9991 - val_loss: 0.3387 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 142/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0228 - accuracy: 0.9987 - val_loss: 0.3647 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 143/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0228 - accuracy: 0.9997 - val_loss: 0.3922 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 144/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0221 - accuracy: 0.9994 - val_loss: 0.3383 - val_accuracy: 0.9150 - lr: 9.0000e-05
# Epoch 145/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0223 - accuracy: 0.9994 - val_loss: 0.5107 - val_accuracy: 0.8950 - lr: 9.0000e-05
# Epoch 146/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0231 - accuracy: 0.9981 - val_loss: 0.3517 - val_accuracy: 0.9075 - lr: 9.0000e-05
# Epoch 147/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0212 - accuracy: 0.9997 - val_loss: 0.3454 - val_accuracy: 0.9125 - lr: 9.0000e-05
# Epoch 148/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0217 - accuracy: 0.9997 - val_loss: 0.3506 - val_accuracy: 0.9100 - lr: 9.0000e-05
# Epoch 149/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0222 - accuracy: 0.9987 - val_loss: 0.3204 - val_accuracy: 0.9187 - lr: 9.0000e-05
# Epoch 150/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0204 - accuracy: 0.9997 - val_loss: 0.3091 - val_accuracy: 0.9150 - lr: 2.7000e-05
# Epoch 151/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0205 - accuracy: 1.0000 - val_loss: 0.3037 - val_accuracy: 0.9200 - lr: 2.7000e-05
# Epoch 152/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0208 - accuracy: 0.9997 - val_loss: 0.3160 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 153/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0204 - accuracy: 0.9997 - val_loss: 0.3093 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 154/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0211 - accuracy: 0.9997 - val_loss: 0.3037 - val_accuracy: 0.9250 - lr: 2.7000e-05
# Epoch 155/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0209 - accuracy: 0.9997 - val_loss: 0.3190 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 156/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.3176 - val_accuracy: 0.9150 - lr: 2.7000e-05
# Epoch 157/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0199 - accuracy: 1.0000 - val_loss: 0.3055 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 158/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0209 - accuracy: 0.9997 - val_loss: 0.3033 - val_accuracy: 0.9200 - lr: 2.7000e-05
# Epoch 159/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0199 - accuracy: 0.9997 - val_loss: 0.2997 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 160/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0200 - accuracy: 0.9997 - val_loss: 0.2981 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 161/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0201 - accuracy: 1.0000 - val_loss: 0.3001 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 162/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0202 - accuracy: 0.9994 - val_loss: 0.3005 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 163/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.2944 - val_accuracy: 0.9250 - lr: 2.7000e-05
# Epoch 164/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0198 - accuracy: 0.9997 - val_loss: 0.3009 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 165/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0202 - accuracy: 1.0000 - val_loss: 0.3138 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 166/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0201 - accuracy: 0.9997 - val_loss: 0.2928 - val_accuracy: 0.9275 - lr: 2.7000e-05
# Epoch 167/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0200 - accuracy: 1.0000 - val_loss: 0.3007 - val_accuracy: 0.9162 - lr: 2.7000e-05
# Epoch 168/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0195 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 169/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3107 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 170/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0200 - accuracy: 0.9997 - val_loss: 0.3266 - val_accuracy: 0.9125 - lr: 2.7000e-05
# Epoch 171/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.2976 - val_accuracy: 0.9237 - lr: 2.7000e-05
# Epoch 172/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0193 - accuracy: 1.0000 - val_loss: 0.3102 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 173/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.3050 - val_accuracy: 0.9200 - lr: 2.7000e-05
# Epoch 174/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0194 - accuracy: 0.9997 - val_loss: 0.3017 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 175/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0197 - accuracy: 0.9997 - val_loss: 0.2962 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 176/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0192 - accuracy: 1.0000 - val_loss: 0.3159 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 177/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.2999 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 178/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0191 - accuracy: 1.0000 - val_loss: 0.2986 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 179/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.3078 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 180/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 181/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0190 - accuracy: 1.0000 - val_loss: 0.2896 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 182/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0195 - accuracy: 0.9994 - val_loss: 0.3037 - val_accuracy: 0.9162 - lr: 2.7000e-05
# Epoch 183/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0189 - accuracy: 1.0000 - val_loss: 0.2975 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 184/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0189 - accuracy: 0.9997 - val_loss: 0.3008 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 185/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.3005 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 186/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0198 - accuracy: 1.0000 - val_loss: 0.3072 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 187/200
# 25/25 [==============================] - 1s 54ms/step - loss: 0.0188 - accuracy: 0.9997 - val_loss: 0.2967 - val_accuracy: 0.9212 - lr: 2.7000e-05
# Epoch 188/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0193 - accuracy: 0.9997 - val_loss: 0.2941 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 189/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0185 - accuracy: 1.0000 - val_loss: 0.2973 - val_accuracy: 0.9250 - lr: 2.7000e-05
# Epoch 190/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0192 - accuracy: 0.9997 - val_loss: 0.2920 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 191/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2861 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 192/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2959 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 193/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0187 - accuracy: 1.0000 - val_loss: 0.3000 - val_accuracy: 0.9225 - lr: 2.7000e-05
# Epoch 194/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0187 - accuracy: 0.9997 - val_loss: 0.3139 - val_accuracy: 0.9200 - lr: 2.7000e-05
# Epoch 195/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0182 - accuracy: 1.0000 - val_loss: 0.2968 - val_accuracy: 0.9200 - lr: 2.7000e-05
# Epoch 196/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0190 - accuracy: 0.9997 - val_loss: 0.3006 - val_accuracy: 0.9175 - lr: 2.7000e-05
# Epoch 197/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0186 - accuracy: 1.0000 - val_loss: 0.2936 - val_accuracy: 0.9187 - lr: 2.7000e-05
# Epoch 198/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.3039 - val_accuracy: 0.9162 - lr: 2.7000e-05
# Epoch 199/200
# 25/25 [==============================] - 1s 53ms/step - loss: 0.0188 - accuracy: 1.0000 - val_loss: 0.2910 - val_accuracy: 0.9237 - lr: 2.7000e-05
# Epoch 200/200
# 25/25 [==============================] - 1s 52ms/step - loss: 0.0181 - accuracy: 1.0000 - val_loss: 0.2942 - val_accuracy: 0.9225 - lr: 8.1000e-06
# [    end time] Sun May 24 16:11:04 2020
# [working time] 276.12 (sec)
# 8/8 [==============================] - 0s 13ms/step - loss: 0.2237 - accuracy: 0.9390
# model name: original, test loss: 0.22371384501457214, test_acc: 0.9390000104904175

# %%
# model_input = Input(shape = (data_length, 1))

# new_models = [
#               build_model_1(model_input),
#               build_model_2(model_input),
#               build_model_3(model_input)
#               ]

# for i, model_name in enumerate(model_names):
#     checkpoint_dir = "/content/drive/My Drive/models/{}/{}".format(notebookName, model_name)
#     latest = tf.train.latest_checkpoint(checkpoint_dir)

#     model = new_models[i]
#     model.load_weights(latest)

#     opt = optimizers.RMSprop(lr = 0.01)
#     model.compile(optimizer = opt,
#                   loss = 'categorical_crossentropy',
#                   metrics = ['accuracy'])
    
#     # test_data
#     test_data = np.load(save_test_data_name + ".npy")
#     test_labels = np.load(save_test_labels_name + ".npy")

#     test_data = test_data.reshape(len(test_data), data_length, 1)
#     test_labels = to_categorical(test_labels)

#     # standarization
#     test_data -= mean
#     test_data /= std 
    
#     my_evaluate(model, test_data, test_labels, batch_size)

# %%
import numpy as np
import os

previous = notebookName
# num_models = 5

working_time = np.zeros((num_models))
histories = np.zeros((num_models, 4, epochs))

for i, model_name in enumerate(model_names):
    history = np.load(os.path.join("/content/drive/My Drive/results", previous, model_name, "{}.npz".format(model_name)))

    histories[i, 0] = history['accuracy']
    histories[i, 1] = history['val_accuracy']
    histories[i, 2] = history['loss']
    histories[i, 3] = history['val_loss']

    working_time[i] = history['working_time']

# %%
print(working_time.shape, histories.shape)
# Out:
# (1,) (1, 4, 200)

# %%
mn = ["original"]

for i in range(num_models):
    print("[{}] avg working time: {:.2f} sec".format(mn[i], working_time[i]))
# Out:
# [original] avg working time: 276.12 sec

# %%
import pandas as pd

def smooth_curve(points):
    # df = pd.DataFrame(points, columns = list('A'))
    # # df['A'] = df['A'].rolling(5).mean()
    # df['B'] = df['A'].ewm(10).mean()
    # return df['B'].to_numpy()
    return points

# %%
import matplotlib.pyplot as plt

def plot_histories(histories):
    fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)
    c = ['g', 'g', 'r', 'm', 'k', 'c']
    # l = ["--", "-", ":", "-."]
    l = ["-"] * num_models

    plt.subplot(1, 2, 1)
    for i, history in enumerate(histories):
        acc = history[0]
        val_acc = history[1]
        plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - smooth_curve(val_acc), color = c[i], label = mn[i], linewidth = 1, linestyle = l[i])
        # plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - val_acc, alpha = .3, color = c[i], linewidth = .5, linestyle = l[i])
    plt.title('Validation Error')
    plt.xlabel('Epochs')
    plt.ylabel('Error Rate')
    plt.ylim([-0.03, 1.03])
    # plt.yscale('log')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.subplot(1, 2, 2)
    for i, history in enumerate(histories):
        loss = history[2]
        val_loss = history[3]
        plt.plot(np.arange(1, len(val_loss) + 1, 1), smooth_curve(val_loss), color = c[i], label = mn[i], linewidth = 1, linestyle = l[i])
        # plt.plot(np.arange(1, len(val_loss) + 1, 1), val_loss, alpha = .3, color = c[i], linewidth = .5, linestyle = l[i])
    plt.title('Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.tight_layout()
    plt.show()

# %%
plot_histories(histories)

# %%
test_labels = np.zeros((1000, 50))
num_labels = 50

# %%
preds = np.zeros((num_models, test_labels.shape[0], test_labels.shape[1])) # (3, 10, 1000, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    preds[i] = pred

# %%
test_errors = np.zeros((num_models))

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)
    
    test_errors[i] = np.sum(np.not_equal(np.argmax(pred, axis = 1), y)) / test_labels.shape[0]

# %%
test_errors

# %%
for i in range(num_models):
    print("[{}] avg test error: {:.4f}".format(mn[i], test_errors[i].mean()))

# %%
cmcs = np.zeros((num_models, 50)) # (3, 10, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", previous, model_name, "{}.npy".format(model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)

    a = np.array([sorted(pred[j], reverse = True).index(pred[j, y[j]]) for j in range(len(y))]) # 정답의 순위    
    cmcs[i] = np.array([len(a[a<=j]) / 1000 for j in range(50)])

# %%
print(cmcs)

# %%
fig = plt.figure(figsize = (5, 4), facecolor = 'white', dpi = 300)

for i, model_cmc in enumerate(cmcs):
    c = ['r', 'g', 'b', 'm', 'k', 'c']
    # l = ["--", "-", ":", "-."]
    l = ["-"] * num_models

    plt.plot(np.arange(1, 21, 1), model_cmc[:20],
             color = c[i], label = mn[i], alpha = .7, linewidth = 1.5, linestyle = l[i])

plt.title('Cumulative Match Curve')
plt.xlabel('Rank (k)')
plt.ylabel('Rank-k Classification Rate')
plt.xticks([1, 5, 10, 20])
plt.legend()
plt.grid(True, linewidth = 0.4)

plt.tight_layout()
plt.show()

# %%
for i, cmc in enumerate(cmcs):
    print("[{}] top 1 error: {:.4f}, top 5 error: {:.4f}".format(mn[i], 1 - cmc[0], 1 - cmc[4]))

# %% [markdown]
# # **주요 내용**
#
# *   dd

# %%
notebookName = "20200512_8"
notebookName
# Out:
# '20200512_8'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2789893809810096998, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 11425651381206410105
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 13202676862842278014
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1180823514470797922
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Tue May 12 12:04:00 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    34W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSF04524CJI0', 'GSM03224CHD0', 'GSM03823YJK0', 'GSF05733HBH0', 'I4F03423KSR0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 9   # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %% [markdown]
# **train data, validation data 분할 및 전처리 (normalization)**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

random_state = 1234
test_size = 0.2

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels,
                                                  test_size = test_size,
                                                  random_state = random_state) # fixed

x_train = X_train.reshape(len(X_train), data_length, 1)
x_val = X_val.reshape(len(X_val), data_length, 1) 

y_train = to_categorical(Y_train)
y_val = to_categorical(Y_val)

# standarization
mean = x_train.mean()
x_train -= mean
std = x_train.std()
x_train /= std

x_val -= mean
x_val /= std

# %%
print("test_size: {}, random_state: {}\n".format(test_size, random_state))
print('x_train.shape: {}, y_train.shape: {}'.format(x_train.shape, y_train.shape))
print('x_val.shape: {}, y_val.shape: {}'.format(x_val.shape, y_val.shape))
# Out:
# test_size: 0.2, random_state: 1234
#
# x_train.shape: (3200, 19683, 1), y_train.shape: (3200, 50)
# x_val.shape: (800, 19683, 1), y_val.shape: (800, 50)

# %% [markdown]
# **Build (Advanced) Model**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

def build_model(model_input, block_size, initial_filter_size, kernel_size):
    '''
        conv_type = conv1d
        diff conv: o
        act func = relu
    '''
    x = layers.Conv1D(filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)

    for i in range(block_size):
        x = layers.Conv1D(filters = initial_filter_size * (2**i), kernel_size = kernel_size,
                          strides = 1, padding = "same")(x)
        x = layers.ReLU()(x)
        x = layers.MaxPooling1D(pool_size = 3)(x)
        x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling1D()(x)
    out = layers.Dense(num_labels, activation = 'softmax')(x)

    model = Model(model_input, out)

    w = model.layers[1].get_weights()[0] # weight
    b = model.layers[1].get_weights()[1] # bias

    w[0][0][0] = -1
    w[1][0][0] = 1.

    b[0] = 0.

    model.layers[1].set_weights([w, b])
    return model

# %% [markdown]
# **Train model**

# %%
import time

def compile_and_train(model, batch_size, epochs): 
    # compile
    model.compile(optimizer = 'rmsprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # train & validate
    # print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 0)
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save model & results
    save_model_path = "/content/drive/My Drive/models"
    save_results_path = "/content/drive/My Drive/results"

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    model.save(os.path.join(save_model_path, "{}_{}".format(notebookName, model.name)) + ".h5")
    np.savez_compressed(os.path.join(save_results_path, "{}_{}".format(notebookName, model.name)),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'])
    
    return history

# %%
batch_size = 80
epochs = 200

# %%
models, histories = [], []

for block_size in [3, 4, 5]:
    for initial_filter_size in [16, 32, 64][:5 - block_size + 1]:
        for kernel_size in [3, 4, 5, 6, 7]:
            model = build_model(model_input, block_size, initial_filter_size, kernel_size)

            print("model_name = {}, block_size = {}, initial_filter_size = {}, kernel_size = {}".format(model.name, block_size, initial_filter_size, kernel_size))
            history = compile_and_train(model, batch_size, epochs)

            models.append(model)
            histories.append(history)
# Out:
# model_name = model_3, block_size = 3, initial_filter_size = 16, kernel_size = 3
# [  start time] Tue May 12 12:15:41 2020
# [    end time] Tue May 12 12:20:12 2020
# [working time] 270.47 (sec)
# model_name = model_4, block_size = 3, initial_filter_size = 16, kernel_size = 4
# [  start time] Tue May 12 12:20:12 2020
# [    end time] Tue May 12 12:25:01 2020
# [working time] 288.95 (sec)
# model_name = model_5, block_size = 3, initial_filter_size = 16, kernel_size = 5
# [  start time] Tue May 12 12:25:01 2020
# [    end time] Tue May 12 12:29:43 2020
# [working time] 281.96 (sec)
# model_name = model_6, block_size = 3, initial_filter_size = 16, kernel_size = 6
# [  start time] Tue May 12 12:29:43 2020
# [    end time] Tue May 12 12:34:47 2020
# [working time] 303.30 (sec)
# model_name = model_7, block_size = 3, initial_filter_size = 16, kernel_size = 7
# [  start time] Tue May 12 12:34:47 2020
# [    end time] Tue May 12 12:39:38 2020
# [working time] 291.63 (sec)
# model_name = model_8, block_size = 3, initial_filter_size = 32, kernel_size = 3
# [  start time] Tue May 12 12:39:39 2020
# [    end time] Tue May 12 12:46:45 2020
# [working time] 425.95 (sec)
# model_name = model_9, block_size = 3, initial_filter_size = 32, kernel_size = 4
# [  start time] Tue May 12 12:46:45 2020
# [    end time] Tue May 12 12:54:38 2020
# [working time] 473.53 (sec)
# model_name = model_10, block_size = 3, initial_filter_size = 32, kernel_size = 5
# [  start time] Tue May 12 12:54:39 2020
# [    end time] Tue May 12 13:02:24 2020
# [working time] 465.70 (sec)
# model_name = model_11, block_size = 3, initial_filter_size = 32, kernel_size = 6
# [  start time] Tue May 12 13:02:25 2020
# [    end time] Tue May 12 13:10:56 2020
# [working time] 511.11 (sec)
# model_name = model_12, block_size = 3, initial_filter_size = 32, kernel_size = 7
# [  start time] Tue May 12 13:10:56 2020
# [    end time] Tue May 12 13:19:14 2020
# [working time] 497.71 (sec)
# model_name = model_13, block_size = 3, initial_filter_size = 64, kernel_size = 3
# [  start time] Tue May 12 13:19:14 2020
# [    end time] Tue May 12 13:33:38 2020
# [working time] 864.18 (sec)
# model_name = model_14, block_size = 3, initial_filter_size = 64, kernel_size = 4
# [  start time] Tue May 12 13:33:39 2020
# [    end time] Tue May 12 13:50:08 2020
# [working time] 989.33 (sec)
# model_name = model_15, block_size = 3, initial_filter_size = 64, kernel_size = 5
# [  start time] Tue May 12 13:50:08 2020
# [    end time] Tue May 12 14:06:16 2020
# [working time] 968.29 (sec)
# model_name = model_16, block_size = 3, initial_filter_size = 64, kernel_size = 6
# [  start time] Tue May 12 14:06:17 2020
# [    end time] Tue May 12 14:24:08 2020
# [working time] 1071.04 (sec)
# model_name = model_17, block_size = 3, initial_filter_size = 64, kernel_size = 7
# [  start time] Tue May 12 14:24:08 2020
# [    end time] Tue May 12 14:41:19 2020
# [working time] 1031.27 (sec)
# model_name = model_18, block_size = 4, initial_filter_size = 16, kernel_size = 3
# [  start time] Tue May 12 14:41:20 2020
# [    end time] Tue May 12 14:46:24 2020
# [working time] 304.85 (sec)
# model_name = model_19, block_size = 4, initial_filter_size = 16, kernel_size = 4
# [  start time] Tue May 12 14:46:25 2020
# [    end time] Tue May 12 14:51:59 2020
# [working time] 334.34 (sec)
# model_name = model_20, block_size = 4, initial_filter_size = 16, kernel_size = 5
# [  start time] Tue May 12 14:51:59 2020
# [    end time] Tue May 12 14:57:26 2020
# [working time] 326.38 (sec)
# model_name = model_21, block_size = 4, initial_filter_size = 16, kernel_size = 6
# [  start time] Tue May 12 14:57:26 2020
# [    end time] Tue May 12 15:03:20 2020
# [working time] 354.53 (sec)
# model_name = model_22, block_size = 4, initial_filter_size = 16, kernel_size = 7
# [  start time] Tue May 12 15:03:21 2020
# [    end time] Tue May 12 15:09:04 2020
# [working time] 342.92 (sec)
# model_name = model_23, block_size = 4, initial_filter_size = 32, kernel_size = 3
# [  start time] Tue May 12 15:09:04 2020
# [    end time] Tue May 12 15:17:37 2020
# [working time] 513.09 (sec)
# model_name = model_24, block_size = 4, initial_filter_size = 32, kernel_size = 4
# [  start time] Tue May 12 15:17:37 2020
# [    end time] Tue May 12 15:27:21 2020
# [working time] 583.32 (sec)
# model_name = model_25, block_size = 4, initial_filter_size = 32, kernel_size = 5
# [  start time] Tue May 12 15:27:21 2020
# [    end time] Tue May 12 15:36:51 2020
# [working time] 570.20 (sec)
# model_name = model_26, block_size = 4, initial_filter_size = 32, kernel_size = 6
# [  start time] Tue May 12 15:36:51 2020
# [    end time] Tue May 12 15:47:24 2020
# [working time] 632.61 (sec)
# model_name = model_27, block_size = 4, initial_filter_size = 32, kernel_size = 7
# [  start time] Tue May 12 15:47:24 2020
# [    end time] Tue May 12 15:57:37 2020
# [working time] 612.14 (sec)
# model_name = model_28, block_size = 5, initial_filter_size = 16, kernel_size = 3
# [  start time] Tue May 12 15:57:37 2020
# [    end time] Tue May 12 16:03:16 2020
# [working time] 339.42 (sec)
# model_name = model_29, block_size = 5, initial_filter_size = 16, kernel_size = 4
# [  start time] Tue May 12 16:03:17 2020
# [    end time] Tue May 12 16:09:34 2020
# [working time] 377.25 (sec)
# model_name = model_30, block_size = 5, initial_filter_size = 16, kernel_size = 5
# [  start time] Tue May 12 16:09:34 2020
# [    end time] Tue May 12 16:15:46 2020
# [working time] 372.10 (sec)
# model_name = model_31, block_size = 5, initial_filter_size = 16, kernel_size = 6
# [  start time] Tue May 12 16:15:47 2020
# [    end time] Tue May 12 16:22:30 2020
# [working time] 402.78 (sec)
# model_name = model_32, block_size = 5, initial_filter_size = 16, kernel_size = 7
# [  start time] Tue May 12 16:22:30 2020
# [    end time] Tue May 12 16:28:54 2020
# [working time] 384.57 (sec)

# %% [markdown]
# **Print history**

# %%
history = histories[27-3]

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)

# accuracy
plt.subplot(1, 2, 1)

plt.plot(np.arange(1, len(acc) + 1, 1), acc, 'bo', label = 'Training accuracy', ms = 4, alpha = .7)
plt.plot(np.arange(1, len(val_acc) + 1, 1), val_acc, 'b', label = 'Validation accuracy', alpha = .7)
plt.title('train and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()

# loss
plt.subplot(1, 2, 2)

plt.plot(np.arange(1, len(loss) + 1, 1), loss, 'bo', label = 'Training loss', ms = 4, alpha = .7)
plt.plot(np.arange(1, len(val_loss) + 1, 1), val_loss, 'b', label = 'Validation loss', alpha = .7)
plt.title('train and validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **Field test**

# %%
# reshaping
del test_data, test_labels

test_data = np.load(save_test_data_name + ".npy")
test_labels = np.load(save_test_labels_name + ".npy")

test_data = test_data.reshape(len(test_data), data_length, 1)
test_labels = to_categorical(test_labels)

# standarization
test_data -= mean
test_data /= std 

print('test_data.shape: {}, test_labels.shape: {}'.format(test_data.shape, test_labels.shape))
# Out:
# test_data.shape: (1000, 19683, 1), test_labels.shape: (1000, 50)

# %%
for model in models:
    results = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print('[{}] test loss, test acc:'.format(model.name), results)
# Out:
# 13/13 [==============================] - 0s 15ms/step - loss: 2.6454 - accuracy: 0.6330
# [model_3] test loss, test acc: [2.645397424697876, 0.6330000162124634]
# 13/13 [==============================] - 0s 14ms/step - loss: 0.1270 - accuracy: 0.9620
# [model_4] test loss, test acc: [0.12699592113494873, 0.9620000123977661]
# 13/13 [==============================] - 0s 14ms/step - loss: 1.3868 - accuracy: 0.7500
# [model_5] test loss, test acc: [1.3868093490600586, 0.75]
# 13/13 [==============================] - 0s 14ms/step - loss: 1.9380 - accuracy: 0.7570
# [model_6] test loss, test acc: [1.9379688501358032, 0.7570000290870667]
# 13/13 [==============================] - 0s 14ms/step - loss: 0.0640 - accuracy: 0.9770
# [model_7] test loss, test acc: [0.06396085023880005, 0.9769999980926514]
# 13/13 [==============================] - 0s 19ms/step - loss: 1.7632 - accuracy: 0.7250
# [model_8] test loss, test acc: [1.7631568908691406, 0.7250000238418579]
# 13/13 [==============================] - 0s 21ms/step - loss: 0.6271 - accuracy: 0.8410
# [model_9] test loss, test acc: [0.6270580887794495, 0.8410000205039978]
# 13/13 [==============================] - 0s 21ms/step - loss: 0.2584 - accuracy: 0.9470

# %% [markdown]
# # **주요 내용**
#
# *   실험

# %%
notebookName = "20200516_3"
notebookName
# Out:
# '20200516_3'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 11298472383058170660, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 167832549993119857
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 8281897092043704352
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701401920
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 13085925479336692740
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Sat May 16 09:22:57 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    32W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSF07132LCY0', 'I4F05625JSY0', 'I4F03543KSY0', 'I4F03922LKY0', 'GSF03031LJH0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 9   # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def my_split(train_data, train_labels):
    test_size = 0.2

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    # standarization
    mean = x_train.mean()
    x_train -= mean
    std = x_train.std()
    x_train /= std

    x_val -= mean
    x_val /= std

    return x_train, y_train, x_val, y_val, mean, std

# %% [markdown]
# **Build Model**

# %%
def build_model_1(model_input):
    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(model_input)
    x = layers.ReLU(name = "block1_conv1_act")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_2(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Add(name = "add")([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block1_conv1_act")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_3(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Concatenate(name = "concatenate", axis = -1)([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block1_conv1_act")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

# %%
model_1 = build_model_1(model_input)
# Out:
# model name: model

# %%
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 19683, 1)]        0
# _________________________________________________________________
# block1_conv1 (Conv1D)        (None, 19683, 32)         128
# _________________________________________________________________
# block1_conv1_act (ReLU)      (None, 19683, 32)         0
# _________________________________________________________________
# block1_conv1_bn (BatchNormal (None, 19683, 32)         128
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 19683, 32)         3104
# _________________________________________________________________
# block1_conv2_act (ReLU)      (None, 19683, 32)         0
# _________________________________________________________________
# block1_conv2_bn (BatchNormal (None, 19683, 32)         128
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 6561, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 6561, 64)          6208
# _________________________________________________________________
# block2_conv1_act (ReLU)      (None, 6561, 64)          0
# _________________________________________________________________
# block2_conv1_bn (BatchNormal (None, 6561, 64)          256
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 6561, 64)          12352
# _________________________________________________________________
# block2_conv2_act (ReLU)      (None, 6561, 64)          0
# _________________________________________________________________
# block2_conv2_bn (BatchNormal (None, 6561, 64)          256
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 2187, 64)          0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 2187, 128)         24704
# _________________________________________________________________
# block3_conv1_act (ReLU)      (None, 2187, 128)         0
# _________________________________________________________________
# block3_conv1_bn (BatchNormal (None, 2187, 128)         512
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 2187, 128)         49280
# _________________________________________________________________
# block3_conv2_act (ReLU)      (None, 2187, 128)         0
# _________________________________________________________________
# block3_conv2_bn (BatchNormal (None, 2187, 128)         512
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 729, 128)          0
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 128)               0
# _________________________________________________________________
# predictions (Dense)          (None, 50)                6450
# =================================================================
# Total params: 104,018
# Trainable params: 103,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
model_2 = build_model_2(model_input)
# Out:
# model name: model_1

# %%
model_2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 19683, 1)]   0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 19683, 1)     3           input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 19683, 1)     0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 19683, 32)    128         add[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (ReLU)         (None, 19683, 32)    0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 19683, 32)    128         block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 19683, 32)    3104        block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 19683, 32)    0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 19683, 32)    128         block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 6561, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 6561, 64)     6208        block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 6561, 64)     0           block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 6561, 64)     256         block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 6561, 64)     12352       block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 6561, 64)     0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 6561, 64)     256         block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 2187, 64)     0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 2187, 128)    24704       block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 2187, 128)    0           block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 2187, 128)    512         block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 2187, 128)    49280       block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 2187, 128)    0           block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 2187, 128)    512         block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 729, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 104,021
# Trainable params: 103,125
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model_3 = build_model_3(model_input)
# Out:
# model name: model_2

# %%
model_3.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 19683, 1)]   0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 19683, 1)     3           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 19683, 2)     0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 19683, 32)    224         concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv1_act (ReLU)         (None, 19683, 32)    0           block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 19683, 32)    128         block1_conv1_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 19683, 32)    3104        block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 19683, 32)    0           block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 19683, 32)    128         block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 6561, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 6561, 64)     6208        block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 6561, 64)     0           block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 6561, 64)     256         block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 6561, 64)     12352       block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 6561, 64)     0           block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 6561, 64)     256         block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 2187, 64)     0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 2187, 128)    24704       block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 2187, 128)    0           block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 2187, 128)    512         block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 2187, 128)    49280       block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 2187, 128)    0           block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 2187, 128)    512         block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 729, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 104,117
# Trainable params: 103,221
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes = True, to_file = 'model_1.png')

# %%
plot_model(model_2, show_shapes = True, to_file = 'model_2.png')

# %%
plot_model(model_3, show_shapes = True, to_file = 'model_3.png')

# %% [markdown]
# **Train model**

# %%
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    model.compile(optimizer = 'rmsprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 0)
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save model & results
    save_model_path = "/content/drive/My Drive/models"
    save_results_path = "/content/drive/My Drive/results"

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    model.save(os.path.join(save_model_path, "{}_{}".format(notebookName, model.name)) + ".h5")
    np.savez_compressed(os.path.join(save_results_path,  "{}_{}".format(notebookName, model.name)),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'],
                        working_time = np.array([end - start]))

# %%
def my_evaluate(model, test_data, test_labels, batch_size):
    loss, acc = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print("model name: {}, test loss: {}, test_acc: {}".format(model.name, loss, acc))

    save_eval_path = "/content/drive/My Drive/evals"
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    pred = model.predict(test_data) # shape: (1000, 50)
    np.save(os.path.join(save_eval_path,  "{}_{}".format(notebookName, model.name)), pred)

# %% [markdown]
# **test**

# %%
batch_size = 128
epochs = 200

num_models = 3
num_loop = 10

model_names = []
for i in range(num_loop):
    # train test split
    x_train, y_train, x_val, y_val, mean, std = my_split(train_data, train_labels)

    # build & compile & train model
    model_input = Input(shape = (data_length, 1))
    models = [
        build_model_1(model_input),
        build_model_2(model_input),
        build_model_3(model_input),
    ]
    
    for model in models:
        compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs)

    # test_data
    test_data = np.load(save_test_data_name + ".npy")
    test_labels = np.load(save_test_labels_name + ".npy")

    test_data = test_data.reshape(len(test_data), data_length, 1)
    test_labels = to_categorical(test_labels)

    # standarization
    test_data -= mean
    test_data /= std 

    for model in models:
        my_evaluate(model, test_data, test_labels, batch_size = batch_size)

    model_names = model_names + [model.name for model in models]
# Out:
# model name: model_3
# model name: model_4
# model name: model_5
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 09:28:06 2020
# [    end time] Sat May 16 09:46:51 2020
# [working time] 1124.32 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 09:46:51 2020
# [    end time] Sat May 16 10:05:59 2020
# [working time] 1148.02 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 10:05:59 2020
# [    end time] Sat May 16 10:25:12 2020
# [working time] 1152.93 (sec)
# 8/8 [==============================] - 1s 64ms/step - loss: 0.0469 - accuracy: 0.9860
# model name: model_3, test loss: 0.04694348946213722, test_acc: 0.9860000014305115
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0379 - accuracy: 0.9920
# model name: model_4, test loss: 0.037925682961940765, test_acc: 0.9919999837875366
# 8/8 [==============================] - 1s 80ms/step - loss: 0.4352 - accuracy: 0.9040
# model name: model_5, test loss: 0.43521738052368164, test_acc: 0.9039999842643738
# model name: model_6
# model name: model_7
# model name: model_8
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 10:25:22 2020
# [    end time] Sat May 16 10:43:59 2020
# [working time] 1117.12 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 10:43:59 2020
# [    end time] Sat May 16 11:03:08 2020
# [working time] 1148.63 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 11:03:08 2020
# [    end time] Sat May 16 11:22:22 2020
# [working time] 1153.86 (sec)
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0467 - accuracy: 0.9870
# model name: model_6, test loss: 0.04671530798077583, test_acc: 0.9869999885559082
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0451 - accuracy: 0.9910
# model name: model_7, test loss: 0.045142218470573425, test_acc: 0.9909999966621399
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0748 - accuracy: 0.9810
# model name: model_8, test loss: 0.07483737915754318, test_acc: 0.9810000061988831
# model name: model_9
# model name: model_10
# model name: model_11
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 11:22:28 2020
# [    end time] Sat May 16 11:41:05 2020
# [working time] 1117.47 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 11:41:05 2020
# [    end time] Sat May 16 12:00:14 2020
# [working time] 1148.35 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 12:00:14 2020
# [    end time] Sat May 16 12:19:25 2020
# [working time] 1151.53 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0561 - accuracy: 0.9890
# model name: model_9, test loss: 0.056143563240766525, test_acc: 0.9890000224113464
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0322 - accuracy: 0.9920
# model name: model_10, test loss: 0.03219945356249809, test_acc: 0.9919999837875366
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0919 - accuracy: 0.9720
# model name: model_11, test loss: 0.0919417291879654, test_acc: 0.972000002861023
# model name: model_12
# model name: model_13
# model name: model_14
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 12:19:31 2020
# [    end time] Sat May 16 12:38:06 2020
# [working time] 1115.62 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 12:38:06 2020
# [    end time] Sat May 16 12:57:10 2020
# [working time] 1143.68 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 12:57:10 2020
# [    end time] Sat May 16 13:16:22 2020
# [working time] 1151.49 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1831 - accuracy: 0.9580
# model name: model_12, test loss: 0.18306845426559448, test_acc: 0.9580000042915344
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0935 - accuracy: 0.9780
# model name: model_13, test loss: 0.09347706288099289, test_acc: 0.9779999852180481
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0872 - accuracy: 0.9810
# model name: model_14, test loss: 0.08719077706336975, test_acc: 0.9810000061988831
# model name: model_15
# model name: model_16
# model name: model_17
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 13:16:27 2020
# [    end time] Sat May 16 13:35:04 2020
# [working time] 1117.22 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 13:35:04 2020
# [    end time] Sat May 16 13:54:11 2020
# [working time] 1147.04 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 13:54:11 2020
# [    end time] Sat May 16 14:13:23 2020
# [working time] 1151.50 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1062 - accuracy: 0.9740
# model name: model_15, test loss: 0.10616438835859299, test_acc: 0.9739999771118164
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2329 - accuracy: 0.9500
# model name: model_16, test loss: 0.23293055593967438, test_acc: 0.949999988079071
# 8/8 [==============================] - 0s 51ms/step - loss: 0.1811 - accuracy: 0.9530
# model name: model_17, test loss: 0.18109345436096191, test_acc: 0.953000009059906
# model name: model_18
# model name: model_19
# model name: model_20
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 14:13:28 2020
# [    end time] Sat May 16 14:32:04 2020
# [working time] 1116.28 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 14:32:04 2020
# [    end time] Sat May 16 14:51:12 2020
# [working time] 1147.45 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 14:51:12 2020
# [    end time] Sat May 16 15:10:23 2020
# [working time] 1150.97 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.1169 - accuracy: 0.9730
# model name: model_18, test loss: 0.11690627038478851, test_acc: 0.9729999899864197
# 8/8 [==============================] - 0s 53ms/step - loss: 0.0367 - accuracy: 0.9840
# model name: model_19, test loss: 0.03668893501162529, test_acc: 0.984000027179718
# 8/8 [==============================] - 0s 54ms/step - loss: 0.0627 - accuracy: 0.9870
# model name: model_20, test loss: 0.0626554787158966, test_acc: 0.9869999885559082
# model name: model_21
# model name: model_22
# model name: model_23
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 15:10:28 2020
# [    end time] Sat May 16 15:29:04 2020
# [working time] 1115.23 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 15:29:04 2020
# [    end time] Sat May 16 15:48:10 2020
# [working time] 1146.26 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 15:48:10 2020
# [    end time] Sat May 16 16:07:22 2020
# [working time] 1151.94 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0396 - accuracy: 0.9900
# model name: model_21, test loss: 0.03958244249224663, test_acc: 0.9900000095367432
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0414 - accuracy: 0.9930
# model name: model_22, test loss: 0.04144004359841347, test_acc: 0.9929999709129333
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0817 - accuracy: 0.9830
# model name: model_23, test loss: 0.08169324696063995, test_acc: 0.9829999804496765
# model name: model_24
# model name: model_25
# model name: model_26
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 16:07:27 2020
# [    end time] Sat May 16 16:26:03 2020
# [working time] 1115.48 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 16:26:03 2020
# [    end time] Sat May 16 16:45:10 2020
# [working time] 1147.16 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 16:45:10 2020
# [    end time] Sat May 16 17:04:21 2020
# [working time] 1151.04 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.2214 - accuracy: 0.9490
# model name: model_24, test loss: 0.221406951546669, test_acc: 0.9490000009536743
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0689 - accuracy: 0.9770
# model name: model_25, test loss: 0.06885667890310287, test_acc: 0.9769999980926514
# 8/8 [==============================] - 0s 52ms/step - loss: 0.1978 - accuracy: 0.9550
# model name: model_26, test loss: 0.19777505099773407, test_acc: 0.9549999833106995
# model name: model_27
# model name: model_28
# model name: model_29
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 17:04:26 2020
# [    end time] Sat May 16 17:23:03 2020
# [working time] 1116.93 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 17:23:03 2020
# [    end time] Sat May 16 17:42:11 2020
# [working time] 1147.31 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 17:42:11 2020
# [    end time] Sat May 16 18:01:22 2020
# [working time] 1151.41 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0417 - accuracy: 0.9870
# model name: model_27, test loss: 0.04169655963778496, test_acc: 0.9869999885559082
# 8/8 [==============================] - 0s 52ms/step - loss: 0.5028 - accuracy: 0.8810
# model name: model_28, test loss: 0.5028198957443237, test_acc: 0.8809999823570251
# 8/8 [==============================] - 0s 51ms/step - loss: 0.0981 - accuracy: 0.9720
# model name: model_29, test loss: 0.09805069863796234, test_acc: 0.972000002861023
# model name: model_30
# model name: model_31
# model name: model_32
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 18:01:27 2020
# [    end time] Sat May 16 18:20:01 2020
# [working time] 1114.25 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 18:20:02 2020
# [    end time] Sat May 16 18:39:07 2020
# [working time] 1145.43 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sat May 16 18:39:07 2020
# [    end time] Sat May 16 18:58:18 2020
# [working time] 1150.67 (sec)
# 8/8 [==============================] - 0s 50ms/step - loss: 0.0490 - accuracy: 0.9810
# model name: model_30, test loss: 0.04904573783278465, test_acc: 0.9810000061988831
# 8/8 [==============================] - 0s 52ms/step - loss: 0.0737 - accuracy: 0.9840
# model name: model_31, test loss: 0.07374991476535797, test_acc: 0.984000027179718
# 8/8 [==============================] - 0s 51ms/step - loss: 0.2034 - accuracy: 0.9540
# model name: model_32, test loss: 0.2034144401550293, test_acc: 0.9539999961853027

# %% [markdown]
# **plot working time & validation loss and accuracy**

# %%
working_time = np.zeros((num_models, num_loop))
histories = np.zeros((num_models, num_loop, 4, epochs))

for i, model_name in enumerate(model_names):
    history = np.load(os.path.join("/content/drive/My Drive/results", "{}_{}.npz".format(notebookName, model_name)))

    histories[i % num_models, i // num_models, 0] = history['accuracy']
    histories[i % num_models, i // num_models, 1] = history['val_accuracy']
    histories[i % num_models, i // num_models, 2] = history['loss']
    histories[i % num_models, i // num_models, 3] = history['val_loss']

    working_time[i % num_models, i // num_models] = history['working_time']

# %%
avg_working_time = working_time.mean(axis = 1)
avg_histories = histories.mean(axis = 1)

print(avg_working_time.shape, avg_histories.shape)
# Out:
# (3,) (3, 4, 200)

# %%
for i in range(num_models):
    print("[model_{}] avg working time: {}".format(i, avg_working_time[i]))
# Out:
# [model_0] avg working time: 1116.9913915872573
# [model_1] avg working time: 1146.9337260723114
# [model_2] avg working time: 1151.7331929922104

# %%
import matplotlib.pyplot as plt

def plot_histories(avg_histories):
    fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)
    c = ['r', 'g', 'b']
    n = ['model_{}'.format(i) for i in range(1, 4, 1)]

    plt.subplot(1, 2, 1)
    for i, history in enumerate(histories):
        acc = avg_histories[i, 0]
        val_acc = avg_histories[i, 1]
        plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - np.array(smooth_curve(val_acc)), color = c[i], label = n[i], alpha = .7)
    plt.title('Validation error')
    plt.xlabel('Epochs')
    plt.ylabel('Error')
    # plt.yscale('log')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i, history in enumerate(histories):
        loss = avg_histories[i, 2]
        val_loss = avg_histories[i, 3]
        plt.plot(np.arange(1, len(val_loss) + 1, 1), smooth_curve(val_loss), color = c[i], label = n[i], alpha = .7)
    plt.title('Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
plot_histories(avg_histories)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-052089e3c121> in <module>()
# ----> 1 plot_histories(avg_histories)
#
# <ipython-input-32-1a25355f4c81> in plot_histories(avg_histories)
#      10         acc = avg_histories[i, 0]
#      11         val_acc = avg_histories[i, 1]
# ---> 12         plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - np.array(smooth_curve(val_acc)), color = c[i], label = n[i], alpha = .7)
#      13     plt.title('Validation error')
#      14     plt.xlabel('Epochs')
#
# NameError: name 'smooth_curve' is not defined

# %% [markdown]
# **plot test error & predictions (CMC Curve)**

# %%
preds = np.zeros((num_models, num_loop, test_labels.shape[0], test_labels.shape[1])) # (3, 10, 1000, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", "{}_{}.npy".format(notebookName, model_name))) # (1000, 50)
    preds[i % num_models, i // num_models] = pred

# %%
test_errors = np.zeros((num_models, num_loop))

for i, model_name in enumerate(model_names):
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)
    test_errors[i % num_models, i // num_models] = np.sum(np.not_equal(np.argmax(pred, axis = 1), y)) / test_labels.shape[0]

# %%
for i in range(num_models):
    print("[model_{}] avg test error: {}".format(i, np.mean(test_errors[i], axis = 1)))

# %%
cmcs = np.zeros((num_models, num_loop, 50)) # (3, 10, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", "{}_{}.npy".format(notebookName, model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)

    a = np.array([sorted(pred[j]).index(pred[j, y[j]]) for j in range(1000)]) # 정답의 순위    
    cmcs[i % num_models, i // num_models] = np.array([len(a[a<=j]) / 1000 for j in range(50)])

# %%
avg_cmcs = cmcs.mean(axis = 1)

fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)

for i, model_name in enumerate(model_names):
    c = ['r', 'g', 'b']
    n = ['model_{}'.format(i) for i in range(1, 4, 1)]

    plt.plot(np.arange(1, 51, 1), avg_cmcs[i], color = c[i], label = n[i], alpha = 0.7)

plt.title('Cumulative Match Curve')
plt.xlabel('Rank (k)')
plt.ylabel('Rank-k Error Rate')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# # **주요 내용**
#
# *   실험

# %%
notebookName = "20200514_10"
notebookName
# Out:
# '20200514_10'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 2782646083111171742, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 10654427497995009216
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 581929156041661809
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 14971808034227426053
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Thu May 14 12:42:46 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    30W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM09752SCY0', 'GSM02544LHS0', 'GSM03321SDK0', 'I4F02631KSM0', 'GSF03732JJH0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 9   # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %% [markdown]
# **train data, validation data 분할 및 전처리 (normalization)**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def split(train_data, train_labels):
    test_size = 0.2

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    # standarization
    mean = x_train.mean()
    x_train -= mean
    std = x_train.std()
    x_train /= std

    x_val -= mean
    x_val /= std

    return x_train, y_train, x_val, y_val, mean, std

# %% [markdown]
# **Build Model**

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

def build_model(model_input):
    a = layers.Conv1D(filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    a = layers.Concatenate(axis = -1)([model_input, a])

    # block 1
    y = layers.Conv1D(filters = 32, kernel_size = 5, strides = 1, padding = "same")(a)
    y = layers.ReLU()(y)
    y = layers.BatchNormalization()(y)
    y = layers.MaxPooling1D(pool_size = 3)(y)

    # block 2
    y = layers.Conv1D(filters = 64, kernel_size = 5, strides = 1, padding = "same")(y)
    y = layers.ReLU()(y)
    y = layers.BatchNormalization()(y)
    y = layers.MaxPooling1D(pool_size = 3)(y)

    # block 3
    y = layers.Conv1D(filters = 128, kernel_size = 5, strides = 1, padding = "same")(y)
    y = layers.ReLU()(y)
    y = layers.BatchNormalization()(y)
    y = layers.MaxPooling1D(pool_size = 3)(y)

    # block 4
    y = layers.Conv1D(filters = 256, kernel_size = 5, strides = 1, padding = "same")(y)
    y = layers.ReLU()(y)
    y = layers.BatchNormalization()(y)
    y = layers.MaxPooling1D(pool_size = 3)(y)

    pooled = layers.GlobalAveragePooling1D()(y)
    out = layers.Dense(num_labels, activation = 'softmax')(pooled)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))

    w = model.layers[1].get_weights()[0] # weight
    b = model.layers[1].get_weights()[1] # bias

    w[0][0][0] = -1
    w[1][0][0] = 1.

    b[0] = 0.

    model.layers[1].set_weights([w, b])
    
    return model

# %% [markdown]
# **Train model**

# %%
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    model.compile(optimizer = 'rmsprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 0)
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save model & results
    save_model_path = "/content/drive/My Drive/models"
    save_results_path = "/content/drive/My Drive/results"

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    model.save(os.path.join(save_model_path, "{}_{}".format(notebookName, model.name)) + ".h5")
    np.savez_compressed(os.path.join(save_results_path,  "{}_{}".format(notebookName, model.name)),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'])
    
    return history

# %%
batch_size = 80
epochs = 500

for i in range(10):
    # train test split
    x_train, y_train, x_val, y_val, mean, std = split(train_data, train_labels)

    test_data = np.load(save_test_data_name + ".npy")
    test_labels = np.load(save_test_labels_name + ".npy")

    test_data = test_data.reshape(len(test_data), data_length, 1)
    test_labels = to_categorical(test_labels)

    # standarization
    test_data -= mean
    test_data /= std 

    # build & compile & train model
    model_input = Input(shape = (data_length, 1))
    model = build_model(model_input)

    compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs)

    # results
    results = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print('test loss, test acc:', results)

    # weight & bias
    print(model.layers[1].get_weights())
# Out:
# model name: model
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 12:46:39 2020
# [    end time] Thu May 14 13:18:07 2020
# [working time] 1888.49 (sec)
# 13/13 [==============================] - 0s 27ms/step - loss: 0.0350 - accuracy: 0.9950
# test loss, test acc: [0.03504880890250206, 0.9950000047683716]
# [array([[[-1.0744408]],
#
#        [[ 1.0286516]]], dtype=float32), array([-0.06965695], dtype=float32)]
# model name: model_1
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 13:18:11 2020
# [    end time] Thu May 14 13:49:38 2020
# [working time] 1887.11 (sec)
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0331 - accuracy: 0.9940
# test loss, test acc: [0.033057939261198044, 0.9940000176429749]
# [array([[[-1.0133384]],
#
#        [[ 1.0810825]]], dtype=float32), array([0.01530647], dtype=float32)]
# model name: model_2
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 13:49:40 2020
# [    end time] Thu May 14 14:20:55 2020
# [working time] 1874.89 (sec)
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0240 - accuracy: 0.9950
# test loss, test acc: [0.02399728260934353, 0.9950000047683716]
# [array([[[-1.0533864]],
#
#        [[ 1.063175 ]]], dtype=float32), array([-0.03067545], dtype=float32)]
# model name: model_3
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 14:20:57 2020
# [    end time] Thu May 14 14:52:19 2020
# [working time] 1882.18 (sec)
# 13/13 [==============================] - 0s 24ms/step - loss: 0.0336 - accuracy: 0.9910
# test loss, test acc: [0.03355640545487404, 0.9909999966621399]
# [array([[[-1.0781105]],
#
#        [[ 1.0426623]]], dtype=float32), array([0.00589393], dtype=float32)]
# model name: model_4
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 14:52:21 2020
# [    end time] Thu May 14 15:23:51 2020
# [working time] 1890.24 (sec)
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0480 - accuracy: 0.9950
# test loss, test acc: [0.04801449924707413, 0.9950000047683716]
# [array([[[-1.0259694]],
#
#        [[ 1.0364488]]], dtype=float32), array([-0.05235904], dtype=float32)]
# model name: model_5
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 15:23:53 2020
# [    end time] Thu May 14 15:55:25 2020
# [working time] 1891.91 (sec)
# 13/13 [==============================] - 0s 26ms/step - loss: 0.0131 - accuracy: 0.9960
# test loss, test acc: [0.013118073344230652, 0.9959999918937683]
# [array([[[-1.069847 ]],
#
#        [[ 1.0548917]]], dtype=float32), array([0.07115642], dtype=float32)]
# model name: model_6
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 15:55:26 2020
# [    end time] Thu May 14 16:26:59 2020
# [working time] 1893.35 (sec)
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0229 - accuracy: 0.9970
# test loss, test acc: [0.022938797250390053, 0.996999979019165]
# [array([[[-1.0516307]],
#
#        [[ 1.0720963]]], dtype=float32), array([-0.03617239], dtype=float32)]
# model name: model_7
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 16:27:01 2020
# [    end time] Thu May 14 16:58:39 2020
# [working time] 1897.75 (sec)
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0271 - accuracy: 0.9940
# test loss, test acc: [0.027057914063334465, 0.9940000176429749]
# [array([[[-1.0242192]],
#
#        [[ 1.0385662]]], dtype=float32), array([-0.07138605], dtype=float32)]
# model name: model_8
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 16:58:40 2020
# [    end time] Thu May 14 17:30:09 2020
# [working time] 1888.38 (sec)
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0222 - accuracy: 0.9970
# test loss, test acc: [0.02222474291920662, 0.996999979019165]
# [array([[[-1.0400642]],
#
#        [[ 1.0597748]]], dtype=float32), array([-0.00630932], dtype=float32)]
# model name: model_9
# Train on 3200 samples, validate on 800 samples...
# [  start time] Thu May 14 17:30:10 2020
# [    end time] Thu May 14 18:01:41 2020
# [working time] 1890.86 (sec)
# 13/13 [==============================] - 0s 25ms/step - loss: 0.0430 - accuracy: 0.9920
# test loss, test acc: [0.0429687462747097, 0.9919999837875366]
# [array([[[-1.0538985]],
#
#        [[ 1.0215056]]], dtype=float32), array([0.05146271], dtype=float32)]

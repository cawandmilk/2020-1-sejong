# %% [markdown]
# # **주요 내용**
#
# *   실험

# %%
notebookName = "20200517_2"
notebookName
# Out:
# '20200517_2'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 6422252807719467683, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9114080301212219417
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 15157023438771771410
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 4922971632072379762
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Sun May 17 04:41:47 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    32W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSF07132LCY0', 'I4F05625JSY0', 'I4F03543KSY0', 'I4F03922LKY0', 'GSF03031LJH0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 8   # 6,561

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 6561), train_labels.shape: (4000,)
# test_data.shape: (1000, 6561), test_labels.shape: (1000,)

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def my_split(train_data, train_labels):
    test_size = 0.2

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    # standarization
    mean = x_train.mean()
    x_train -= mean
    std = x_train.std()
    x_train /= std

    x_val -= mean
    x_val /= std

    return x_train, y_train, x_val, y_val, mean, std

# %% [markdown]
# **Build Model**

# %%
def build_model_1(model_input, i):
    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(model_input)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    x = layers.Dropout(rate = 0.4, name = "dropout")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out, name = "normal_{}".format(i))
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_2(model_input, i):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Add(name = "add")([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    x = layers.Dropout(rate = 0.4, name = "dropout")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out, name = "sfconv_add_{}".format(i))
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_3(model_input, i):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Concatenate(name = "concatenate", axis = -1)([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)
    x = layers.ReLU(name = "block1_conv2_act")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    x = layers.Dropout(rate = 0.4, name = "dropout")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out, name = "sfconv_concat_{}".format(i))
    print("model name: {}".format(model.name))
    return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

# %%
model_1 = build_model_1(model_input, 0)
# Out:
# model name: normal_0

# %%
model_1.summary()
# Out:
# Model: "normal_0"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 6561, 1)]         0
# _________________________________________________________________
# block1_conv1 (Conv1D)        (None, 6561, 32)          128
# _________________________________________________________________
# block1_conv1_bn (BatchNormal (None, 6561, 32)          128
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 6561, 32)          3104
# _________________________________________________________________
# block1_conv2_bn (BatchNormal (None, 6561, 32)          128
# _________________________________________________________________
# block1_conv2_act (ReLU)      (None, 6561, 32)          0
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 2187, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 2187, 64)          6208
# _________________________________________________________________
# block2_conv1_bn (BatchNormal (None, 2187, 64)          256
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 2187, 64)          12352
# _________________________________________________________________
# block2_conv2_bn (BatchNormal (None, 2187, 64)          256
# _________________________________________________________________
# block2_conv2_act (ReLU)      (None, 2187, 64)          0
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 729, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 729, 128)          24704
# _________________________________________________________________
# block3_conv1_bn (BatchNormal (None, 729, 128)          512
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 729, 128)          49280
# _________________________________________________________________
# block3_conv2_bn (BatchNormal (None, 729, 128)          512
# _________________________________________________________________
# block3_conv2_act (ReLU)      (None, 729, 128)          0
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 243, 128)          0
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 128)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# predictions (Dense)          (None, 50)                6450
# =================================================================
# Total params: 104,018
# Trainable params: 103,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
model_2 = build_model_2(model_input, 0)
# Out:
# model name: sfconv_add_0

# %%
model_2.summary()
# Out:
# Model: "sfconv_add_0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 6561, 1)      0           input_3[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 6561, 32)     128         add[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 6561, 32)     3104        block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 6561, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        dropout[0][0]
# ==================================================================================================
# Total params: 104,021
# Trainable params: 103,125
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model_3 = build_model_3(model_input, 0)
# Out:
# model name: sfconv_concat_0

# %%
model_3.summary()
# Out:
# Model: "sfconv_concat_0"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6561, 2)      0           input_3[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 6561, 32)     224         concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 6561, 32)     3104        block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 6561, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 128)          0           avg_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        dropout[0][0]
# ==================================================================================================
# Total params: 104,117
# Trainable params: 103,221
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes = True, to_file = 'model_1.png')

# %%
plot_model(model_2, show_shapes = True, to_file = 'model_2.png')

# %%
plot_model(model_3, show_shapes = True, to_file = 'model_3.png')

# %% [markdown]
# **Train model**

# %%
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    model.compile(optimizer = 'rmsprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 0)
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save model & results
    save_model_path = "/content/drive/My Drive/models"
    save_results_path = "/content/drive/My Drive/results"

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    model.save(os.path.join(save_model_path, "{}_{}".format(notebookName, model.name)) + ".h5")
    np.savez_compressed(os.path.join(save_results_path,  "{}_{}".format(notebookName, model.name)),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'],
                        working_time = np.array([end - start]))

# %%
def my_evaluate(model, test_data, test_labels, batch_size):
    loss, acc = model.evaluate(test_data, test_labels, batch_size = batch_size)
    print("model name: {}, test loss: {}, test_acc: {}".format(model.name, loss, acc))

    save_eval_path = "/content/drive/My Drive/evals"
    if not os.path.exists(save_eval_path):     os.mkdir(save_eval_path)

    pred = model.predict(test_data) # (1000, 50)
    np.save(os.path.join(save_eval_path,  "{}_{}".format(notebookName, model.name)), pred)

# %% [markdown]
# **test**

# %%
batch_size = 128
epochs = 500

num_models = 3
num_loop = 10

model_names = []
for i in range(num_loop):
    # train test split
    x_train, y_train, x_val, y_val, mean, std = my_split(train_data, train_labels)

    # build & compile & train model
    model_input = Input(shape = (data_length, 1))
    models = [
        build_model_1(model_input, i),
        build_model_2(model_input, i),
        build_model_3(model_input, i),
    ]
    
    for model in models:
        compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs)

    # test_data
    test_data = np.load(save_test_data_name + ".npy")
    test_labels = np.load(save_test_labels_name + ".npy")

    test_data = test_data.reshape(len(test_data), data_length, 1)
    test_labels = to_categorical(test_labels)

    # standarization
    test_data -= mean
    test_data /= std 

    for model in models:
        my_evaluate(model, test_data, test_labels, batch_size = batch_size)

    model_names = model_names + [model.name for model in models]
# Out:
# model name: normal_0
# model name: sfconv_add_0
# model name: sfconv_concat_0
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 06:28:38 2020
# [    end time] Sun May 17 06:44:24 2020
# [working time] 946.52 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 06:44:25 2020
# [    end time] Sun May 17 07:00:39 2020
# [working time] 974.38 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 07:00:40 2020
# [    end time] Sun May 17 07:16:58 2020
# [working time] 978.15 (sec)
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3816 - accuracy: 0.8880
# model name: normal_0, test loss: 0.38162660598754883, test_acc: 0.8880000114440918
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6478 - accuracy: 0.8400
# model name: sfconv_add_0, test loss: 0.6478007435798645, test_acc: 0.8399999737739563
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4959 - accuracy: 0.8480
# model name: sfconv_concat_0, test loss: 0.4958757162094116, test_acc: 0.8479999899864197
# model name: normal_1
# model name: sfconv_add_1
# model name: sfconv_concat_1
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 07:17:02 2020
# [    end time] Sun May 17 07:32:48 2020
# [working time] 946.96 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 07:32:49 2020
# [    end time] Sun May 17 07:49:03 2020
# [working time] 974.81 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 07:49:03 2020
# [    end time] Sun May 17 08:05:14 2020
# [working time] 970.96 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5226 - accuracy: 0.8450
# model name: normal_1, test loss: 0.5226468443870544, test_acc: 0.8450000286102295
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4143 - accuracy: 0.8770
# model name: sfconv_add_1, test loss: 0.41431954503059387, test_acc: 0.8769999742507935
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4069 - accuracy: 0.8690
# model name: sfconv_concat_1, test loss: 0.40687641501426697, test_acc: 0.8690000176429749
# model name: normal_2
# model name: sfconv_add_2
# model name: sfconv_concat_2
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 08:05:17 2020
# [    end time] Sun May 17 08:21:04 2020
# [working time] 947.25 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 08:21:05 2020
# [    end time] Sun May 17 08:37:19 2020
# [working time] 974.75 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 08:37:19 2020
# [    end time] Sun May 17 08:53:38 2020
# [working time] 978.72 (sec)
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5155 - accuracy: 0.8520
# model name: normal_2, test loss: 0.5154616832733154, test_acc: 0.8519999980926514
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3494 - accuracy: 0.9100
# model name: sfconv_add_2, test loss: 0.3494250476360321, test_acc: 0.9100000262260437
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5462 - accuracy: 0.8480
# model name: sfconv_concat_2, test loss: 0.5462262630462646, test_acc: 0.8479999899864197
# model name: normal_3
# model name: sfconv_add_3
# model name: sfconv_concat_3
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 08:53:41 2020
# [    end time] Sun May 17 09:09:28 2020
# [working time] 946.89 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 09:09:28 2020
# [    end time] Sun May 17 09:25:43 2020
# [working time] 974.72 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 09:25:43 2020
# [    end time] Sun May 17 09:41:52 2020
# [working time] 969.74 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3877 - accuracy: 0.8720
# model name: normal_3, test loss: 0.3877060115337372, test_acc: 0.871999979019165
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3945 - accuracy: 0.8890
# model name: sfconv_add_3, test loss: 0.39451465010643005, test_acc: 0.8889999985694885
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3153 - accuracy: 0.9190
# model name: sfconv_concat_3, test loss: 0.3153320252895355, test_acc: 0.9190000295639038
# model name: normal_4
# model name: sfconv_add_4
# model name: sfconv_concat_4
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 09:41:56 2020
# [    end time] Sun May 17 09:57:41 2020
# [working time] 945.54 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 09:57:41 2020
# [    end time] Sun May 17 10:13:56 2020
# [working time] 974.71 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 10:13:56 2020
# [    end time] Sun May 17 10:30:15 2020
# [working time] 978.52 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5769 - accuracy: 0.8420
# model name: normal_4, test loss: 0.5768628120422363, test_acc: 0.8420000076293945
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3989 - accuracy: 0.8860
# model name: sfconv_add_4, test loss: 0.39889636635780334, test_acc: 0.8859999775886536
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4753 - accuracy: 0.8710
# model name: sfconv_concat_4, test loss: 0.475349098443985, test_acc: 0.8709999918937683
# model name: normal_5
# model name: sfconv_add_5
# model name: sfconv_concat_5
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 10:30:17 2020
# [    end time] Sun May 17 10:46:03 2020
# [working time] 945.33 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 10:46:03 2020
# [    end time] Sun May 17 11:02:18 2020
# [working time] 974.92 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 11:02:18 2020
# [    end time] Sun May 17 11:18:37 2020
# [working time] 978.66 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6348 - accuracy: 0.8210
# model name: normal_5, test loss: 0.6348078846931458, test_acc: 0.8209999799728394
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5494 - accuracy: 0.8450
# model name: sfconv_add_5, test loss: 0.5494091510772705, test_acc: 0.8450000286102295
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4690 - accuracy: 0.8530
# model name: sfconv_concat_5, test loss: 0.4690038561820984, test_acc: 0.8529999852180481
# model name: normal_6
# model name: sfconv_add_6
# model name: sfconv_concat_6
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 11:18:39 2020
# [    end time] Sun May 17 11:34:27 2020
# [working time] 947.34 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 11:34:27 2020
# [    end time] Sun May 17 11:50:43 2020
# [working time] 976.55 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 11:50:43 2020
# [    end time] Sun May 17 12:07:05 2020
# [working time] 981.37 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6012 - accuracy: 0.8440
# model name: normal_6, test loss: 0.6011594533920288, test_acc: 0.843999981880188
# 8/8 [==============================] - 0s 18ms/step - loss: 0.9001 - accuracy: 0.7800
# model name: sfconv_add_6, test loss: 0.9001036882400513, test_acc: 0.7799999713897705
# 8/8 [==============================] - 0s 18ms/step - loss: 0.5426 - accuracy: 0.8500
# model name: sfconv_concat_6, test loss: 0.5425592064857483, test_acc: 0.8500000238418579
# model name: normal_7
# model name: sfconv_add_7
# model name: sfconv_concat_7
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 12:07:07 2020
# [    end time] Sun May 17 12:22:56 2020
# [working time] 948.98 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 12:22:57 2020
# [    end time] Sun May 17 12:39:13 2020
# [working time] 976.53 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 12:39:13 2020
# [    end time] Sun May 17 12:55:29 2020
# [working time] 975.36 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3816 - accuracy: 0.8850
# model name: normal_7, test loss: 0.38161247968673706, test_acc: 0.8849999904632568
# 8/8 [==============================] - 0s 18ms/step - loss: 1.4300 - accuracy: 0.6790
# model name: sfconv_add_7, test loss: 1.4300332069396973, test_acc: 0.6790000200271606
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4068 - accuracy: 0.8940
# model name: sfconv_concat_7, test loss: 0.40682610869407654, test_acc: 0.8939999938011169
# model name: normal_8
# model name: sfconv_add_8
# model name: sfconv_concat_8
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 12:55:31 2020
# [    end time] Sun May 17 13:11:20 2020
# [working time] 948.45 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 13:11:20 2020
# [    end time] Sun May 17 13:27:37 2020
# [working time] 976.90 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 13:27:37 2020
# [    end time] Sun May 17 13:43:58 2020
# [working time] 981.42 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3411 - accuracy: 0.8990
# model name: normal_8, test loss: 0.3410510718822479, test_acc: 0.8989999890327454
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3777 - accuracy: 0.7110
# model name: sfconv_add_8, test loss: 1.3776694536209106, test_acc: 0.7110000252723694
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4290 - accuracy: 0.8750
# model name: sfconv_concat_8, test loss: 0.428981751203537, test_acc: 0.875
# model name: normal_9
# model name: sfconv_add_9
# model name: sfconv_concat_9
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 13:44:01 2020
# [    end time] Sun May 17 13:59:50 2020
# [working time] 948.49 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 13:59:50 2020
# [    end time] Sun May 17 14:16:06 2020
# [working time] 976.24 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Sun May 17 14:16:06 2020
# [    end time] Sun May 17 14:32:28 2020
# [working time] 982.01 (sec)
# 8/8 [==============================] - 0s 17ms/step - loss: 1.0547 - accuracy: 0.7190
# model name: normal_9, test loss: 1.0546783208847046, test_acc: 0.718999981880188
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4492 - accuracy: 0.8680
# model name: sfconv_add_9, test loss: 0.449157178401947, test_acc: 0.8679999709129333
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4261 - accuracy: 0.8790
# model name: sfconv_concat_9, test loss: 0.4260615110397339, test_acc: 0.8790000081062317

# %%
# model_names = [
#                "normal_0", "sfconv_add_0", "sfconv_concat_0"
# ]

# %%
import numpy as np
import os

previous = "20200517_2"
num_models = 3
num_loop = 10
epochs = 500

working_time = np.zeros((num_models, num_loop))
histories = np.zeros((num_models, num_loop, 4, epochs))

for i, model_name in enumerate(model_names):
    history = np.load(os.path.join("/content/drive/My Drive/results", "{}_{}.npz".format(previous, model_name)))

    histories[i % num_models, i // num_models, 0] = history['accuracy']
    histories[i % num_models, i // num_models, 1] = history['val_accuracy']
    histories[i % num_models, i // num_models, 2] = history['loss']
    histories[i % num_models, i // num_models, 3] = history['val_loss']

    working_time[i % num_models, i // num_models] = history['working_time']

# %%
avg_working_time = working_time.mean(axis = 1)
avg_histories = histories.mean(axis = 1)

print(avg_working_time.shape, avg_histories.shape)
# Out:
# (3,) (3, 4, 500)

# %%
for i in range(num_models):
    print("[model_{}] avg working time: {:.2f} sec".format(i, avg_working_time[i]))
# Out:
# [model_0] avg working time: 947.18 sec
# [model_1] avg working time: 975.45 sec
# [model_2] avg working time: 977.49 sec

# %%
def smooth_curve(points, factor = 0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
import matplotlib.pyplot as plt

def plot_histories(avg_histories):
    fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)
    c = ['r', 'g', 'b']
    l = ["--", "-", ":"]
    n = ["without sfconv", "sfconv + add", "sfconv + concat"]

    plt.subplot(1, 2, 1)
    for i, history in enumerate(avg_histories):
        acc = history[0]
        val_acc = history[1]
        plt.plot(np.arange(1, len(val_acc) + 1, 1), 1 - np.array(smooth_curve(val_acc)),
                 color = c[i], label = n[i], alpha = .7, linewidth = 1.5, linestyle = l[i])
    plt.title('Averaged Validation Error')
    plt.xlabel('Epochs')
    plt.ylabel('Error Rate')
    plt.ylim([-0.03, 1.03])
    # plt.yscale('log')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.subplot(1, 2, 2)
    for i, history in enumerate(avg_histories):
        loss = history[2]
        val_loss = history[3]
        plt.plot(np.arange(1, len(val_loss) + 1, 1), smooth_curve(val_loss),
                 color = c[i], label = n[i], alpha = .7, linewidth = 1.5, linestyle = l[i])
    plt.title('Averaged Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True, linewidth = 0.4)

    plt.tight_layout()
    plt.show()

# %%
plot_histories(avg_histories)

# %%
test_labels = np.zeros((1000, 50))
num_labels = 50

# %%
preds = np.zeros((num_models, num_loop, test_labels.shape[0], test_labels.shape[1])) # (3, 10, 1000, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", "{}_{}.npy".format(previous, model_name))) # (1000, 50)
    preds[i % num_models, i // num_models] = pred

# %%
test_errors = np.zeros((num_models, num_loop))

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", "{}_{}.npy".format(previous, model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)
    
    test_errors[i % num_models, i // num_models] = np.sum(np.not_equal(np.argmax(pred, axis = 1), y)) / test_labels.shape[0]

# %%
test_errors
# Out:
# array([[0.112, 0.155, 0.148, 0.128, 0.158, 0.179, 0.156, 0.115, 0.101,
#         0.281],
#        [0.16 , 0.123, 0.09 , 0.111, 0.114, 0.155, 0.22 , 0.321, 0.289,
#         0.132],
#        [0.152, 0.131, 0.152, 0.081, 0.129, 0.147, 0.15 , 0.106, 0.125,
#         0.121]])

# %%
for i in range(num_models):
    print("[model_{}] avg test error: {:.4f}".format(i, test_errors[i].mean()))
# Out:
# [model_0] avg test error: 0.1533
# [model_1] avg test error: 0.1715
# [model_2] avg test error: 0.1294

# %%
cmcs = np.zeros((num_models, num_loop, 50)) # (3, 10, 50)

for i, model_name in enumerate(model_names):
    pred = np.load(os.path.join("/content/drive/My Drive/evals", "{}_{}.npy".format(previous, model_name))) # (1000, 50)
    y = np.array(sorted([i for i in range(num_labels)] * 20)) # (1000)

    a = np.array([sorted(pred[j], reverse = True).index(pred[j, y[j]]) for j in range(len(y))]) # 정답의 순위    
    cmcs[i % num_models, i // num_models] = np.array([len(a[a<=j]) / 1000 for j in range(50)])

# %%
print(cmcs)
# Out:
# [[[0.888 0.955 0.974 ... 1.    1.    1.   ]
#   [0.845 0.924 0.954 ... 1.    1.    1.   ]
#   [0.852 0.931 0.96  ... 1.    1.    1.   ]
#   ...
#   [0.885 0.957 0.976 ... 1.    1.    1.   ]
#   [0.899 0.96  0.98  ... 1.    1.    1.   ]
#   [0.719 0.847 0.913 ... 1.    1.    1.   ]]
#
#  [[0.84  0.921 0.952 ... 1.    1.    1.   ]
#   [0.877 0.948 0.966 ... 1.    1.    1.   ]
#   [0.91  0.962 0.98  ... 1.    1.    1.   ]
#   ...
#   [0.679 0.818 0.869 ... 0.999 0.999 1.   ]
#   [0.711 0.813 0.855 ... 0.999 0.999 1.   ]
#   [0.868 0.95  0.967 ... 1.    1.    1.   ]]
#
#  [[0.848 0.941 0.966 ... 1.    1.    1.   ]
#   [0.869 0.954 0.978 ... 1.    1.    1.   ]
#   [0.848 0.935 0.96  ... 1.    1.    1.   ]
#   ...
#   [0.894 0.948 0.973 ... 1.    1.    1.   ]
#   [0.875 0.954 0.979 ... 1.    1.    1.   ]
#   [0.879 0.951 0.971 ... 1.    1.    1.   ]]]

# %%
avg_cmcs = cmcs.mean(axis = 1)

fig = plt.figure(figsize = (5, 4), facecolor = 'white', dpi = 300)

for i, model_cmc in enumerate(avg_cmcs):
    c = ['r', 'g', 'b']
    l = ["--", "-", ":"]
    n = ["without sfconv", "sfconv + add", "sfconv + concat"]

    plt.plot(np.arange(1, 21, 1), model_cmc[:20],
             color = c[i], label = n[i], alpha = .7, linewidth = 1.5, linestyle = l[i])


plt.title('Averaged Cumulative Match Curve')
plt.xlabel('Rank (k)')
plt.ylabel('Rank-k Error Rate')
plt.xticks([1, 5, 10, 20])
plt.legend()
plt.grid(True, linewidth = 0.4)

plt.tight_layout()
plt.show()

# %%
for i, cmc in enumerate(avg_cmcs):
    print("[model_{}] top 1 error: {:.4f}, top 5 error: {:.4f}".format(i, 1 - cmc[0], 1 - cmc[4]))
# Out:
# [model_0] top 1 error: 0.1533, top 5 error: 0.0192
# [model_1] top 1 error: 0.1715, top 5 error: 0.0311
# [model_2] top 1 error: 0.1294, top 5 error: 0.0148

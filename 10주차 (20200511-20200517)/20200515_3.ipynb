# %% [markdown]
# # **주요 내용**
#
# *   실험

# %%
notebookName = "20200515_3"
notebookName
# Out:
# '20200515_3'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5165610919463667323, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 15422576675727076495
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3109707464368598367
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 554886465406805423
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Fri May 15 11:02:29 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P0    33W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM09752SCY0', 'GSM02544LHS0', 'GSM03321SDK0', 'I4F02631KSM0', 'GSF03732JJH0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 8   # 19,683

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 6561), train_labels.shape: (4000,)
# test_data.shape: (1000, 6561), test_labels.shape: (1000,)

# %% [markdown]
# **train data, validation data 분할 및 전처리 (normalization)**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

def my_split(train_data, train_labels):
    test_size = 0.2

    X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels, test_size = test_size)

    x_train = X_train.reshape(len(X_train), data_length, 1)
    x_val = X_val.reshape(len(X_val), data_length, 1) 

    y_train = to_categorical(Y_train)
    y_val = to_categorical(Y_val)

    # standarization
    mean = x_train.mean()
    x_train -= mean
    std = x_train.std()
    x_train /= std

    x_val -= mean
    x_val /= std

    return x_train, y_train, x_val, y_val, mean, std

# %% [markdown]
# **Build Model**

# %%
def set_params(model):
    for i, layer in enumerate(model.layers):
        if layer.name is "block0_sfconv":
            w = model.layers[i].get_weights()[0] # weight
            b = model.layers[i].get_weights()[1] # bias

            w[0][0][0] = -1
            w[1][0][0] = 1.
            b[0] = 0.

            model.layers[i].set_weights([w, b])

# %%
def build_model_1(model_input):
    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(model_input)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_2(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Add(name = "add")([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_3(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Add(name = "add")([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    set_params(model)
    return model

# %%
def build_model_4(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Concatenate(name = "concatenate", axis = -1)([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    return model

# %%
def build_model_5(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Concatenate(name = "concatenate", axis = -1)([model_input, x])

    # block 1
    x = layers.Conv1D(name = "block1_conv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv1_bn")(x)

    x = layers.ReLU(name = "block1_conv2_act")(x)
    x = layers.Conv1D(name = "block1_conv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_conv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    set_params(model)
    return model

# %%
def build_model_6(model_input):
    # block 0
    x = layers.Conv1D(name = "block0_sfconv", filters = 1, kernel_size = 2, strides = 1, padding = "same")(model_input)
    x = layers.Concatenate(name = "concatenate", axis = -1)([model_input, x])

    # block 1
    x = layers.SeparableConv1D(name = "block1_sepconv1", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_sepconv1_bn")(x)

    x = layers.ReLU(name = "block1_sepconv2_act")(x)
    x = layers.SeparableConv1D(name = "block1_sepconv2", filters = 32, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block1_sepconv2_bn")(x)

    x = layers.MaxPooling1D(name = "block1_pool", pool_size = 3)(x)

    # block 2
    x = layers.ReLU(name = "block2_conv1_act")(x)
    x = layers.Conv1D(name = "block2_conv1", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv1_bn")(x)
    
    x = layers.ReLU(name = "block2_conv2_act")(x)
    x = layers.Conv1D(name = "block2_conv2", filters = 64, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block2_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block2_pool", pool_size = 3)(x)

    # block 3
    x = layers.ReLU(name = "block3_conv1_act")(x)
    x = layers.Conv1D(name = "block3_conv1", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv1_bn")(x)
    
    x = layers.ReLU(name = "block3_conv2_act")(x)
    x = layers.Conv1D(name = "block3_conv2", filters = 128, kernel_size = 3, strides = 1, padding = "same")(x)
    x = layers.BatchNormalization(name = "block3_conv2_bn")(x)    
    
    x = layers.MaxPooling1D(name = "block3_pool", pool_size = 3)(x)

    # out
    x = layers.GlobalAveragePooling1D(name = "avg_pool")(x)
    out = layers.Dense(num_labels, activation = 'softmax', name = "predictions")(x)

    model = Model(model_input, out)
    print("model name: {}".format(model.name))
    set_params(model)
    return model

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers, Input

model_input = Input(shape = (data_length, 1))

# %%
model_1 = build_model_1(model_input)
# Out:
# model name: model

# %%
model_1.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6561, 1)]         0
# _________________________________________________________________
# block1_conv1 (Conv1D)        (None, 6561, 32)          128
# _________________________________________________________________
# block1_conv1_bn (BatchNormal (None, 6561, 32)          128
# _________________________________________________________________
# block1_conv2_act (ReLU)      (None, 6561, 32)          0
# _________________________________________________________________
# block1_conv2 (Conv1D)        (None, 6561, 32)          3104
# _________________________________________________________________
# block1_conv2_bn (BatchNormal (None, 6561, 32)          128
# _________________________________________________________________
# block1_pool (MaxPooling1D)   (None, 2187, 32)          0
# _________________________________________________________________
# block2_conv1_act (ReLU)      (None, 2187, 32)          0
# _________________________________________________________________
# block2_conv1 (Conv1D)        (None, 2187, 64)          6208
# _________________________________________________________________
# block2_conv1_bn (BatchNormal (None, 2187, 64)          256
# _________________________________________________________________
# block2_conv2_act (ReLU)      (None, 2187, 64)          0
# _________________________________________________________________
# block2_conv2 (Conv1D)        (None, 2187, 64)          12352
# _________________________________________________________________
# block2_conv2_bn (BatchNormal (None, 2187, 64)          256
# _________________________________________________________________
# block2_pool (MaxPooling1D)   (None, 729, 64)           0
# _________________________________________________________________
# block3_conv1_act (ReLU)      (None, 729, 64)           0
# _________________________________________________________________
# block3_conv1 (Conv1D)        (None, 729, 128)          24704
# _________________________________________________________________
# block3_conv1_bn (BatchNormal (None, 729, 128)          512
# _________________________________________________________________
# block3_conv2_act (ReLU)      (None, 729, 128)          0
# _________________________________________________________________
# block3_conv2 (Conv1D)        (None, 729, 128)          49280
# _________________________________________________________________
# block3_conv2_bn (BatchNormal (None, 729, 128)          512
# _________________________________________________________________
# block3_pool (MaxPooling1D)   (None, 243, 128)          0
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 128)               0
# _________________________________________________________________
# predictions (Dense)          (None, 50)                6450
# =================================================================
# Total params: 104,018
# Trainable params: 103,122
# Non-trainable params: 896
# _________________________________________________________________

# %%
model_2 = build_model_2(model_input)
# Out:
# model name: model_1

# %%
model_2.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 6561, 1)      0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 6561, 32)     128         add[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 6561, 32)     0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 6561, 32)     3104        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 2187, 32)     0           block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 729, 64)      0           block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 104,021
# Trainable params: 103,125
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model_3 = build_model_3(model_input)
# Out:
# model name: model_2

# %%
model_3.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_1[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 6561, 1)      0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 6561, 32)     128         add[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 6561, 32)     0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 6561, 32)     3104        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 2187, 32)     0           block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 729, 64)      0           block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 104,021
# Trainable params: 103,125
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model_3.layers[1].name
# Out:
# 'block0_sfconv'

# %%
model_3.layers[1].get_weights()
# Out:
# [array([[[-1.]],
#
#         [[ 1.]]], dtype=float32), array([0.], dtype=float32)]

# %%
model_4 = build_model_4(model_input)
# Out:
# model name: model_3

# %%
model_4.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6561, 2)      0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 6561, 32)     224         concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 6561, 32)     0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 6561, 32)     3104        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 2187, 32)     0           block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 729, 64)      0           block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 104,117
# Trainable params: 103,221
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model_5 = build_model_5(model_input)
# Out:
# model name: model_4

# %%
model_5.summary()
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6561, 2)      0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_conv1 (Conv1D)           (None, 6561, 32)     224         concatenate[0][0]
# __________________________________________________________________________________________________
# block1_conv1_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv1[0][0]
# __________________________________________________________________________________________________
# block1_conv2_act (ReLU)         (None, 6561, 32)     0           block1_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_conv2 (Conv1D)           (None, 6561, 32)     3104        block1_conv2_act[0][0]
# __________________________________________________________________________________________________
# block1_conv2_bn (BatchNormaliza (None, 6561, 32)     128         block1_conv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 2187, 32)     0           block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 729, 64)      0           block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 104,117
# Trainable params: 103,221
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
model_6 = build_model_6(model_input)
# Out:
# model name: model_5

# %%
model_6.summary()
# Out:
# Model: "model_5"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6561, 1)]    0
# __________________________________________________________________________________________________
# block0_sfconv (Conv1D)          (None, 6561, 1)      3           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6561, 2)      0           input_1[0][0]
#                                                                  block0_sfconv[0][0]
# __________________________________________________________________________________________________
# block1_sepconv1 (SeparableConv1 (None, 6561, 32)     102         concatenate[0][0]
# __________________________________________________________________________________________________
# block1_sepconv1_bn (BatchNormal (None, 6561, 32)     128         block1_sepconv1[0][0]
# __________________________________________________________________________________________________
# block1_sepconv2_act (ReLU)      (None, 6561, 32)     0           block1_sepconv1_bn[0][0]
# __________________________________________________________________________________________________
# block1_sepconv2 (SeparableConv1 (None, 6561, 32)     1152        block1_sepconv2_act[0][0]
# __________________________________________________________________________________________________
# block1_sepconv2_bn (BatchNormal (None, 6561, 32)     128         block1_sepconv2[0][0]
# __________________________________________________________________________________________________
# block1_pool (MaxPooling1D)      (None, 2187, 32)     0           block1_sepconv2_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv1_act (ReLU)         (None, 2187, 32)     0           block1_pool[0][0]
# __________________________________________________________________________________________________
# block2_conv1 (Conv1D)           (None, 2187, 64)     6208        block2_conv1_act[0][0]
# __________________________________________________________________________________________________
# block2_conv1_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv1[0][0]
# __________________________________________________________________________________________________
# block2_conv2_act (ReLU)         (None, 2187, 64)     0           block2_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block2_conv2 (Conv1D)           (None, 2187, 64)     12352       block2_conv2_act[0][0]
# __________________________________________________________________________________________________
# block2_conv2_bn (BatchNormaliza (None, 2187, 64)     256         block2_conv2[0][0]
# __________________________________________________________________________________________________
# block2_pool (MaxPooling1D)      (None, 729, 64)      0           block2_conv2_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv1_act (ReLU)         (None, 729, 64)      0           block2_pool[0][0]
# __________________________________________________________________________________________________
# block3_conv1 (Conv1D)           (None, 729, 128)     24704       block3_conv1_act[0][0]
# __________________________________________________________________________________________________
# block3_conv1_bn (BatchNormaliza (None, 729, 128)     512         block3_conv1[0][0]
# __________________________________________________________________________________________________
# block3_conv2_act (ReLU)         (None, 729, 128)     0           block3_conv1_bn[0][0]
# __________________________________________________________________________________________________
# block3_conv2 (Conv1D)           (None, 729, 128)     49280       block3_conv2_act[0][0]
# __________________________________________________________________________________________________
# block3_conv2_bn (BatchNormaliza (None, 729, 128)     512         block3_conv2[0][0]
# __________________________________________________________________________________________________
# block3_pool (MaxPooling1D)      (None, 243, 128)     0           block3_conv2_bn[0][0]
# __________________________________________________________________________________________________
# avg_pool (GlobalAveragePooling1 (None, 128)          0           block3_pool[0][0]
# __________________________________________________________________________________________________
# predictions (Dense)             (None, 50)           6450        avg_pool[0][0]
# ==================================================================================================
# Total params: 102,043
# Trainable params: 101,147
# Non-trainable params: 896
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model_1, show_shapes = True, to_file = 'model_1.png')

# %%
plot_model(model_2, show_shapes = True, to_file = 'model_2.png')

# %%
plot_model(model_3, show_shapes = True, to_file = 'model_3.png')

# %%
plot_model(model_4, show_shapes = True, to_file = 'model_4.png')

# %%
plot_model(model_5, show_shapes = True, to_file = 'model_5.png')

# %%
plot_model(model_6, show_shapes = True, to_file = 'model_6.png')

# %% [markdown]
# **Train model**

# %%
import time

def compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs): 
    # compile
    model.compile(optimizer = 'rmsprop',
                  loss = 'categorical_crossentropy',
                  metrics = ['accuracy'])
    
    # train & validate
    print("Train on {} samples, validate on {} samples...".format(x_train.shape[0], x_val.shape[0]))

    start = time.time()
    print("[  start time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    history = model.fit(x_train, y_train,
                        validation_data = (x_val, y_val),
                        epochs = epochs,
                        batch_size = batch_size,
                        verbose = 0)
    end = time.time()
    print("[    end time] {}".format(time.strftime('%c', time.localtime(time.time()))))
    print("[working time] {:.2f} (sec)".format(end - start))

    # save model & results
    save_model_path = "/content/drive/My Drive/models"
    save_results_path = "/content/drive/My Drive/results"

    if not os.path.exists(save_model_path):     os.mkdir(save_model_path)
    if not os.path.exists(save_results_path):   os.mkdir(save_results_path)

    model.save(os.path.join(save_model_path, "{}_{}".format(notebookName, model.name)) + ".h5")
    np.savez_compressed(os.path.join(save_results_path,  "{}_{}".format(notebookName, model.name)),
                        accuracy = history.history['accuracy'],
                        val_accuracy = history.history['val_accuracy'],
                        loss = history.history['loss'],
                        val_loss = history.history['val_loss'])
    
    return history

# %%
batch_size = 128
epochs = 200

models_list, histories_list = [], []
for i in range(5):
    # train test split
    x_train, y_train, x_val, y_val, mean, std = my_split(train_data, train_labels)

    # build & compile & train model
    model_input = Input(shape = (data_length, 1))
    models = [
        build_model_1(model_input),
        build_model_2(model_input),
        build_model_3(model_input),
        build_model_4(model_input),
        build_model_5(model_input),
        build_model_6(model_input),
    ]
    histories = [
        compile_and_train(model, x_train, y_train, x_val, y_val, batch_size, epochs) for model in models
    ]

    # test_data
    test_data = np.load(save_test_data_name + ".npy")
    test_labels = np.load(save_test_labels_name + ".npy")

    test_data = test_data.reshape(len(test_data), data_length, 1)
    test_labels = to_categorical(test_labels)

    # standarization
    test_data -= mean
    test_data /= std 

    # results
    results = [model.evaluate(test_data, test_labels, batch_size = batch_size) for model in models]

    models_list.append(models)
    histories_list.append(histories)
# Out:
# model name: model_6
# model name: model_7
# model name: model_8
# model name: model_9
# model name: model_10
# model name: model_11
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:06:28 2020
# [    end time] Fri May 15 11:12:57 2020
# [working time] 388.59 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:12:57 2020
# [    end time] Fri May 15 11:19:34 2020
# [working time] 397.07 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:19:34 2020
# [    end time] Fri May 15 11:26:11 2020
# [working time] 397.06 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:26:11 2020
# [    end time] Fri May 15 11:32:50 2020
# [working time] 398.82 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:32:50 2020
# [    end time] Fri May 15 11:39:29 2020
# [working time] 398.90 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:39:31 2020
# [    end time] Fri May 15 11:52:07 2020
# [working time] 756.24 (sec)
# 8/8 [==============================] - 0s 25ms/step - loss: 1.1887 - accuracy: 0.7490
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5077 - accuracy: 0.8640
# 8/8 [==============================] - 0s 19ms/step - loss: 13.3504 - accuracy: 0.3780
# 8/8 [==============================] - 0s 20ms/step - loss: 2.1814 - accuracy: 0.6320
# 8/8 [==============================] - 0s 19ms/step - loss: 1.3067 - accuracy: 0.7130
# 8/8 [==============================] - 0s 22ms/step - loss: 0.5053 - accuracy: 0.8620
# model name: model_12
# model name: model_13
# model name: model_14
# model name: model_15
# model name: model_16
# model name: model_17
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:52:13 2020
# [    end time] Fri May 15 11:58:36 2020
# [working time] 382.80 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 11:58:38 2020
# [    end time] Fri May 15 12:05:14 2020
# [working time] 396.36 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:05:15 2020
# [    end time] Fri May 15 12:11:52 2020
# [working time] 397.10 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:11:55 2020
# [    end time] Fri May 15 12:18:34 2020
# [working time] 399.29 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:18:35 2020
# [    end time] Fri May 15 12:25:14 2020
# [working time] 398.99 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:25:14 2020
# [    end time] Fri May 15 12:37:48 2020
# [working time] 754.08 (sec)
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7066 - accuracy: 0.8130
# 8/8 [==============================] - 0s 19ms/step - loss: 0.3883 - accuracy: 0.8990
# 8/8 [==============================] - 0s 19ms/step - loss: 1.2051 - accuracy: 0.7600
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6631 - accuracy: 0.8310
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5214 - accuracy: 0.8330
# 8/8 [==============================] - 0s 20ms/step - loss: 2.2579 - accuracy: 0.6820
# model name: model_18
# model name: model_19
# model name: model_20
# model name: model_21
# model name: model_22
# model name: model_23
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:37:52 2020
# [    end time] Fri May 15 12:44:18 2020
# [working time] 385.72 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:44:18 2020
# [    end time] Fri May 15 12:50:56 2020
# [working time] 397.53 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:50:56 2020
# [    end time] Fri May 15 12:57:30 2020
# [working time] 393.94 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 12:57:30 2020
# [    end time] Fri May 15 13:04:09 2020
# [working time] 398.69 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:04:09 2020
# [    end time] Fri May 15 13:10:48 2020
# [working time] 399.11 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:10:48 2020
# [    end time] Fri May 15 13:23:22 2020
# [working time] 754.42 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 3.3266 - accuracy: 0.5320
# 8/8 [==============================] - 0s 19ms/step - loss: 1.2324 - accuracy: 0.7310
# 8/8 [==============================] - 0s 18ms/step - loss: 7.7937 - accuracy: 0.4410
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1753 - accuracy: 0.7760
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5412 - accuracy: 0.8480
# 8/8 [==============================] - 0s 20ms/step - loss: 3.2235 - accuracy: 0.6000
# model name: model_24
# model name: model_25
# model name: model_26
# model name: model_27
# model name: model_28
# model name: model_29
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:23:26 2020
# [    end time] Fri May 15 13:29:51 2020
# [working time] 384.74 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:29:51 2020
# [    end time] Fri May 15 13:36:27 2020
# [working time] 396.17 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:36:28 2020
# [    end time] Fri May 15 13:43:04 2020
# [working time] 396.73 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:43:04 2020
# [    end time] Fri May 15 13:49:43 2020
# [working time] 398.56 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:49:43 2020
# [    end time] Fri May 15 13:56:22 2020
# [working time] 398.73 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 13:56:22 2020
# [    end time] Fri May 15 14:08:58 2020
# [working time] 755.57 (sec)
# 8/8 [==============================] - 0s 18ms/step - loss: 1.8433 - accuracy: 0.6910
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4486 - accuracy: 0.8720
# 8/8 [==============================] - 0s 19ms/step - loss: 2.7918 - accuracy: 0.5500
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6934 - accuracy: 0.8270
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9213 - accuracy: 0.8060
# 8/8 [==============================] - 0s 20ms/step - loss: 0.7886 - accuracy: 0.8020
# model name: model_30
# model name: model_31
# model name: model_32
# model name: model_33
# model name: model_34
# model name: model_35
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 14:09:02 2020
# [    end time] Fri May 15 14:15:28 2020
# [working time] 386.01 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 14:15:28 2020
# [    end time] Fri May 15 14:22:03 2020
# [working time] 394.88 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 14:22:03 2020
# [    end time] Fri May 15 14:28:40 2020
# [working time] 397.33 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 14:28:41 2020
# [    end time] Fri May 15 14:35:19 2020
# [working time] 398.29 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 14:35:19 2020
# [    end time] Fri May 15 14:41:58 2020
# [working time] 398.93 (sec)
# Train on 3200 samples, validate on 800 samples...
# [  start time] Fri May 15 14:41:58 2020
# [    end time] Fri May 15 14:54:34 2020
# [working time] 756.34 (sec)
# 8/8 [==============================] - 0s 19ms/step - loss: 1.3761 - accuracy: 0.6800
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4097 - accuracy: 0.8810
# 8/8 [==============================] - 0s 20ms/step - loss: 16.0406 - accuracy: 0.3410
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5747 - accuracy: 0.8480
# 8/8 [==============================] - 0s 19ms/step - loss: 1.3564 - accuracy: 0.7170
# 8/8 [==============================] - 0s 21ms/step - loss: 1.1248 - accuracy: 0.7600

# %% [markdown]
# **지수이동평균 계산 및 결과 출력**

# %%
def smooth_curve(points, factor = 0.9):
    smoothed_points = []
    for point in points:
        if smoothed_points:
            previous = smoothed_points[-1]
            smoothed_points.append(previous * factor + point * (1 - factor))
        else:
            smoothed_points.append(point)
    return smoothed_points

# %%
result = np.zeros((5, 6, 4, 200))
for i, histories in enumerate(histories_list):
    for j, history in enumerate(histories):
        result[i, j, 0, :] = history.history['accuracy']
        result[i, j, 1, :] = history.history['val_accuracy']
        result[i, j, 2, :] = history.history['loss']
        result[i, j, 3, :] = history.history['val_loss']

# %%
result = result.mean(axis = 0)

# %%
result.shape
# Out:
# (6, 4, 200)

# %%
import matplotlib.pyplot as plt

def plot_histories(result):
    fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)
    c = ['r', 'g', 'b', 'c', 'k', 'm']
    n = ['model_{}'.format(i) for i in range(1, 7, 1)]

    plt.subplot(1, 2, 1)
    for i, history in enumerate(histories):
        acc = result[i, 0]
        val_acc = result[i, 1]
        plt.plot(np.arange(1, len(val_acc) + 1, 1), np.array(smooth_curve(val_acc)), color = c[i], label = n[i], alpha = .7)
    plt.title('Validation accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('accuracy')
    # plt.yscale('log')
    plt.legend()

    plt.subplot(1, 2, 2)
    for i, history in enumerate(histories):
        loss = result[i, 2]
        val_loss = result[i, 3]
        plt.plot(np.arange(1, len(val_loss) + 1, 1), smooth_curve(val_loss), color = c[i], label = n[i], alpha = .7)
    plt.title('Validation loss')
    plt.xlabel('Epochs')
    plt.ylabel('loss')
    plt.legend(loc = 'upper right')

    plt.tight_layout()
    plt.show()

# %%
plot_histories(result)

# %%
np.array(models_list).shape
# Out:
# (5, 6)

# %%
preds = np.array([[models_list[i][j].evaluate(test_data, test_labels, batch_size = batch_size) for j in range(6)] for i in range(5)])
# Out:
# 8/8 [==============================] - 0s 19ms/step - loss: 1.2031 - accuracy: 0.7460
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5100 - accuracy: 0.8610
# 8/8 [==============================] - 0s 19ms/step - loss: 13.4254 - accuracy: 0.3770
# 8/8 [==============================] - 0s 19ms/step - loss: 2.1921 - accuracy: 0.6330
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3080 - accuracy: 0.7120
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5064 - accuracy: 0.8610
# 8/8 [==============================] - 0s 18ms/step - loss: 0.6997 - accuracy: 0.8170
# 8/8 [==============================] - 0s 18ms/step - loss: 0.3882 - accuracy: 0.8960
# 8/8 [==============================] - 0s 19ms/step - loss: 1.2209 - accuracy: 0.7590
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6722 - accuracy: 0.8280
# 8/8 [==============================] - 0s 20ms/step - loss: 0.5197 - accuracy: 0.8340
# 8/8 [==============================] - 0s 20ms/step - loss: 2.2803 - accuracy: 0.6810
# 8/8 [==============================] - 0s 19ms/step - loss: 3.3571 - accuracy: 0.5280
# 8/8 [==============================] - 0s 18ms/step - loss: 1.2649 - accuracy: 0.7270
# 8/8 [==============================] - 0s 19ms/step - loss: 7.8872 - accuracy: 0.4350
# 8/8 [==============================] - 0s 19ms/step - loss: 1.1999 - accuracy: 0.7710
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5542 - accuracy: 0.8470
# 8/8 [==============================] - 0s 20ms/step - loss: 3.2617 - accuracy: 0.5990
# 8/8 [==============================] - 0s 19ms/step - loss: 1.8458 - accuracy: 0.6910
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4491 - accuracy: 0.8720
# 8/8 [==============================] - 0s 19ms/step - loss: 2.7916 - accuracy: 0.5490
# 8/8 [==============================] - 0s 19ms/step - loss: 0.6930 - accuracy: 0.8270
# 8/8 [==============================] - 0s 19ms/step - loss: 0.9232 - accuracy: 0.8060
# 8/8 [==============================] - 0s 19ms/step - loss: 0.7894 - accuracy: 0.8020
# 8/8 [==============================] - 0s 18ms/step - loss: 1.3761 - accuracy: 0.6800
# 8/8 [==============================] - 0s 19ms/step - loss: 0.4097 - accuracy: 0.8810
# 8/8 [==============================] - 0s 19ms/step - loss: 16.0406 - accuracy: 0.3410
# 8/8 [==============================] - 0s 19ms/step - loss: 0.5747 - accuracy: 0.8480
# 8/8 [==============================] - 0s 19ms/step - loss: 1.3564 - accuracy: 0.7170
# 8/8 [==============================] - 0s 20ms/step - loss: 1.1248 - accuracy: 0.7600

# %%
preds.shape
# Out:
# (5, 6, 2)

# %%
for i in range(6):
    print("[model_{}] test loss: {:.4f}, test acc: {:.4f}".format(i+1, preds.mean(axis = 0)[i, 0], preds.mean(axis = 0)[i, 1]))
# Out:
# [model_1] test loss: 1.6963, test acc: 0.6924
# [model_2] test loss: 0.6044, test acc: 0.8474
# [model_3] test loss: 8.2732, test acc: 0.4922
# [model_4] test loss: 1.0664, test acc: 0.7814
# [model_5] test loss: 0.9323, test acc: 0.7832
# [model_6] test loss: 1.5925, test acc: 0.7406

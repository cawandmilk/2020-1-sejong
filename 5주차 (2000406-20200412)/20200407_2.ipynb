# %% [markdown]
# # **주요 내용**
# data length : 16,000 (sampling rate * duration) → 19,683 (3^9)
#
# (변경 이유: 논문에서 입력값을 3의 배수로 맞춘다음, max_pooling을 통해 size를 1/3으로 줄이고 있어서 따라해봄)
#
# 성능은 그럭저럭... (별로 좋아진 것 같지는 않음)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0-rc2'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15116018496487716381, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 12025300930074778485
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 3375112275019540036
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701463552
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 3185938831219911159
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Tue Apr  7 15:30:18 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P0    33W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM06044JBY0', 'GSM05953CJH0', 'GSF06934SYN0', 'GSF03732JJH0', 'GSM07355MIW0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)

# print samples
print(os.listdir(wav_path)[:5])
print(len(os.listdir(wav_path)))
# Out:
# ['28_87.wav', '9_64.wav', '24_79.wav', '28_59.wav', '2_34.wav']
# 5000

# %%
import numpy as np

num_labels = 50
num_features = 100
data_length = 3 ** 9
# sr = 16000
# duration = 1

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        # start = int(len(samples)//2 - duration * sample_rate / 2)
        # end = int(len(samples)//2 + duration * sample_rate / 2)

        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 19683), train_labels.shape: (4000,)
# test_data.shape: (1000, 19683), test_labels.shape: (1000,)

# %% [markdown]
# **train data, validation data 분할 및 전처리 (normalization)**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

random_state = 1234
test_size = 0.2

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels,
                                                  test_size = test_size,
                                                  random_state = random_state) # fixed

x_train = X_train.reshape(len(X_train), data_length, 1)
x_val = X_val.reshape(len(X_val), data_length, 1) 

y_train = to_categorical(Y_train)
y_val = to_categorical(Y_val)

# standarization
mean = x_train.mean()
x_train -= mean
std = x_train.std()
x_train /= std

x_val -= mean
x_val /= std 

print("test_size: {}, random_state: {}\n".format(test_size, random_state))
print('x_train.shape: {}, y_train.shape: {}'.format(x_train.shape, y_train.shape))
print('x_val.shape: {}, y_val.shape: {}'.format(x_val.shape, y_val.shape))
# Out:
# test_size: 0.2, random_state: 1234
#
# x_train.shape: (3200, 19683, 1), y_train.shape: (3200, 50)
# x_val.shape: (800, 19683, 1), y_val.shape: (800, 50)

# %% [markdown]
# **Build Model (pre-emphasis 적용 x)**

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model

model = Sequential()

# pre-emphasis
# model.add(layers.Conv1D(filters = data_length, kernel_size = 2, strides = 1, 
#                         padding = "same", activation = 'relu', input_shape = (data_length, 1)))
# model.add(layers.MaxPooling1D(3))
# model.add(layers.BatchNormalization())

# convolutional layer (4 blocks)
model.add(layers.Conv1D(filters = 128, kernel_size = 3, strides = 1, 
                        padding = "same", activation = 'relu', input_shape = (data_length, 1)))
model.add(layers.MaxPooling1D(3))
model.add(layers.BatchNormalization())

model.add(layers.Conv1D(filters = 128, kernel_size = 3, strides = 1,
                        padding = "same", activation = 'relu'))
model.add(layers.MaxPooling1D(3))
model.add(layers.BatchNormalization())

model.add(layers.Conv1D(filters = 128, kernel_size = 3, strides = 1,
                        padding = "same", activation = 'relu'))
model.add(layers.MaxPooling1D(3))
model.add(layers.BatchNormalization())

model.add(layers.Conv1D(filters = 128, kernel_size = 3, strides = 1,
                        padding = "same", activation = 'relu'))
model.add(layers.MaxPooling1D(3))
model.add(layers.BatchNormalization())

# mapping from (81, 128) to 128 by GlobalAveragePooling1D()
model.add(layers.GlobalAveragePooling1D())
model.add(layers.Dense(num_labels, activation = 'softmax'))

model.compile(optimizer = 'rmsprop',
              loss = 'categorical_crossentropy',
              metrics = ['accuracy'])

model.summary()
# plot_model(model, show_shapes = True, to_file = 'model.png')
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_46 (Conv1D)           (None, 19683, 128)        512
# _________________________________________________________________
# max_pooling1d_46 (MaxPooling (None, 6561, 128)         0
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 6561, 128)         512
# _________________________________________________________________
# conv1d_47 (Conv1D)           (None, 6561, 128)         49280
# _________________________________________________________________
# max_pooling1d_47 (MaxPooling (None, 2187, 128)         0
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 2187, 128)         512
# _________________________________________________________________
# conv1d_48 (Conv1D)           (None, 2187, 128)         49280
# _________________________________________________________________
# max_pooling1d_48 (MaxPooling (None, 729, 128)          0
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 729, 128)          512
# _________________________________________________________________
# conv1d_49 (Conv1D)           (None, 729, 128)          49280
# _________________________________________________________________
# max_pooling1d_49 (MaxPooling (None, 243, 128)          0
# _________________________________________________________________
# batch_normalization_49 (Batc (None, 243, 128)          512
# _________________________________________________________________
# global_average_pooling1d_10  (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 50)                6450
# =================================================================
# Total params: 156,850
# Trainable params: 155,826
# Non-trainable params: 1,024
# _________________________________________________________________

# %% [markdown]
# **첫 번째 convolutional layer인 pre-emphasis layer의 가중치 초기값 설정**

# %%
weight = np.zeros((2, 1, data_length))

# %% [markdown]
# **모델 훈련 및 저장**

# %%
from datetime import datetime

batch_size = 80
epochs = 100

history = model.fit(x_train, y_train,
                    validation_data = (x_val, y_val),
                    epochs = epochs,
                    batch_size = batch_size,
                    verbose = 2)
# Out:
# Epoch 1/100
# 40/40 - 6s - loss: 2.6484 - accuracy: 0.3866 - val_loss: 3.8095 - val_accuracy: 0.0312
# Epoch 2/100
# 40/40 - 6s - loss: 1.8088 - accuracy: 0.6466 - val_loss: 4.0235 - val_accuracy: 0.0213
# Epoch 3/100
# 40/40 - 6s - loss: 1.4014 - accuracy: 0.7678 - val_loss: 4.4478 - val_accuracy: 0.0325
# Epoch 4/100
# 40/40 - 6s - loss: 1.1079 - accuracy: 0.8228 - val_loss: 5.3082 - val_accuracy: 0.0325
# Epoch 5/100
# 40/40 - 6s - loss: 0.8996 - accuracy: 0.8606 - val_loss: 5.7013 - val_accuracy: 0.0350
# Epoch 6/100
# 40/40 - 6s - loss: 0.7445 - accuracy: 0.8828 - val_loss: 6.0719 - val_accuracy: 0.0487
# Epoch 7/100
# 40/40 - 6s - loss: 0.6338 - accuracy: 0.8916 - val_loss: 6.2700 - val_accuracy: 0.0763
# Epoch 8/100
# 40/40 - 6s - loss: 0.5263 - accuracy: 0.9203 - val_loss: 6.0951 - val_accuracy: 0.0725
# Epoch 9/100
# 40/40 - 6s - loss: 0.4621 - accuracy: 0.9225 - val_loss: 6.2623 - val_accuracy: 0.0487
# Epoch 10/100
# 40/40 - 6s - loss: 0.3968 - accuracy: 0.9316 - val_loss: 5.1001 - val_accuracy: 0.0763
# Epoch 11/100
# 40/40 - 6s - loss: 0.3453 - accuracy: 0.9400 - val_loss: 4.7991 - val_accuracy: 0.0962
# Epoch 12/100
# 40/40 - 6s - loss: 0.3094 - accuracy: 0.9472 - val_loss: 3.6804 - val_accuracy: 0.1800
# Epoch 13/100
# 40/40 - 6s - loss: 0.2631 - accuracy: 0.9531 - val_loss: 2.4316 - val_accuracy: 0.3425
# Epoch 14/100
# 40/40 - 6s - loss: 0.2388 - accuracy: 0.9569 - val_loss: 1.9750 - val_accuracy: 0.5200
# Epoch 15/100
# 40/40 - 6s - loss: 0.2167 - accuracy: 0.9625 - val_loss: 1.3256 - val_accuracy: 0.6250
# Epoch 16/100
# 40/40 - 6s - loss: 0.1901 - accuracy: 0.9647 - val_loss: 0.8674 - val_accuracy: 0.7387
# Epoch 17/100
# 40/40 - 6s - loss: 0.1683 - accuracy: 0.9706 - val_loss: 0.4131 - val_accuracy: 0.8838
# Epoch 18/100
# 40/40 - 6s - loss: 0.1540 - accuracy: 0.9744 - val_loss: 0.3795 - val_accuracy: 0.8800
# Epoch 19/100
# 40/40 - 6s - loss: 0.1403 - accuracy: 0.9759 - val_loss: 0.8171 - val_accuracy: 0.7450
# Epoch 20/100
# 40/40 - 6s - loss: 0.1386 - accuracy: 0.9750 - val_loss: 0.2255 - val_accuracy: 0.9325
# Epoch 21/100
# 40/40 - 6s - loss: 0.1134 - accuracy: 0.9809 - val_loss: 0.4589 - val_accuracy: 0.8537
# Epoch 22/100
# 40/40 - 6s - loss: 0.1039 - accuracy: 0.9816 - val_loss: 0.2400 - val_accuracy: 0.9400
# Epoch 23/100
# 40/40 - 6s - loss: 0.0928 - accuracy: 0.9869 - val_loss: 0.4906 - val_accuracy: 0.8450
# Epoch 24/100
# 40/40 - 6s - loss: 0.0873 - accuracy: 0.9875 - val_loss: 0.4722 - val_accuracy: 0.8575
# Epoch 25/100
# 40/40 - 6s - loss: 0.0834 - accuracy: 0.9872 - val_loss: 0.4405 - val_accuracy: 0.8438
# Epoch 26/100
# 40/40 - 6s - loss: 0.0692 - accuracy: 0.9878 - val_loss: 0.5233 - val_accuracy: 0.8475
# Epoch 27/100
# 40/40 - 6s - loss: 0.0643 - accuracy: 0.9887 - val_loss: 0.7987 - val_accuracy: 0.7650
# Epoch 28/100
# 40/40 - 6s - loss: 0.0619 - accuracy: 0.9887 - val_loss: 0.4453 - val_accuracy: 0.8525
# Epoch 29/100
# 40/40 - 6s - loss: 0.0562 - accuracy: 0.9894 - val_loss: 0.1804 - val_accuracy: 0.9513
# Epoch 30/100
# 40/40 - 6s - loss: 0.0540 - accuracy: 0.9912 - val_loss: 1.3464 - val_accuracy: 0.7325
# Epoch 31/100
# 40/40 - 6s - loss: 0.0523 - accuracy: 0.9919 - val_loss: 0.1122 - val_accuracy: 0.9725
# Epoch 32/100
# 40/40 - 6s - loss: 0.0463 - accuracy: 0.9922 - val_loss: 0.8284 - val_accuracy: 0.7675
# Epoch 33/100
# 40/40 - 6s - loss: 0.0450 - accuracy: 0.9934 - val_loss: 0.2077 - val_accuracy: 0.9388
# Epoch 34/100
# 40/40 - 6s - loss: 0.0390 - accuracy: 0.9934 - val_loss: 0.1566 - val_accuracy: 0.9538
# Epoch 35/100
# 40/40 - 6s - loss: 0.0371 - accuracy: 0.9944 - val_loss: 0.2086 - val_accuracy: 0.9438
# Epoch 36/100
# 40/40 - 6s - loss: 0.0323 - accuracy: 0.9950 - val_loss: 0.0828 - val_accuracy: 0.9787
# Epoch 37/100
# 40/40 - 6s - loss: 0.0312 - accuracy: 0.9962 - val_loss: 0.5181 - val_accuracy: 0.8350
# Epoch 38/100
# 40/40 - 6s - loss: 0.0369 - accuracy: 0.9937 - val_loss: 1.5156 - val_accuracy: 0.6413
# Epoch 39/100
# 40/40 - 6s - loss: 0.0241 - accuracy: 0.9972 - val_loss: 0.2304 - val_accuracy: 0.9287
# Epoch 40/100
# 40/40 - 6s - loss: 0.0273 - accuracy: 0.9944 - val_loss: 0.2273 - val_accuracy: 0.9388
# Epoch 41/100
# 40/40 - 6s - loss: 0.0232 - accuracy: 0.9962 - val_loss: 6.2324 - val_accuracy: 0.3462
# Epoch 42/100
# 40/40 - 6s - loss: 0.0211 - accuracy: 0.9962 - val_loss: 0.4115 - val_accuracy: 0.8662
# Epoch 43/100
# 40/40 - 6s - loss: 0.0314 - accuracy: 0.9944 - val_loss: 0.5081 - val_accuracy: 0.8625
# Epoch 44/100
# 40/40 - 6s - loss: 0.0144 - accuracy: 0.9994 - val_loss: 0.3308 - val_accuracy: 0.9000
# Epoch 45/100
# 40/40 - 6s - loss: 0.0270 - accuracy: 0.9953 - val_loss: 1.5164 - val_accuracy: 0.6575
# Epoch 46/100
# 40/40 - 6s - loss: 0.0160 - accuracy: 0.9975 - val_loss: 0.0826 - val_accuracy: 0.9737
# Epoch 47/100
# 40/40 - 6s - loss: 0.0198 - accuracy: 0.9962 - val_loss: 0.1626 - val_accuracy: 0.9425
# Epoch 48/100
# 40/40 - 6s - loss: 0.0145 - accuracy: 0.9972 - val_loss: 0.1139 - val_accuracy: 0.9600
# Epoch 49/100
# 40/40 - 6s - loss: 0.0182 - accuracy: 0.9966 - val_loss: 0.0734 - val_accuracy: 0.9787
# Epoch 50/100
# 40/40 - 6s - loss: 0.0220 - accuracy: 0.9956 - val_loss: 0.0695 - val_accuracy: 0.9800
# Epoch 51/100
# 40/40 - 6s - loss: 0.0130 - accuracy: 0.9981 - val_loss: 0.1403 - val_accuracy: 0.9550
# Epoch 52/100
# 40/40 - 6s - loss: 0.0123 - accuracy: 0.9984 - val_loss: 0.0807 - val_accuracy: 0.9800
# Epoch 53/100
# 40/40 - 6s - loss: 0.0185 - accuracy: 0.9959 - val_loss: 0.2566 - val_accuracy: 0.9225
# Epoch 54/100
# 40/40 - 6s - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.6200 - val_accuracy: 0.8163
# Epoch 55/100
# 40/40 - 6s - loss: 0.0119 - accuracy: 0.9978 - val_loss: 0.1093 - val_accuracy: 0.9638
# Epoch 56/100
# 40/40 - 6s - loss: 0.0129 - accuracy: 0.9984 - val_loss: 0.6551 - val_accuracy: 0.8100
# Epoch 57/100
# 40/40 - 6s - loss: 0.0101 - accuracy: 0.9975 - val_loss: 0.0733 - val_accuracy: 0.9762
# Epoch 58/100
# 40/40 - 6s - loss: 0.0125 - accuracy: 0.9981 - val_loss: 0.1350 - val_accuracy: 0.9575
# Epoch 59/100
# 40/40 - 6s - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.1507 - val_accuracy: 0.9525
# Epoch 60/100
# 40/40 - 6s - loss: 0.0086 - accuracy: 0.9984 - val_loss: 0.2966 - val_accuracy: 0.9175
# Epoch 61/100
# 40/40 - 6s - loss: 0.0147 - accuracy: 0.9966 - val_loss: 0.1573 - val_accuracy: 0.9488
# Epoch 62/100
# 40/40 - 6s - loss: 0.0090 - accuracy: 0.9984 - val_loss: 1.1388 - val_accuracy: 0.7225
# Epoch 63/100
# 40/40 - 6s - loss: 0.0088 - accuracy: 0.9984 - val_loss: 0.1026 - val_accuracy: 0.9675
# Epoch 64/100
# 40/40 - 6s - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.1042 - val_accuracy: 0.9675
# Epoch 65/100
# 40/40 - 6s - loss: 0.0057 - accuracy: 0.9994 - val_loss: 0.4189 - val_accuracy: 0.8775
# Epoch 66/100
# 40/40 - 6s - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.1185 - val_accuracy: 0.9600
# Epoch 67/100
# 40/40 - 6s - loss: 0.0080 - accuracy: 0.9987 - val_loss: 0.1056 - val_accuracy: 0.9650
# Epoch 68/100
# 40/40 - 6s - loss: 0.0078 - accuracy: 0.9981 - val_loss: 0.2090 - val_accuracy: 0.9388
# Epoch 69/100
# 40/40 - 6s - loss: 0.0043 - accuracy: 0.9994 - val_loss: 0.2198 - val_accuracy: 0.9425
# Epoch 70/100
# 40/40 - 6s - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.3360 - val_accuracy: 0.8950
# Epoch 71/100
# 40/40 - 6s - loss: 0.0038 - accuracy: 0.9994 - val_loss: 0.2418 - val_accuracy: 0.9337
# Epoch 72/100
# 40/40 - 6s - loss: 0.0103 - accuracy: 0.9975 - val_loss: 0.2501 - val_accuracy: 0.9200
# Epoch 73/100
# 40/40 - 6s - loss: 0.0065 - accuracy: 0.9991 - val_loss: 1.8052 - val_accuracy: 0.6575
# Epoch 74/100
# 40/40 - 6s - loss: 0.0087 - accuracy: 0.9987 - val_loss: 0.1537 - val_accuracy: 0.9475
# Epoch 75/100
# 40/40 - 6s - loss: 0.0031 - accuracy: 0.9997 - val_loss: 0.0833 - val_accuracy: 0.9762
# Epoch 76/100
# 40/40 - 6s - loss: 0.0043 - accuracy: 0.9987 - val_loss: 0.1916 - val_accuracy: 0.9438
# Epoch 77/100
# 40/40 - 6s - loss: 0.0035 - accuracy: 0.9994 - val_loss: 1.4333 - val_accuracy: 0.6812
# Epoch 78/100
# 40/40 - 6s - loss: 0.0022 - accuracy: 0.9997 - val_loss: 0.0956 - val_accuracy: 0.9737
# Epoch 79/100
# 40/40 - 6s - loss: 0.0111 - accuracy: 0.9978 - val_loss: 0.0640 - val_accuracy: 0.9800
# Epoch 80/100
# 40/40 - 6s - loss: 0.0024 - accuracy: 0.9991 - val_loss: 0.1729 - val_accuracy: 0.9450
# Epoch 81/100
# 40/40 - 6s - loss: 0.0074 - accuracy: 0.9984 - val_loss: 0.9351 - val_accuracy: 0.7925
# Epoch 82/100
# 40/40 - 6s - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.5763 - val_accuracy: 0.8350
# Epoch 83/100
# 40/40 - 6s - loss: 0.0075 - accuracy: 0.9981 - val_loss: 0.1692 - val_accuracy: 0.9488
# Epoch 84/100
# 40/40 - 6s - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1263 - val_accuracy: 0.9625
# Epoch 85/100
# 40/40 - 6s - loss: 0.0066 - accuracy: 0.9981 - val_loss: 0.0743 - val_accuracy: 0.9775
# Epoch 86/100
# 40/40 - 6s - loss: 7.0032e-04 - accuracy: 1.0000 - val_loss: 0.0394 - val_accuracy: 0.9900
# Epoch 87/100
# 40/40 - 6s - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.1779 - val_accuracy: 0.9388
# Epoch 88/100
# 40/40 - 6s - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.2257 - val_accuracy: 0.9450
# Epoch 89/100
# 40/40 - 6s - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.4512 - val_accuracy: 0.8775
# Epoch 90/100
# 40/40 - 6s - loss: 0.0018 - accuracy: 0.9994 - val_loss: 0.2984 - val_accuracy: 0.9000
# Epoch 91/100
# 40/40 - 6s - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.0938 - val_accuracy: 0.9725
# Epoch 92/100
# 40/40 - 6s - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0532 - val_accuracy: 0.9837
# Epoch 93/100
# 40/40 - 6s - loss: 0.0048 - accuracy: 0.9997 - val_loss: 0.1927 - val_accuracy: 0.9463
# Epoch 94/100
# 40/40 - 6s - loss: 0.0064 - accuracy: 0.9984 - val_loss: 0.1132 - val_accuracy: 0.9638
# Epoch 95/100
# 40/40 - 6s - loss: 0.0083 - accuracy: 0.9966 - val_loss: 1.4880 - val_accuracy: 0.7200
# Epoch 96/100
# 40/40 - 6s - loss: 6.6184e-04 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 0.9712
# Epoch 97/100
# 40/40 - 6s - loss: 0.0031 - accuracy: 0.9994 - val_loss: 0.2158 - val_accuracy: 0.9375
# Epoch 98/100
# 40/40 - 6s - loss: 0.0086 - accuracy: 0.9987 - val_loss: 0.0978 - val_accuracy: 0.9712
# Epoch 99/100
# 40/40 - 6s - loss: 8.9362e-04 - accuracy: 1.0000 - val_loss: 0.1441 - val_accuracy: 0.9650
# Epoch 100/100
# 40/40 - 6s - loss: 0.0030 - accuracy: 0.9987 - val_loss: 1.1163 - val_accuracy: 0.8037

# %% [markdown]
# **모델 및 결과 저장**

# %%
def history_to_numpy(history):
    title = list(history.history.keys())
    history_npy = np.array(title + [history.history[t] for t in title])

    print(title)

    return history_npy

save_model_path = "/content/drive/My Drive/models" # save to my drive
if not os.path.exists(save_model_path):
    os.mkdir(save_model_path)

save_results_path = "/content/drive/My Drive/results"
if not os.path.exists(save_results_path):
    os.mkdir(save_results_path)

save_file_name = "{}".format(datetime.today().strftime("%Y_%m_%d_%H_%M_%S"))
model.save(os.path.join(save_model_path, "{}.h5".format(save_file_name)))
np.save(os.path.join(save_model_path, "{}.npy".format(save_file_name)), history_to_numpy(history))
# Out:
# ['loss', 'accuracy', 'val_loss', 'val_accuracy']

# %% [markdown]
# **히스토리 출력**

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)

# accuracy
plt.subplot(1, 2, 1)

plt.plot(range(1, epochs + 1), acc, 'bo', label = 'Trianing accuracy of model')
plt.plot(range(1, epochs + 1), val_acc, 'b', label = 'Validation accuracy of model')
plt.title('train and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()

# loss
plt.subplot(1, 2, 2)

plt.plot(range(1, epochs + 1), loss, 'bo', label = 'Trianing loss of model')
plt.plot(range(1, epochs + 1), val_loss, 'b', label = 'Validation loss of model')
plt.title('train and validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **test data를 통해 모델 최종 평가 (field test)**

# %%
# reshaping
del test_data, test_labels

test_data = np.load(save_test_data_name + ".npy")
test_labels = np.load(save_test_labels_name + ".npy")

test_data = test_data.reshape(len(test_data), data_length, 1)
test_labels = to_categorical(test_labels)

# standarization
test_data -= mean
test_data /= std 

print('test_data.shape: {}, test_labels.shape: {}'.format(test_data.shape, test_labels.shape))
# Out:
# test_data.shape: (1000, 19683, 1), test_labels.shape: (1000, 50)

# %%
results = model.evaluate(test_data, test_labels, batch_size = batch_size)

print('test loss, test acc:', results)
# Out:
# 13/13 [==============================] - 1s 48ms/step - loss: 0.8688 - accuracy: 0.8420
# test loss, test acc: [0.8688259124755859, 0.8420000076293945]

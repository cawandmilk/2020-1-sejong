# %% [markdown]
# # **주요 내용**
# 모델 가중치 확인

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0-rc2'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4604425659946341031, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 9337570312051187521
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 10399866857844995850
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 11150726272
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 18286358532262698594
#  physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Tue Apr  7 12:28:51 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.64.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0    70W / 149W |    130MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **파일 압축 해제 (드라이브에는 *.zip 파일 형식으로 저장되어 있음)**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path):
    os.mkdir(pcm_path)

if not os.path.exists(wav_path):
    os.mkdir(wav_path)

# unzip with quite mode (-q options)
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSM06044JBY0', 'GSM05953CJH0', 'GSF06934SYN0', 'GSF03732JJH0', 'GSM07355MIW0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))): # sorted!!!
    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)): # sorted!!!
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)

# print samples
print(os.listdir(wav_path)[:5])
print(len(os.listdir(wav_path)))
# Out:
# ['28_87.wav', '9_64.wav', '24_79.wav', '28_59.wav', '2_34.wav']
# 5000

# %%
import numpy as np

num_labels = 50
num_features = 100
sr = 16000
duration = 1

train_rate = 0.8
num_train_data = int(num_features * train_rate) # 80

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# naming
save_train_data_name = 'train_data'
save_train_labels_name = 'train_labels'

save_test_data_name = 'test_data'
save_test_labels_name = 'test_labels'

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
# save features as *.npz format

from scipy.io import wavfile

data = np.zeros((num_labels * num_features, duration * sr))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        # extract 1 sec (i.e. 'duration * sr' length) of each files
        start = int(len(samples)//2 - duration * sample_rate / 2)
        end = int(len(samples)//2 + duration * sample_rate / 2)
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./" + save_train_data_name, train_data)
np.save("./" + save_train_labels_name, train_labels)

np.save("./" + save_test_data_name, test_data)
np.save("./" + save_test_labels_name, test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (4000, 16000), train_labels.shape: (4000,)
# test_data.shape: (1000, 16000), test_labels.shape: (1000,)

# %% [markdown]
# **train data, validation data 분할 및 전처리 (normalization)**

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

random_state = 1234
len_data = train_data.shape[1] # 16000
test_size = 0.2

X_train, X_val, Y_train, Y_val = train_test_split(train_data, train_labels,
                                                  test_size = test_size,
                                                  random_state = random_state) # fixed

x_train = X_train.reshape(len(X_train), len_data, 1)
x_val = X_val.reshape(len(X_val), len_data, 1) 

y_train = to_categorical(Y_train)
y_val = to_categorical(Y_val)

# standarization
mean = x_train.mean()
x_train -= mean
std = x_train.std()
x_train /= std

x_val -= mean
x_val /= std 

print("test_size: {}, random_state: {}\n".format(test_size, random_state))
print('x_train.shape: {}, y_train.shape: {}'.format(x_train.shape, y_train.shape))
print('x_val.shape: {}, y_val.shape: {}'.format(x_val.shape, y_val.shape))
# Out:
# test_size: 0.2, random_state: 1234
#
# x_train.shape: (3200, 16000, 1), y_train.shape: (3200, 50)
# x_val.shape: (800, 16000, 1), y_val.shape: (800, 50)

# %% [markdown]
# **Build Model (GlobalAveragePooling1D())**

# %%
from tensorflow.keras import layers, models
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import plot_model

model = Sequential()
model.add(layers.Conv1D(16, 5, activation = 'relu', input_shape = (sr * duration, 1)))
model.add(layers.MaxPooling1D(5))

model.add(layers.Conv1D(32, 7, activation = 'relu'))
model.add(layers.BatchNormalization())
model.add(layers.MaxPooling1D(5))

model.add(layers.Conv1D(64, 7, activation = 'relu'))
model.add(layers.MaxPooling1D(5))

model.add(layers.Conv1D(128, 7, activation = 'relu'))
model.add(layers.Conv1D(128, 8, activation = 'relu'))
model.add(layers.BatchNormalization())
# model.add(layers.GlobalMaxPooling1D())
model.add(layers.GlobalAveragePooling1D())

model.add(layers.Dense(num_labels, activation = 'softmax'))

model.compile(optimizer = 'rmsprop',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy'])

model.summary()
# plot_model(model, show_shapes = True, to_file = 'model.png')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 15996, 16)         96
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 3199, 16)          0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 3193, 32)          3616
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3193, 32)          128
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 638, 32)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 632, 64)           14400
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 126, 64)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 120, 128)          57472
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 113, 128)          131200
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 113, 128)          512
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 213,874
# Trainable params: 213,554
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# **모델 훈련 및 저장**

# %%
from datetime import datetime

batch_size = 80
epochs = 100

history = model.fit(x_train, y_train,
                    validation_data = (x_val, y_val),
                    epochs = epochs,
                    batch_size = batch_size,
                    verbose = 1) # 1 → 훈련과정 보기, 0 → 훈련과정 생략

save_model_path = "/content/drive/My Drive/models" # save to my drive
if not os.path.exists(save_model_path):
    os.mkdir(save_model_path)

model.save(os.path.join(save_model_path, "{}.h5".format(datetime.today().strftime("%Y_%m_%d_%H_%M_%S"))))
# Out:
# Epoch 1/100
# 40/40 [==============================] - 3s 82ms/step - loss: 2.8715 - accuracy: 0.2747 - val_loss: 3.8016 - val_accuracy: 0.0350
# Epoch 2/100
# 40/40 [==============================] - 3s 74ms/step - loss: 1.7596 - accuracy: 0.6081 - val_loss: 3.9535 - val_accuracy: 0.0250
# Epoch 3/100
# 40/40 [==============================] - 3s 75ms/step - loss: 1.1936 - accuracy: 0.7500 - val_loss: 4.1762 - val_accuracy: 0.0413
# Epoch 4/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.8798 - accuracy: 0.8222 - val_loss: 4.3654 - val_accuracy: 0.0288
# Epoch 5/100
# 40/40 [==============================] - 3s 75ms/step - loss: 0.6575 - accuracy: 0.8637 - val_loss: 4.1773 - val_accuracy: 0.0475
# Epoch 6/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.5069 - accuracy: 0.8966 - val_loss: 4.4872 - val_accuracy: 0.0425
# Epoch 7/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.4268 - accuracy: 0.9128 - val_loss: 4.7502 - val_accuracy: 0.0338
# Epoch 8/100
# 40/40 [==============================] - 3s 75ms/step - loss: 0.3434 - accuracy: 0.9287 - val_loss: 3.5192 - val_accuracy: 0.1700
# Epoch 9/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.2740 - accuracy: 0.9469 - val_loss: 3.4089 - val_accuracy: 0.1513
# Epoch 10/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.2369 - accuracy: 0.9550 - val_loss: 2.7195 - val_accuracy: 0.3225
# Epoch 11/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.2052 - accuracy: 0.9597 - val_loss: 1.9359 - val_accuracy: 0.4325
# Epoch 12/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.1701 - accuracy: 0.9697 - val_loss: 1.4607 - val_accuracy: 0.5612
# Epoch 13/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.1398 - accuracy: 0.9731 - val_loss: 1.1407 - val_accuracy: 0.6338
# Epoch 14/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.1271 - accuracy: 0.9778 - val_loss: 0.5519 - val_accuracy: 0.8413
# Epoch 15/100
# 40/40 [==============================] - 3s 75ms/step - loss: 0.1080 - accuracy: 0.9784 - val_loss: 0.4143 - val_accuracy: 0.8763
# Epoch 16/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.1104 - accuracy: 0.9794 - val_loss: 0.4638 - val_accuracy: 0.8550
# Epoch 17/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0787 - accuracy: 0.9856 - val_loss: 0.4411 - val_accuracy: 0.8612
# Epoch 18/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0889 - accuracy: 0.9834 - val_loss: 0.5933 - val_accuracy: 0.8363
# Epoch 19/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0617 - accuracy: 0.9894 - val_loss: 0.3082 - val_accuracy: 0.9087
# Epoch 20/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0615 - accuracy: 0.9881 - val_loss: 0.2939 - val_accuracy: 0.9150
# Epoch 21/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0679 - accuracy: 0.9862 - val_loss: 0.9066 - val_accuracy: 0.8487
# Epoch 22/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0751 - accuracy: 0.9816 - val_loss: 0.1710 - val_accuracy: 0.9488
# Epoch 23/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0376 - accuracy: 0.9937 - val_loss: 0.3474 - val_accuracy: 0.8963
# Epoch 24/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0473 - accuracy: 0.9897 - val_loss: 0.1664 - val_accuracy: 0.9500
# Epoch 25/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0372 - accuracy: 0.9928 - val_loss: 0.2469 - val_accuracy: 0.9175
# Epoch 26/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0562 - accuracy: 0.9909 - val_loss: 0.3053 - val_accuracy: 0.9162
# Epoch 27/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0355 - accuracy: 0.9931 - val_loss: 0.1957 - val_accuracy: 0.9413
# Epoch 28/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.
100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0035 - accuracy: 0.9997 - val_loss: 0.1317 - val_accuracy: 0.9638
# Epoch 62/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0160 - accuracy: 0.9959 - val_loss: 0.2125 - val_accuracy: 0.9513
# Epoch 63/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0111 - accuracy: 0.9975 - val_loss: 0.2547 - val_accuracy: 0.9275
# Epoch 64/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0123 - accuracy: 0.9972 - val_loss: 0.2056 - val_accuracy: 0.9425
# Epoch 65/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0167 - accuracy: 0.9969 - val_loss: 0.1540 - val_accuracy: 0.9525
# Epoch 66/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0164 - accuracy: 0.9972 - val_loss: 0.3191 - val_accuracy: 0.9100
# Epoch 67/100
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.1203 - val_accuracy: 0.9638
# Epoch 68/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0132 - accuracy: 0.9959 - val_loss: 0.1735 - val_accuracy: 0.9488
# Epoch 69/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0091 - accuracy: 0.9984 - val_loss: 1.1102 - val_accuracy: 0.7450
# Epoch 70/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0090 - accuracy: 0.9975 - val_loss: 0.1454 - val_accuracy: 0.9563
# Epoch 71/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0103 - accuracy: 0.9969 - val_loss: 0.2270 - val_accuracy: 0.9413
# Epoch 72/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0156 - accuracy: 0.9966 - val_loss: 0.3435 - val_accuracy: 0.9162
# Epoch 73/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 0.8215 - val_accuracy: 0.8238
# Epoch 74/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0190 - accuracy: 0.9956 - val_loss: 0.1619 - val_accuracy: 0.9463
# Epoch 75/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 0.1161 - val_accuracy: 0.9613
# Epoch 76/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0141 - accuracy: 0.9966 - val_loss: 0.4227 - val_accuracy: 0.9112
# Epoch 77/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0063 - accuracy: 0.9991 - val_loss: 0.7232 - val_accuracy: 0.8350
# Epoch 78/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0144 - accuracy: 0.9972 - val_loss: 0.1914 - val_accuracy: 0.9450
# Epoch 79/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0061 - accuracy: 0.9981 - val_loss: 0.2390 - val_accuracy: 0.9325
# Epoch 80/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0089 - accuracy: 0.9978 - val_loss: 0.2181 - val_accuracy: 0.9425
# Epoch 81/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.1424 - val_accuracy: 0.9588
# Epoch 82/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0148 - accuracy: 0.9969 - val_loss: 0.3536 - val_accuracy: 0.9225
# Epoch 83/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0092 - accuracy: 0.9972 - val_loss: 0.1710 - val_accuracy: 0.9500
# Epoch 84/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0092 - accuracy: 0.9981 - val_loss: 0.1710 - val_accuracy: 0.9450
# Epoch 85/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0044 - accuracy: 0.9994 - val_loss: 0.2412 - val_accuracy: 0.9275
# Epoch 86/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0037 - accuracy: 0.9991 - val_loss: 0.2031 - val_accuracy: 0.9513
# Epoch 87/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0120 - accuracy: 0.9975 - val_loss: 0.1338 - val_accuracy: 0.9613
# Epoch 88/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0171 - accuracy: 0.9950 - val_loss: 0.3341 - val_accuracy: 0.9200
# Epoch 89/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.6509 - val_accuracy: 0.8850
# Epoch 90/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0119 - accuracy: 0.9984 - val_loss: 0.5864 - val_accuracy: 0.8675
# Epoch 91/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0071 - accuracy: 0.9969 - val_loss: 0.1729 - val_accuracy: 0.9525
# Epoch 92/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0030 - accuracy: 0.9994 - val_loss: 0.2178 - val_accuracy: 0.9500
# Epoch 93/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0070 - accuracy: 0.9984 - val_loss: 0.5177 - val_accuracy: 0.8850
# Epoch 94/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0150 - accuracy: 0.9966 - val_loss: 0.4064 - val_accuracy: 0.8963
# Epoch 95/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0034 - accuracy: 0.9991 - val_loss: 0.1917 - val_accuracy: 0.9362
# Epoch 96/100
# 40/40 [==============================] - 3s 75ms/step - loss: 0.0085 - accuracy: 0.9975 - val_loss: 0.4775 - val_accuracy: 0.8900
# Epoch 97/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.2694 - val_accuracy: 0.9250
# Epoch 98/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0033 - accuracy: 0.9994 - val_loss: 0.4933 - val_accuracy: 0.8800
# Epoch 99/100
# 40/40 [==============================] - 3s 73ms/step - loss: 0.0064 - accuracy: 0.9981 - val_loss: 0.4697 - val_accuracy: 0.8850
# Epoch 100/100
# 40/40 [==============================] - 3s 74ms/step - loss: 0.0128 - accuracy: 0.9962 - val_loss: 0.2709 - val_accuracy: 0.9337

# %% [markdown]
# **히스토리 출력**

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

fig = plt.figure(figsize = (10, 4), facecolor = 'white', dpi = 300)

# accuracy
plt.subplot(1, 2, 1)

plt.plot(range(1, epochs + 1), acc, 'bo', label = 'Trianing accuracy of model')
plt.plot(range(1, epochs + 1), val_acc, 'b', label = 'Validation accuracy of model')
plt.title('train and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('accuracy')
plt.legend()

# loss
plt.subplot(1, 2, 2)

plt.plot(range(1, epochs + 1), loss, 'bo', label = 'Trianing loss of model')
plt.plot(range(1, epochs + 1), val_loss, 'b', label = 'Validation loss of model')
plt.title('train and validation loss')
plt.xlabel('Epochs')
plt.ylabel('loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# **test data를 통해 모델 최종 평가 (field test)**

# %%
# reshaping
del test_data, test_labels

test_data = np.load(save_test_data_name + ".npy")
test_labels = np.load(save_test_labels_name + ".npy")

test_data = test_data.reshape(len(test_data), len_data, 1)
test_labels = to_categorical(test_labels)

# standarization
test_data -= mean
test_data /= std 

print('test_data.shape: {}, test_labels.shape: {}'.format(test_data.shape, test_labels.shape))
# Out:
# test_data.shape: (1000, 16000, 1), test_labels.shape: (1000, 50)

# %%
results = model.evaluate(test_data, test_labels, batch_size = batch_size)

print('test loss, test acc:', results)
# Out:
# 13/13 [==============================] - 1s 48ms/step - loss: 0.1490 - accuracy: 0.9600
# test loss, test acc: [0.1489524096250534, 0.9599999785423279]

# %% [markdown]
# **Layer name 확인**

# %%
layer_names = np.array([])
for layer in model.layers:
    layer_names = np.append(layer_names, layer.name)

print(layer_names)
# Out:
# ['conv1d_10' 'max_pooling1d_6' 'conv1d_11' 'batch_normalization_4'
#  'max_pooling1d_7' 'conv1d_12' 'max_pooling1d_8' 'conv1d_13' 'conv1d_14'
#  'batch_normalization_5' 'global_average_pooling1d_2' 'dense_2']

# %% [markdown]
# **모델 weight & bias 확인**
#
# conv1d()는 weight (size: (kernel size, # of input filters, # of output filters))와 bias (size: (# of output filters))의 가중치를 가짐.
#
# Dense()는 weight (size: (input shape))와 bias (size: (output shape))의 가중치를 가짐.
#
# batchnormalization()은 4개의 가중치 (size: (input shape))를 가짐.
#
# max_pooling1d, global_average_normalization은 가중치를 가지지 않음.
#
# https://datascienceschool.net/view-notebook/51e147088d474fe1bf32e394394eaea7/
#
# https://keras.io/ko/layers/convolutional/

# %%
for l in model.layers:
    print("{}".format(l.name))

    for w in l.get_weights():
        print(w.shape, end = " ")
    
    print('\n' if l.get_weights() else 'None\n')
# Out:
# conv1d_10
# (5, 1, 16) (16,)
#
# max_pooling1d_6
# None
#
# conv1d_11
# (7, 16, 32) (32,)
#
# batch_normalization_4
# (32,) (32,) (32,) (32,)
#
# max_pooling1d_7
# None
#
# conv1d_12
# (7, 32, 64) (64,)
#
# max_pooling1d_8
# None
#
# conv1d_13
# (7, 64, 128) (128,)
#
# conv1d_14
# (8, 128, 128) (128,)
#
# batch_normalization_5
# (128,) (128,) (128,) (128,)
#
# global_average_pooling1d_2
# None
#
# dense_2
# (128, 50) (50,)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_10 (Conv1D)           (None, 15996, 16)         96
# _________________________________________________________________
# max_pooling1d_6 (MaxPooling1 (None, 3199, 16)          0
# _________________________________________________________________
# conv1d_11 (Conv1D)           (None, 3193, 32)          3616
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3193, 32)          128
# _________________________________________________________________
# max_pooling1d_7 (MaxPooling1 (None, 638, 32)           0
# _________________________________________________________________
# conv1d_12 (Conv1D)           (None, 632, 64)           14400
# _________________________________________________________________
# max_pooling1d_8 (MaxPooling1 (None, 126, 64)           0
# _________________________________________________________________
# conv1d_13 (Conv1D)           (None, 120, 128)          57472
# _________________________________________________________________
# conv1d_14 (Conv1D)           (None, 113, 128)          131200
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 113, 128)          512
# _________________________________________________________________
# global_average_pooling1d_2 ( (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                6450
# =================================================================
# Total params: 213,874
# Trainable params: 213,554
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# https://www.researchgate.net/publication/327594319_A_Complete_End-to-End_Speaker_Verification_System_Using_Deep_Neural_Networks_From_Raw_Signals_to_Verification_Result

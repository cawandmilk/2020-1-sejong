# %% [markdown]
# # **주요 내용**
#
# *   triplet loss 실험
#     *   train : test = 5 : 95로 변경
#     *   5-way, 10-way 고정

# %%
notebookName = "20200526"
notebookName
# Out:
# '20200526'

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 1703043044641791571, name: "/device:XLA_CPU:0"
#  device_type: "XLA_CPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 15627469858727805984
#  physical_device_desc: "device: XLA_CPU device", name: "/device:XLA_GPU:0"
#  device_type: "XLA_GPU"
#  memory_limit: 17179869184
#  locality {
#  }
#  incarnation: 17829341447857194144
#  physical_device_desc: "device: XLA_GPU device", name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 15701401920
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 6655882480060205631
#  physical_device_desc: "device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0"]

# %%
import platform
platform.platform()
# Out:
# 'Linux-4.19.104+-x86_64-with-Ubuntu-18.04-bionic'

# %%
# !nvidia-smi
# Out:
# Tue May 26 07:38:16 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   47C    P0    36W / 250W |    353MiB / 16280MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# **unzip**

# %%
import os

pcm_path = "./pcm_dataset"
wav_path = "./wav_dataset"

# mkdir
if not os.path.exists(pcm_path): os.mkdir(pcm_path)
if not os.path.exists(wav_path): os.mkdir(wav_path)

# unsip
# !unzip -q "/content/drive/My Drive/ETRI/9_voice_download_4_Korean_English_by_Korean_part2.zip" -d "./pcm_dataset"

print(os.listdir(pcm_path)[:5])
print(len(os.listdir(pcm_path)))
# Out:
# ['GSF08333KJH0', 'GSM07355MIW0', 'I4F03423KSR0', 'GSM03224CHD0', 'GSF05134JHK0']
# 50

# %% [markdown]
# ***.pcm to *.wav**

# %%
import wave

for i, folder_path in enumerate(sorted(os.listdir(pcm_path))):
    print("{}\t{}".format(i, folder_path))

    file_list = os.listdir(os.path.join(pcm_path, folder_path)) # label's path
    file_list_pcm = [files for files in file_list if files.endswith(".pcm")] # *.pcm files

    for j, file_path in enumerate(sorted(file_list_pcm)):
        with open(os.path.join(pcm_path, folder_path, file_path), "rb") as pcm_file:
            pcm_data = pcm_file.read()
        # save as {label}_{features}.wav format
        with wave.open(os.path.join(wav_path, "{}_{}.wav".format(i, j)), 'wb') as wav_file:
            wav_file.setparams((1, 2, 16000, 0, 'NONE', 'NONE')) # 16kHz, mono channel
            wav_file.writeframes(pcm_data)
# Out:
# 0	GSF03031LJH0
# 1	GSF03732JJH0
# 2	GSF04122LHK0
# 3	GSF04524CJI0
# 4	GSF04623LWJ0
# 5	GSF04923PEY0
# 6	GSF05134JHK0
# 7	GSF05432KSY0
# 8	GSF05733HBH0
# 9	GSF05844LJR0
# 10	GSF06654KES0
# 11	GSF06742CKA0
# 12	GSF06833JYK0
# 13	GSF06934SYN0
# 14	GSF07132LCY0
# 15	GSF08142LDH0
# 16	GSF08233NEH0
# 17	GSF08333KJH0
# 18	GSF09025WYY0
# 19	GSF09431SHY0
# 20	GSF09844KKS0
# 21	GSM02434AGS0
# 22	GSM02544LHS0
# 23	GSM03224CHD0
# 24	GSM03321SDK0
# 25	GSM03634SJY0
# 26	GSM03823YJK0
# 27	GSM04233KMS0
# 28	GSM04424JBRC
# 29	GSM05953CJH0
# 30	GSM06044JBY0
# 31	GSM06235BJH0
# 32	GSM07042NSK0
# 33	GSM07355MIW0
# 34	GSM09534JHD0
# 35	GSM09644KCK0
# 36	GSM09752SCY0
# 37	I4F02224SDY0
# 38	I4F02631KSM0
# 39	I4F02821YRR0
# 40	I4F02933JSI0
# 41	I4F03423KSR0
# 42	I4F03543KSY0
# 43	I4F03922LKY0
# 44	I4F04732OIY0
# 45	I4F05332CJH0
# 46	I4F05625JSY0
# 47	I4F07443LJA0
# 48	I4F07633JSI0
# 49	I4F07852PKJ0

# %%
import numpy as np

num_labels = 5
num_features = 100
data_length = 3 ** 9

train_rate = 0.05
num_train_data = int(num_features * train_rate) # 5

select_train_data = [True] * num_train_data + [False] * (num_features - num_train_data)
select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# a = np.array([True] * shot + [False] * (num_train_data - shot))
# np.random.shuffle(a)
# b = np.array([False] * (num_features - num_train_data))

# select_train_data = np.concatenate((a, b))
# select_test_data = [False] * num_train_data + [True] * (num_features - num_train_data)

# %% [markdown]
# **train data, test data로 구분하여 numpy 저장 (*.npz)**

# %%
from scipy.io import wavfile

data = np.zeros((num_labels * num_features, data_length))
labels = np.zeros((num_labels * num_features))

for i in range(num_labels):
    for j in range(num_features):
        file_name = "{}_{}.wav".format(i, j)
        sample_rate, samples = wavfile.read(os.path.join(wav_path, file_name))
        
        start = int(len(samples) - data_length) // 2
        end = start + data_length
        
        data[i * num_features + j] = samples[start:end]
        labels[i * num_features + j] = i

train_data = data[select_train_data * num_labels]
train_labels = labels[select_train_data * num_labels]

test_data = data[select_test_data * num_labels]
test_labels = labels[select_test_data * num_labels]

# save *.npy        
np.save("./train_data", train_data)
np.save("./train_labels", train_labels)

np.save("./test_data", test_data)
np.save("./test_labels", test_labels)

print("train_data.shape: {}, train_labels.shape: {}".format(train_data.shape, train_labels.shape))
print("test_data.shape: {}, test_labels.shape: {}".format(test_data.shape, test_labels.shape))
# Out:
# train_data.shape: (25, 19683), train_labels.shape: (25,)
# test_data.shape: (475, 19683), test_labels.shape: (475,)

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((train_data[:, :, np.newaxis], train_labels))
test_dataset = tf.data.Dataset.from_tensor_slices((test_data[:, :, np.newaxis], test_labels))

train_dataset = train_dataset.shuffle(data_length * 1000).batch(128)
test_dataset = test_dataset.batch(128)

# %%
train_dataset
# Out:
# <BatchDataset shapes: ((None, 19683, 1), (None,)), types: (tf.float64, tf.float64)>

# %% [markdown]
# **Build Model**

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Conv1D(filters = 32, kernel_size = 3, padding = 'same', activation = 'relu', input_shape = (data_length, 1)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling1D(pool_size = 3),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Conv1D(filters = 64, kernel_size = 3, padding = 'same', activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling1D(pool_size = 3),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Conv1D(filters = 128, kernel_size = 3, padding = 'same', activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling1D(pool_size = 3),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.Conv1D(filters = 256, kernel_size = 3, padding = 'same', activation = 'relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPooling1D(pool_size = 3),
    tf.keras.layers.Dropout(0.3),

    tf.keras.layers.GlobalAveragePooling1D(),
    tf.keras.layers.Dense(256, activation = None),
    tf.keras.layers.Lambda(lambda x: tf.math.l2_normalize(x, axis = 1)) # L2 normalize embeddings
])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_32 (Conv1D)           (None, 19683, 32)         128
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 19683, 32)         128
# _________________________________________________________________
# max_pooling1d_32 (MaxPooling (None, 6561, 32)          0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 6561, 32)          0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 6561, 64)          6208
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 6561, 64)          256
# _________________________________________________________________
# max_pooling1d_33 (MaxPooling (None, 2187, 64)          0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 2187, 64)          0
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 2187, 128)         24704
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 2187, 128)         512
# _________________________________________________________________
# max_pooling1d_34 (MaxPooling (None, 729, 128)          0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 729, 128)          0
# _________________________________________________________________
# conv1d_35 (Conv1D)           (None, 729, 256)          98560
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 729, 256)          1024
# _________________________________________________________________
# max_pooling1d_35 (MaxPooling (None, 243, 256)          0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 243, 256)          0
# _________________________________________________________________
# global_average_pooling1d_8 ( (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               65792
# _________________________________________________________________
# lambda_8 (Lambda)            (None, 256)               0
# =================================================================
# Total params: 197,312
# Trainable params: 196,352
# Non-trainable params: 960
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, show_shapes = True, to_file = 'model.png')

# %% [markdown]
# **Train model**

# %%
import tensorflow_addons as tfa
import tensorflow_datasets as tfds

model.compile(
    optimizer = tf.keras.optimizers.Adam(0.001),
    loss = tfa.losses.TripletSemiHardLoss())

# %%
# callback
def scheduler(epoch, lr):
    if not epoch:
        return lr
    return 0.3 * lr if not (epoch % 50) else lr

# Train the network
history = model.fit(
    train_dataset,
    verbose = 1,
    epochs = 100)
    # callbacks = [tf.keras.callbacks.LearningRateScheduler(scheduler)])
# Out:
# Epoch 1/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9725
# Epoch 2/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.9540
# Epoch 3/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.9088
# Epoch 4/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.8447
# Epoch 5/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7458
# Epoch 6/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6928
# Epoch 7/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7347
# Epoch 8/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7352
# Epoch 9/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.7517
# Epoch 10/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7387
# Epoch 11/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.7399
# Epoch 12/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.7037
# Epoch 13/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6545
# Epoch 14/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.6191
# Epoch 15/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5647
# Epoch 16/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.5317
# Epoch 17/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.4878
# Epoch 18/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.4322
# Epoch 19/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.2110
# Epoch 20/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.2112
# Epoch 21/100
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1388
# Epoch 22/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1882
# Epoch 23/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.1114
# Epoch 24/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.1118
# Epoch 25/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0610
# Epoch 26/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0567
# Epoch 27/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0240
# Epoch 28/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0433
# Epoch 29/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0058
# Epoch 30/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0159
# Epoch 31/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0081
# Epoch 32/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0029
# Epoch 33/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0054
# Epoch 34/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 35/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0028
# Epoch 36/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0131
# Epoch 37/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5801e-05
# Epoch 38/100
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0062
# Epoch 39/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0072
# Epoch 40/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9238e-04
# Epoch 41/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 42/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0020
# Epoch 43/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0085
# Epoch 44/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0111
# Epoch 45/100
# 1/1 [==============================] - 0s 2ms/step - loss: 7.6247e-04
# Epoch 46/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 47/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 48/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 49/100
# 1/1 [==============================] - 0s 2ms/step - loss: 3.5595e-04
# Epoch 50/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0084
# Epoch 51/100
# 1/1 [==============================] - 0s 1ms/step - loss: 8.9020e-04
# Epoch 52/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 53/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 54/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 55/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0022
# Epoch 56/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.1647e-04
# Epoch 57/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 58/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.2845e-04
# Epoch 59/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 60/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 61/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0072
# Epoch 62/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 63/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0026
# Epoch 64/100
# 1/1 [==============================] - 0s 1ms/step - loss: 6.7543e-04
# Epoch 65/100
# 1/1 [==============================] - 0s 1ms/step - loss: 1.5501e-04
# Epoch 66/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 67/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 68/100
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4981e-05
# Epoch 69/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 70/100
# 1/1 [==============================] - 0s 2ms/step - loss: 5.4858e-04
# Epoch 71/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 72/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 73/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 74/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 75/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 76/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 77/100
# 1/1 [==============================] - 0s 6ms/step - loss: 0.0000e+00
# Epoch 78/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 79/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 80/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 81/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 82/100
# 1/1 [==============================] - 0s 2ms/step - loss: 1.9859e-04
# Epoch 83/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 84/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 85/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 86/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 87/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 88/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 89/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 90/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 91/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 92/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 93/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 94/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 95/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 96/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 97/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 98/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00
# Epoch 99/100
# 1/1 [==============================] - 0s 2ms/step - loss: 0.0000e+00
# Epoch 100/100
# 1/1 [==============================] - 0s 1ms/step - loss: 0.0000e+00

# %%
results = model.predict(test_dataset)

# %%
results.shape
# Out:
# (475, 256)

# %%
import io
import numpy as np

# Save test embeddings for visualization in projector
np.savetxt("vecs.tsv", results, delimiter='\t')

out_m = io.open('meta.tsv', 'w', encoding='utf-8')
for img, labels in tfds.as_numpy(test_dataset):
    [out_m.write(str(x) + "\n") for x in labels]
out_m.close()


try:
    from google.colab import files
    files.download('vecs.tsv')
    files.download('meta.tsv')
except:
    pass

# %%
history.history.keys()
# Out:
# dict_keys(['loss'])

# %%
from matplotlib import pyplot as plt
plt.plot(np.arange(1, 100 + 1, 1), history.history['loss'])

# %% [markdown]
# **Embedding Visualization with t-Stochastic Neighbor Embedding (t-SNE)**
#
# *   https://lovit.github.io/nlp/representation/2018/09/28/tsne/
# *   https://lovit.github.io/nlp/representation/2018/09/28/tsne/

# %%
import numpy as np

n_data_per_class = num_features - num_train_data
n_classes = num_labels

x = model.predict(test_dataset)
y = test_labels

# %%
x.shape
# Out:
# (475, 256)

# %%
y.shape
# Out:
# (475,)

# %%
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot
from bokeh.io import export_png

output_notebook()

title = '{} classes {} points'.format(n_classes, n_classes * n_data_per_class)

def draw_figure(x, y, title, show_figure=True,
    colors = 'firebrick darksalmon lightslategray darkslateblue forestgreen'.split()):

    p = figure(width=400, height=400, title=title)
    for c in range(n_classes):
        idx = np.where(y == c)[0]
        x_ = x[idx]
        p.scatter(x_[:,0], x_[:,1], fill_color=colors[c], line_color=colors[c])
    if show_figure:
        show(p)
    return p

p = draw_figure(x, y, title)
# Out:
#   <div class="bk-root" id="f1517d19-1655-489e-9557-b3d0d79e43e3" data-root-id="4545"></div>

# %%
from sklearn.manifold import TSNE

plots = []
for perplexity in [2, 5, 10, 30, 100, 200, 500, 1000]:
    z = TSNE(
        n_components = 2,
        perplexity = perplexity
    ).fit_transform(x)
    title = 't-SNE with perplexity = {}'.format(perplexity)
    plots.append(draw_figure(z, y, title, show_figure = False))

gp = gridplot([
               [plots[0], plots[1]],
               [plots[2], plots[3]], 
               [plots[4], plots[5]],
               [plots[6], plots[7]]])
show(gp)
# Out:
#   <div class="bk-root" id="7b9a6076-2260-4b15-b717-1debe98abe52" data-root-id="10691"></div>

# %% [markdown]
# **K-Nearest Neighbor Algorithm**

# %%
from sklearn.neighbors import KNeighborsClassifier

x = TSNE(n_components = 2).fit_transform(model.predict(train_dataset))
y = train_labels

classifier = KNeighborsClassifier(n_neighbors = 3, weights = 'distance')
classifier.fit(x, y)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=3, p=2,
#                      weights='distance')

# %%
_x = TSNE(n_components = 2).fit_transform(model.predict(test_dataset))
_y = test_labels

print(classifier.score(_x, _y))
# Out:
# 0.2
